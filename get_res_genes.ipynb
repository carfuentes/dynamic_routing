# %%
import networkx as nx
import numpy as np
import os
import random as rand
from collections import defaultdict
import matplotlib.pyplot as plt

# %%
def get_r_dictionaries(file,mapping=True):
    with open(file, "r") as in_file:
        dict_map={}
        for line in in_file:
            line.strip()
            if mapping:
                dict_map[line.split()[1]]=line.split()[0]
            else:
                dict_map[line.split()[0]]=set(line.split()[1:])
    return dict_map

# %%
def get_cyclic_net(filename):
    G=nx.read_edgelist(filename, comments='#', delimiter="\t", nodetype =str,  data=(('mode',str),), create_using=nx.DiGraph())
    G.remove_nodes_from(["Source", "Target"])
    selfloops=G.selfloop_edges()
    G.remove_edges_from(G.selfloop_edges())

    while 0 in [d[1] for d in G.in_degree()] or 0 in [d[1] for d in G.out_degree()]:
        nodes_to_remove=[node for node in G if G.in_degree(node) == 0 or G.out_degree(node) == 0]
        G.remove_nodes_from(nodes_to_remove)
        
        
    selfloops_in_reservoir=[edge for edge in selfloops if edge[0] in G.nodes()]
    G.add_edges_from(selfloops_in_reservoir)

    return G

# %%
def build_adj_weighted_matrix(filename,mapping):
        #NETWORK v2.0
    net=get_cyclic_net(filename)
    nx.relabel_nodes(net,mapping,copy=False)
    dict_pos=dict((node,pos) for (pos,node) in enumerate(net.nodes()))
    for edge in net.edges(data="mode", default=0):
        source,target,mode=edge
        if mode== "+":
            net[source][target]["weight"]= abs(rand.gauss(0,1))
        elif mode== "-":
            net[source][target]["weight"]= rand.gauss(0,1)*-1
        elif mode== 0:
            net[source][target]["weight"]= rand.gauss(0,1)
        
    return nx.to_numpy_matrix(net),dict_pos

# %%
def write_nodes_file(out_file,filename,net):
    with open("%s_%s"%(out_file,filename),"w") as out:
        for gene in net.nodes():
            if "hsa" in gene:
                gene=gene[4:].lower()
            out.write(gene +"\n")

# %%
file="Dataset1/network_edge_list_ENCODE.csv"
net=get_cyclic_net("Dataset1/network_edge_list_ENCODE.csv")
G=nx.read_edgelist(file, comments='#', delimiter="\t", nodetype =str,  data=(('mode',str),), create_using=nx.DiGraph())

# %%
G.in_edges("TMEM14C")
# Out:
# InEdgeDataView([('SP1', 'TMEM14C'), ('NR3C1', 'TMEM14C'), ('SREBF1', 'TMEM14C'), ('MAFK', 'TMEM14C'), ('MAFF', 'TMEM14C')])

# %%
readout_to_cyclic=['ZNF775',
 'TMEM14C',
 'C20orf111',
 'STYXL1',
 'BRD9',
 'ABCA3',
 'ALDH1A1',
 'ACAD9']

# %%
input_nodes=[(go,readout) for go,set_readout in GO_id_map.items() for readout in set_readout ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-64eca7748b53> in <module>()
# ----> 1 input_nodes=[(go,readout) for go,set_readout in GO_id_map.items() for readout in set_readout ]
#
# NameError: name 'GO_id_map' is not defined

# %%
edges_readout=[edge for edge in G.edges() if edge[1] in readout_to_cyclic and edge[0] in net.nodes()]

# %%
edges_readout
# Out:
# [('SP1', 'TMEM14C'),
#  ('BRCA1', 'STYXL1'),
#  ('E2F6', 'ABCA3'),
#  ('E2F6', 'ACAD9'),
#  ('CTCFL', 'ABCA3'),
#  ('SIN3A', 'BRD9'),
#  ('SIN3A', 'C20orf111'),
#  ('MAX', 'ABCA3'),
#  ('MAX', 'ACAD9'),
#  ('MAX', 'ALDH1A1'),
#  ('NFYB', 'ZNF775'),
#  ('NRF1', 'ABCA3'),
#  ('NRF1', 'C20orf111'),
#  ('NRF1', 'ACAD9'),
#  ('TCF4', 'ZNF775'),
#  ('CTCF', 'ALDH1A1'),
#  ('CTCF', 'C20orf111'),
#  ('CTCF', 'ABCA3'),
#  ('ZBTB33', 'STYXL1'),
#  ('ETS1', 'STYXL1'),
#  ('NR3C1', 'TMEM14C'),
#  ('E2F1', 'BRD9'),
#  ('FOS', 'ZNF775'),
#  ('NFYA', 'ZNF775'),
#  ('GABPA', 'BRD9'),
#  ('GABPA', 'STYXL1'),
#  ('JUND', 'C20orf111'),
#  ('JUND', 'ACAD9'),
#  ('USF1', 'ALDH1A1'),
#  ('E2F4', 'BRD9'),
#  ('MYC', 'BRD9'),
#  ('JUN', 'ALDH1A1'),
#  ('MAFK', 'TMEM14C'),
#  ('ATF3', 'ACAD9'),
#  ('RAD21', 'ALDH1A1'),
#  ('RAD21', 'C20orf111'),
#  ('MAFF', 'TMEM14C'),
#  ('SREBF1', 'ZNF775'),
#  ('SREBF1', 'TMEM14C'),
#  ('ELF1', 'STYXL1')]

# %%
net.add_edges_from(edges_readout)
net.add_edges_from(input_nodes)
nx.write_gexf(net, "test.gexf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-1443bc66cec6> in <module>()
#       1 net.add_edges_from(edges_readout)
# ----> 2 net.add_edges_from(input_nodes)
#       3 nx.write_gexf(net, "test.gexf")
#
# NameError: name 'input_nodes' is not defined

# %%
G.add_edges_from(input_nodes)
nx.write_gexf(G, "full.gexf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-f29cc4ac20b4> in <module>()
# ----> 1 G.add_edges_from(input_nodes)
#       2 nx.write_gexf(G, "full.gexf")
#
# NameError: name 'input_nodes' is not defined

# %%
readout_direct_targets=defaultdict(set)

for source, target in G.edges():
    if source in net.nodes() and target not in net.nodes():
        readout_direct_targets[source].add(target)

readout_direct_targets["MAX"]
    #print(target)
# Out:
# {'AATF',
#  'ABCA17P',
#  'ABCB4',
#  'ABCF1',
#  'ABCG1',
#  'AC011472.1',
#  'AC013553.1',
#  'AC044799.1',
#  'AC136618.1',
#  'ACAP1',
#  'ACTC1',
#  'ADAM19',
#  'ADAMTS16',
#  'ADH6',
#  'ADM',
#  'ADORA1',
#  'AFMID',
#  'AFP',
#  'AGFG2',
#  'AGT',
#  'AIMP2',
#  'AIP',
#  'AK2',
#  'AKR1A1',
#  'AKR1C1',
#  'AKR1C3',
#  'AKT1S1',
#  'ALB',
#  'ALDOC',
#  'ALG2',
#  'ALG3',
#  'ALOX15B',
#  'AMDHD2',
#  'AMN',
#  'AMPD3',
#  'ANAPC7',
#  'ANG',
#  'ANK1',
#  'ANKRD12',
#  'ANKRD30BL',
#  'ANO3',
#  'ANP32B',
#  'AOC3',
#  'AP1G2',
#  'AP1S1',
#  'AP2M1',
#  'AP4M1',
#  'APBB3',
#  'APEX1',
#  'APOBR',
#  'APOC1',
#  'APOC2',
#  'APOE',
#  'APOH',
#  'APRT',
#  'ARHGAP24',
#  'ARSK',
#  'ASGR1',
#  'ASGR2',
#  'ASPSCR1',
#  'ATL3',
#  'ATP13A4',
#  'ATP6V0B',
#  'ATP6V0D1',
#  'ATP8B1',
#  'ATXN3',
#  'BAT3',
#  'BAX',
#  'BCAS3',
#  'BCKDHA',
#  'BCL2',
#  'BCR',
#  'BIN1',
#  'BLOC1S3',
#  'BMP4',
#  'BOLA1',
#  'BPIL1',
#  'BST2',
#  'BUB3',
#  'C10orf116',
#  'C10orf18',
#  'C10orf46',
#  'C10orf76',
#  'C10orf88',
#  'C11orf59',
#  'C12orf24',
#  'C12orf49',
#  'C13orf23',
#  'C16orf5',
#  'C16orf54',
#  'C16orf73',
#  'C17orf86',
#  'C17orf87',
#  'C18orf19',
#  'C19orf24',
#  'C19orf47',
#  'C19orf48',
#  'C19orf70',
#  'C1R',
#  'C1S',
#  'C1orf107',
#  'C1orf110',
#  'C1orf212',
#  'C1orf43',
#  'C1orf51',
#  'C1orf55',
#  'C20orf12',
#  'C21orf49',
#  'C22orf29',
#  'C2CD4B',
#  'C2orf34',
#  'C3',
#  'C3orf17',
#  'C3orf26',
#  'C5orf33',
#  'C5orf4',
#  'C5orf41',
#  'C6orf108',
#  'C6orf211',
#  'C6orf52',
#  'C7orf13',
#  'C7orf40',
#  'C9orf156',
#  'C9orf43',
#  'C9orf86',
#  'CA5A',
#  'CABC1',
#  'CACNA2D4',
#  'CACNG1',
#  'CALCB',
#  'CAPG',
#  'CARD6',
#  'CASP14',
#  'CBX5',
#  'CC2D1B',
#  'CCDC103',
#  'CCDC116',
#  'CCDC47',
#  'CCDC86',
#  'CCDC99',
#  'CCL14',
#  'CCL22',
#  'CCND1',
#  'CCNJ',
#  'CCNT1',
#  'CCR7',
#  'CD164',
#  'CD19',
#  'CD248',
#  'CD37',
#  'CD4',
#  'CD7',
#  'CD70',
#  'CD79A',
#  'CD79B',
#  'CD82',
#  'CDH11',
#  'CDH15',
#  'CDK15',
#  'CDK4',
#  'CEACAM1',
#  'CEACAM21',
#  'CEACAM5',
#  'CENPF',
#  'CENPM',
#  'CENPP',
#  'CHI3L1',
#  'CHP',
#  'CKLF',
#  'CKS1B',
#  'CLCN6',
#  'CLCN7',
#  'CLDN5',
#  'CLEC17A',
#  'CLIP3',
#  'CLN3',
#  'CLUAP1',
#  'COL4A2',
#  'COL6A1',
#  'COL9A1',
#  'COL9A3',
#  'COMMD8',
#  'COPS7A',
#  'COQ4',
#  'CORO1A',
#  'CORO1C',
#  'CPN2',
#  'CPVL',
#  'CRCT1',
#  'CRKL',
#  'CRLF1',
#  'CSF1',
#  'CSTF3',
#  'CTNNA1',
#  'CTSH',
#  'CTU2',
#  'CUTA',
#  'CXCL16',
#  'CXCR4',
#  'CYP1B1',
#  'CYSLTR1',
#  'CYTIP',
#  'DAB2',
#  'DAK',
#  'DBP',
#  'DCAF17',
#  'DCN',
#  'DDR2',
#  'DDX21',
#  'DDX42',
#  'DENND1C',
#  'DERL3',
#  'DFFA',
#  'DGCR8',
#  'DHDDS',
#  'DHRS2',
#  'DHX35',
#  'DHX40',
#  'DKK3',
#  'DLK1',
#  'DMPK',
#  'DNAH14',
#  'DNAJB9',
#  'DNAJC11',
#  'DNAJC16',
#  'DNAJC30',
#  'DNAJC8',
#  'DNLZ',
#  'DOCK10',
#  'DOK7',
#  'DPAGT1',
#  'DPEP1',
#  'DSCR4',
#  'DSCR8',
#  'DUS3L',
#  'DUSP10',
#  'DUSP9',
#  'DVL2',
#  'DYM',
#  'DYNC1H1',
#  'DYRK1B',
#  'EAF2',
#  'EBI3',
#  'EBNA1BP2',
#  'ECD',
#  'ECE1',
#  'ECE2',
#  'EDN1',
#  'EFTUD2',
#  'EIF2B3',
#  'EIF3B',
#  'EIF3K',
#  'EIF4A1',
#  'EIF4E',
#  'EIF4EBP3',
#  'EIF4H',
#  'EIF5A2',
#  'ELOVL2',
#  'ELOVL3',
#  'EML4',
#  'EMR1',
#  'ENKUR',
#  'ENO1',
#  'ENOPH1',
#  'ENPP2',
#  'EPB41L2',
#  'EPO',
#  'EPS8L2',
#  'ERBB3',
#  'ERCC6',
#  'ERP29',
#  'ETFB',
#  'ETV4',
#  'EXD1',
#  'EXOSC5',
#  'FABP1',
#  'FABP3',
#  'FADS3',
#  'FAF1',
#  'FAM103A1',
#  'FAM111A',
#  'FAM118B',
#  'FAM126A',
#  'FAM129C',
#  'FAM183A',
#  'FAM21C',
#  'FAM65C',
#  'FAM70B',
#  'FAM76A',
#  'FAM78A',
#  'FARSB',
#  'FCER2',
#  'FCRL2',
#  'FCRL5',
#  'FGF21',
#  'FGFR3',
#  'FGL1',
#  'FJX1',
#  'FLAD1',
#  'FLG',
#  'FLJ39582',
#  'FN1',
#  'FNBP1',
#  'FNIP1',
#  'FOXF1',
#  'FTCD',
#  'FTSJD1',
#  'FUT3',
#  'FUT5',
#  'FUT6',
#  'FXYD1',
#  'FXYD3',
#  'FYB',
#  'G6PC',
#  'G6PC3',
#  'GABPB1',
#  'GALK2',
#  'GALNS',
#  'GAPDH',
#  'GCFC1',
#  'GET4',
#  'GFI1',
#  'GGA1',
#  'GGTLC2',
#  'GLDC',
#  'GLTPD2',
#  'GLTSCR2',
#  'GLYR1',
#  'GNB1L',
#  'GNG11',
#  'GNPDA2',
#  'GNS',
#  'GOLGA5',
#  'GP1BB',
#  'GPN3',
#  'GPR114',
#  'GPR132',
#  'GPR153',
#  'GPR162',
#  'GPR180',
#  'GPR37',
#  'GPR87',
#  'GPRC5C',
#  'GPX2',
#  'GRAMD1A',
#  'GRAMD3',
#  'GRK4',
#  'GTF2A1',
#  'GTF2H1',
#  'HAMP',
#  'HAVCR2',
#  'HBP1',
#  'HCLS1',
#  'HDGFRP2',
#  'HECW2',
#  'HELQ',
#  'HEPACAM',
#  'HES4',
#  'HIGD2A',
#  'HINFP',
#  'HIRA',
#  'HLCS',
#  'HLF',
#  'HLTF',
#  'HMOX2',
#  'HMSD',
#  'HNF1A',
#  'HNRNPA1',
#  'HNRNPF',
#  'HNRNPR',
#  'HNRPA1L-2',
#  'HNRPDL',
#  'HOXA3',
#  'HOXA4',
#  'HOXA7',
#  'HOXA9',
#  'HOXC5',
#  'HOXC6',
#  'HP',
#  'HPD',
#  'HPN',
#  'HPS5',
#  'HRC',
#  'HSD11B1L',
#  'HSD17B2',
#  'HSF2BP',
#  'HSP90AB1',
#  'HSPA9',
#  'HSPB3',
#  'HSPB6',
#  'HSPBAP1',
#  'HYAL1',
#  'HYOU1',
#  'IARS',
#  'IGFBP1',
#  'IGSF1',
#  'IKZF3',
#  'IL12RB1',
#  'IL13RA2',
#  'IL1RN',
#  'IL2RG',
#  'IL4I1',
#  'IL7R',
#  'ILF3',
#  'IMMP2L',
#  'INPPL1',
#  'INSIG2',
#  'IP6K1',
#  'IPO13',
#  'IPO4',
#  'IQCG',
#  'IRF8',
#  'IRX4',
#  'ISM2',
#  'ITFG2',
#  'ITGA5',
#  'ITGAL',
#  'ITGB1BP1',
#  'ITIH2',
#  'ITPR1',
#  'IVL',
#  'JHDM1D',
#  'JUP',
#  'KAL1',
#  'KAT5',
#  'KCNH4',
#  'KDM3A',
#  'KHDRBS1',
#  'KIAA0090',
#  'KIAA0391',
#  'KIAA0415',
#  'KIAA0748',
#  'KIAA0930',
#  'KIAA1199',
#  'KIAA1407',
#  'KIAA1530',
#  'KIAA1737',
#  'KIAA1919',
#  'KIAA1984',
#  'KIF2A',
#  'KLF1',
#  'KLF11',
#  'KLF9',
#  'KLHL12',
#  'KLHL22',
#  'KLK8',
#  'KRT17',
#  'KRTDAP',
#  'LACTB2',
#  'LAMA4',
#  'LAMP1',
#  'LAT',
#  'LBH',
#  'LCN15',
#  'LEMD3',
#  'LGALS7',
#  'LGALS7B',
#  'LGR5',
#  'LIPC',
#  'LOC100130581',
#  'LOC100289341',
#  'LOC147727',
#  'LOC283922',
#  'LOC284023',
#  'LOC388796',
#  'LOC401242',
#  'LOC648691',
#  'LONP1',
#  'LOXL1',
#  'LRG1',
#  'LRPPRC',
#  'LRRC32',
#  'LRRC61',
#  'LSR',
#  'LY86',
#  'LYL1',
#  'LYPD6B',
#  'LYZ',
#  'LZTFL1',
#  'LZTR1',
#  'MAB21L1',
#  'MAGEA9',
#  'MAGEC2',
#  'MAMSTR',
#  'MAN1B1',
#  'MAN1C1',
#  'MAP1D',
#  'MAPK1',
#  'MARCH8',
#  'MBNL3',
#  'MCCC1',
#  'MCOLN1',
#  'MDN1',
#  'MEST',
#  'METTL1',
#  'METTL7B',
#  'METTL8',
#  'MFAP1',
#  'MFAP3L',
#  'MGA',
#  'MGST2',
#  'MLF1',
#  'MMD',
#  'MOGAT2',
#  'MOGAT3',
#  'MPP6',
#  'MRGPRF',
#  'MRPL40',
#  'MRPL45',
#  'MRPS18C',
#  'MRTO4',
#  'MSC',
#  'MSH5',
#  'MST1',
#  'MTHFD2',
#  'MTHFR',
#  'MTRNR2L4',
#  'MTTP',
#  'MYBPH',
#  'MYEOV',
#  'MYH14',
#  'MYL2',
#  'MYLPF',
#  'MYO16',
#  'MYO3B',
#  'MYO7A',
#  'MYOG',
#  'N6AMT1',
#  'NAPA',
#  'NAPSA',
#  'NAT10',
#  'NBPF1',
#  'NCAM1',
#  'NCL',
#  'NDRG2',
#  'NDUFA4',
#  'NEK3',
#  'NEK6',
#  'NFX1',
#  'NHLRC3',
#  'NKD1',
#  'NLE1',
#  'NME1',
#  'NME1-NME2',
#  'NMRAL1',
#  'NMU',
#  'NNMT',
#  'NOC3L',
#  'NOL7',
#  'NOL8',
#  'NOM1',
#  'NOP10',
#  'NOP14',
#  'NOP16',
#  'NOTUM',
#  'NPIP',
#  'NR0B2',
#  'NR1D1',
#  'NR1D2',
#  'NR5A1',
#  'NRBF2',
#  'NSUN5',
#  'NTF3',
#  'NUCB2',
#  'NUDT1',
#  'NUP205',
#  'NUP214',
#  'NUP62',
#  'ODC1',
#  'OPA1',
#  'OPTN',
#  'ORMDL3',
#  'OSGEP',
#  'P2RY8',
#  'PACRGL',
#  'PADI2',
#  'PAICS',
#  'PAK1IP1',
#  'PARVG',
#  'PCDHB5',
#  'PCYT1B',
#  'PDCD6IP',
#  'PDE12',
#  'PDE4D',
#  'PDGFRA',
#  'PDGFRB',
#  'PDIA4',
#  'PECR',
#  'PES1',
#  'PGK1',
#  'PHF19',
#  'PHF20',
#  'PI4KA',
#  'PIGZ',
#  'PIK3R3',
#  'PIK3R5',
#  'PIP5K1A',
#  'PLCG2',
#  'PLD3',
#  'PLD6',
#  'PLEKHA6',
#  'PNO1',
#  'PNPO',
#  'POLE4',
#  'POLR2E',
#  'POLR2J3',
#  'POLR3F',
#  'POSTN',
#  'PPA1',
#  'PPAN-P2RY11',
#  'PPAT',
#  'PPFIA4',
#  'PPIA',
#  'PPID',
#  'PPIL2',
#  'PPP2R3C',
#  'PPP2R5C',
#  'PRAME',
#  'PREPL',
#  'PRMT1',
#  'PRODH2',
#  'PRR15L',
#  'PSG5',
#  'PSMD9',
#  'PSME3',
#  'PTBP1',
#  'PTGIR',
#  'PTGS1',
#  'PTP4A2',
#  'PTPN7',
#  'PUS7',
#  'QKI',
#  'QSOX1',
#  'QTRT1',
#  'QTRTD1',
#  'RAB17',
#  'RAB34',
#  'RAB36',
#  'RAB3IL1',
#  'RAB42',
#  'RAB42P1',
#  'RAD23A',
#  'RAD9A',
#  'RAD9B',
#  'RAET1E',
#  'RAI14',
#  'RAMP2',
#  'RANBP1',
#  'RAPGEF1',
#  'RASAL3',
#  'RASGRP1',
#  'RBBP4',
#  'RBBP5',
#  'RBM15',
#  'RBP4',
#  'RBPJ',
#  'RCCD1',
#  'REPIN1',
#  'RFC1',
#  'RFTN1',
#  'RGS1',
#  'RGS13',
#  'RGS16',
#  'RHBDL1',
#  'RHBG',
#  'RIBC2',
#  'RIOK2',
#  'RMND1',
#  'RMRP',
#  'RNASE1',
#  'RNASE4',
#  'RNASEH2A',
#  'RNASET2',
#  'RNF130',
#  'RNF166',
#  'RNF32',
#  'RNFT2',
#  'RNMT',
#  'ROCK1P1',
#  'RP11-1212A22.4',
#  'RP11-35N6.1',
#  'RP11-383H13.1',
#  'RPA2',
#  'RPL10A',
#  'RPL12',
#  'RPL13A',
#  'RPL14',
#  'RPL21',
#  'RPL21P28',
#  'RPL23A',
#  'RPL32',
#  'RPL35A',
#  'RPS12',
#  'RPS8',
#  'RPSA',
#  'RPUSD4',
#  'RRAGD',
#  'RRAS2',
#  'RRP1',
#  'RRP1B',
#  'S100PBP',
#  'SAE1',
#  'SAMSN1',
#  'SBSN',
#  'SCAMP3',
#  'SCAND3',
#  'SCARNA2',
#  'SCFD2',
#  'SCN5A',
#  'SDF2L1',
#  'SDR42E1',
#  'SEC1',
#  'SEC61B',
#  'SELL',
#  'SEPHS2',
#  'SEPP1',
#  'SERF2',
#  'SERPINB10',
#  'SERPINC1',
#  'SERPINE2',
#  'SERPINF1',
#  'SERPINF2',
#  'SETD6',
#  'SFRP1',
#  'SFRS13A',
#  'SFRS18',
#  'SFRS2IP',
#  'SFRS7',
#  'SGCD',
#  'SGK1',
#  'SGOL1',
#  'SGPL1',
#  'SGPP2',
#  'SGTA',
#  'SHC1',
#  'SHD',
#  'SHISA9',
#  'SIRPB1',
#  'SIRT1',
#  'SKAP1',
#  'SLC13A3',
#  'SLC13A5',
#  'SLC16A1',
#  'SLC17A9',
#  'SLC25A1',
#  'SLC2A5',
#  'SLC35A4',
#  'SLC35A5',
#  'SLC39A5',
#  'SLC3A2',
#  'SLC40A1',
#  'SLC7A5P1',
#  'SLC7A5P2',
#  'SLCO4A1',
#  'SMC1B',
#  'SNAP29',
#  'SNHG1',
#  'SNHG7',
#  'SNORA76',
#  'SNORD104',
#  'SNORD55',
#  'SNRPA',
#  'SNX20',
#  'SNX5',
#  'SOAT2',
#  'SOCS5',
#  'SORL1',
#  'SP5',
#  'SPN',
#  'SPNS1',
#  'SPON2',
#  'SPOP',
#  'SPRYD4',
#  'SRP19',
#  'ST8SIA2',
#  'STAM',
#  'STAR',
#  'STAT5A',
#  'STK25',
#  'STMN1',
#  'SUB1',
#  'SULT1A1',
#  'SULT1A2',
#  'SULT1A3',
#  'SULT1A4',
#  'SULT2A1',
#  'SUMF1',
#  'SUPV3L1',
#  'TAF12',
#  'TAF4B',
#  'TAGLN',
#  'TAOK2',
#  'TASP1',
#  'TBC1D15',
#  'TBC1D16',
#  'TBC1D17',
#  'TBCB',
#  'TBX2',
#  'TBX4',
#  'TCERG1',
#  'TDG',
#  'TESC',
#  'TFEB',
#  'THADA',
#  'THAP5',
#  'THAP7',
#  'THAP8',
#  'THBS1',
#  'THNSL1',
#  'TIMM13',
#  'TINAGL1',
#  'TLCD1',
#  'TLK1',
#  'TM4SF5',
#  'TM9SF4',
#  'TMC8',
#  'TMED1',
#  'TMEM116',
#  'TMEM146',
#  'TMEM194A',
#  'TMEM233',
#  'TMEM37',
#  'TMEM40',
#  'TMEM42',
#  'TMEM48',
#  'TMEM55B',
#  'TNFRSF1A',
#  'TNFRSF9',
#  'TNNI3',
#  'TNPO2',
#  'TNS3',
#  'TOR1A',
#  'TPM1',
#  'TRA2A',
#  'TRAPPC2L',
#  'TRIM50',
#  'TRIM55',
#  'TRIM59',
#  'TRIM61',
#  'TRIM73',
#  'TRMT2A',
#  'TRUB2',
#  'TSN',
#  'TSNAX',
#  'TSNAX-DISC1',
#  'TTC37',
#  'TTC39B',
#  'TTR',
#  'TUBB1',
#  'TUBGCP2',
#  'TXNRD1',
#  'TXNRD2',
#  'TYROBP',
#  'UBA52',
#  'UBAC1',
#  'UBAP2',
#  'UBAP2L',
#  'UBASH3A',
#  'UBE2B',
#  'UBE2G2',
#  'UBE2Q1',
#  'UBE2S',
#  'UBXN11',
#  'URB2',
#  'USP14',
#  'USP20',
#  'USP36',
#  'UTP11L',
#  'VARS',
#  'VIM',
#  'VPS29',
#  'VSNL1',
#  'WDR36',
#  'WDR4',
#  'WDR62',
#  'WDR65',
#  'WDR74',
#  'WDR81',
#  'WDR89',
#  'WDR90',
#  'WDR92',
#  'WFDC1',
#  'WNT7A',
#  'XIRP1',
#  'XKR9',
#  'YBX1',
#  'YDJC',
#  'YPEL1',
#  'ZBTB40',
#  'ZC3H10',
#  'ZCCHC7',
#  'ZCWPW1',
#  'ZFR',
#  'ZFYVE27',
#  'ZIK1',
#  'ZIM2',
#  'ZKSCAN2',
#  'ZMYND8',
#  'ZNF239',
#  'ZNF280A',
#  'ZNF280D',
#  'ZNF292',
#  'ZNF3',
#  'ZNF628',
#  'ZNF692',
#  'ZNF74',
#  'ZNF785',
#  'ZNF84',
#  'hsa-miR-17*',
#  'hsa-miR-18a*',
#  'hsa-miR-19a*',
#  'hsa-miR-19b',
#  'hsa-miR-19b-1*',
#  'hsa-miR-20a*',
#  'hsa-miR-663b',
#  'hsa-miR-92a-1*'}

# %%
len(set(net["SRF"]))
# Out:
# 12

# %%
len(net.out_edges("SRF"))
# Out:
# 12

# %%
len(set.union(*readout_direct_targets.values()))
# Out:
# 13389

# %%
filename=file[file.index("list")+5:file.index(".csv")]

# %%
write_nodes_file("all_gene",filename,G)

# %%
len(net.nodes())
# Out:
# 215

# %%
## Get R dictionaries
## GO term -> set ids
GO_id_map=get_r_dictionaries("test.txt",mapping=False)
#print(GO_id_map)

## id to ENTREZ id
edgeid_ezid_map=get_r_dictionaries("mapping_id_to_entrez.txt")
print(edgeid_ezid_map)
# Out:
# {'5669': 'SP1', '6667': 'SP1', '199699': 'SP1', '6668': 'SP2', '2623': 'GATA1', '672': 'BRCA1', '3172': 'HNF4A', '1876': 'E2F6', '406920': 'hsa-miR-130b', '4208': 'MEF2C', '140690': 'CTCFL', '5452': 'POU2F2', '406982': 'hsa-miR-20a', '406953': 'hsa-miR-18a', '7702': 'ZNF143', '23462': 'HEY1', '6721': 'SREBF2', '25942': 'SIN3A', '2355': 'FOSL2', '53335': 'BCL11A', '7182': 'NR2C2', '147912': 'SIX5', '4149': 'MAX', '4601': 'MXI1', '10891': 'PPARGC1A', '4801': 'NFYB', '1958': 'EGR1', '1051': 'CEBPB', '5993': 'RFX5', '6688': 'SPI1', '9774': 'BCLAF1', '6938': 'TCF12', '639': 'PRDM1', '3066': 'HDAC2', '6256': 'RXRA', '4779': 'NRF1', '4899': 'NRF1', '6886': 'TAL1', '6925': 'TCF4', '6934': 'TCF4', '2099': 'ESR1', '905': 'CCNT2', '10664': 'CTCF', '5090': 'PBX3', '11128': 'POLR3A', '10009': 'ZBTB33', '3659': 'IRF1', '2033': 'EP300', '2113': 'ETS1', '2908': 'NR3C1', '51341': 'ZBTB7A', '1869': 'E2F1', '6722': 'SRF', '3661': 'IRF3', '2353': 'FOS', '8061': 'FOSL1', '3726': 'JUNB', '10535': 'JUNB', '6599': 'SMARCC1', '1879': 'EBF1', '4800': 'NFYA', '1106': 'CHD2', '1826': 'CHD2', '6908': 'TBP', '2551': 'GABPA', '1488': 'CTBP2', '3727': 'JUND', '6597': 'SMARCA4', '3662': 'IRF4', '3174': 'HNF4G', '3169': 'FOXA1', '4778': 'NFE2', '7936': 'RDBP', '6773': 'STAT2', '2005': 'ELK4', '406903': 'hsa-miR-10b', '26469': 'BDP1', '55814': 'BDP1', '7392': 'USF2', '23512': 'SUZ12', '678': 'BRF2', '55290': 'BRF2', '7391': 'USF1', '1874': 'E2F4', '6935': 'ZEB1', '4205': 'MEF2A', '602': 'BCL3', '574455': 'hsa-miR-193b', '8553': 'BHLHE40', '7022': 'TFAP2C', '10538': 'BATF', '2624': 'GATA2', '10155': 'TRIM28', '4790': 'NFKB1', '442904': 'hsa-miR-335', '5460': 'POU5F1', '51548': 'SIRT6', '100302232': 'hsa-miR-1226', '100302201': 'hsa-miR-1228', '7020': 'TFAP2A', '2959': 'GTF2B', '4609': 'MYC', '5820': 'MYC', '5079': 'PAX5', '3725': 'JUN', '3170': 'FOXA2', '7975': 'MAFK', '7528': 'YY1', '467': 'ATF3', '406998': 'hsa-miR-216a', '100126319': 'hsa-miR-216b', '407029': 'hsa-miR-30a', '406936': 'hsa-miR-144', '406999': 'hsa-miR-217', '6601': 'SMARCC2', '100126348': 'hsa-miR-760', '6772': 'STAT1', '406942': 'hsa-miR-150', '442900': 'hsa-miR-326', '406884': 'hsa-let-7b', '494324': 'hsa-miR-375', '406919': 'hsa-miR-130a', '442895': 'hsa-miR-302c', '407028': 'hsa-miR-302a', '100302143': 'hsa-miR-1248', '693158': 'hsa-miR-573', '406947': 'hsa-miR-155', '406921': 'hsa-miR-132', '693174': 'hsa-miR-589', '5885': 'RAD21', '23764': 'MAFF', '6720': 'SREBF1', '3297': 'HSF1', '6774': 'STAT3', '6879': 'TAF7', '10127': 'ZNF263', '56897': 'WRNIP1', '406985': 'hsa-miR-200c', '407011': 'hsa-miR-23b', '406994': 'hsa-miR-212', '1997': 'ELF1', '84337': 'ELF1', '9126': 'SMC3', '768218': 'hsa-miR-766', '574456': 'hsa-miR-497', '442891': 'hsa-miR-135b', '619553': 'hsa-miR-484', '6598': 'SMARCB1', '406902': 'hsa-miR-10a', '100126340': 'hsa-miR-944'}

# %%
## Primero: Hay que cambiarle el id del res al id de ENTREZ
## hay que hacer un mapping dictionary con la info que tenemos de los nodos de GO.term
##Como no todos están anotados es mejor crear un diccionario 
mapping_relabel = edgeid_ezid_map
for node in net.nodes():
    if node not in edgeid_ezid_map.values():
        mapping_relabel[node]=node
mapping_relabel
# Out:
# {'10009': 'ZBTB33',
#  '100126319': 'hsa-miR-216b',
#  '100126340': 'hsa-miR-944',
#  '100126348': 'hsa-miR-760',
#  '100302143': 'hsa-miR-1248',
#  '100302201': 'hsa-miR-1228',
#  '100302232': 'hsa-miR-1226',
#  '10127': 'ZNF263',
#  '10155': 'TRIM28',
#  '1051': 'CEBPB',
#  '10535': 'JUNB',
#  '10538': 'BATF',
#  '10664': 'CTCF',
#  '10891': 'PPARGC1A',
#  '1106': 'CHD2',
#  '11128': 'POLR3A',
#  '140690': 'CTCFL',
#  '147912': 'SIX5',
#  '1488': 'CTBP2',
#  '1826': 'CHD2',
#  '1869': 'E2F1',
#  '1874': 'E2F4',
#  '1876': 'E2F6',
#  '1879': 'EBF1',
#  '1958': 'EGR1',
#  '199699': 'SP1',
#  '1997': 'ELF1',
#  '2005': 'ELK4',
#  '2033': 'EP300',
#  '2099': 'ESR1',
#  '2113': 'ETS1',
#  '23462': 'HEY1',
#  '23512': 'SUZ12',
#  '2353': 'FOS',
#  '2355': 'FOSL2',
#  '23764': 'MAFF',
#  '2551': 'GABPA',
#  '25942': 'SIN3A',
#  '2623': 'GATA1',
#  '2624': 'GATA2',
#  '26469': 'BDP1',
#  '2908': 'NR3C1',
#  '2959': 'GTF2B',
#  '3066': 'HDAC2',
#  '3169': 'FOXA1',
#  '3170': 'FOXA2',
#  '3172': 'HNF4A',
#  '3174': 'HNF4G',
#  '3297': 'HSF1',
#  '3659': 'IRF1',
#  '3661': 'IRF3',
#  '3662': 'IRF4',
#  '3725': 'JUN',
#  '3726': 'JUNB',
#  '3727': 'JUND',
#  '406884': 'hsa-let-7b',
#  '406902': 'hsa-miR-10a',
#  '406903': 'hsa-miR-10b',
#  '406919': 'hsa-miR-130a',
#  '406920': 'hsa-miR-130b',
#  '406921': 'hsa-miR-132',
#  '406936': 'hsa-miR-144',
#  '406942': 'hsa-miR-150',
#  '406947': 'hsa-miR-155',
#  '406953': 'hsa-miR-18a',
#  '406982': 'hsa-miR-20a',
#  '406985': 'hsa-miR-200c',
#  '406994': 'hsa-miR-212',
#  '406998': 'hsa-miR-216a',
#  '406999': 'hsa-miR-217',
#  '407011': 'hsa-miR-23b',
#  '407028': 'hsa-miR-302a',
#  '407029': 'hsa-miR-30a',
#  '4149': 'MAX',
#  '4205': 'MEF2A',
#  '4208': 'MEF2C',
#  '442891': 'hsa-miR-135b',
#  '442895': 'hsa-miR-302c',
#  '442900': 'hsa-miR-326',
#  '442904': 'hsa-miR-335',
#  '4601': 'MXI1',
#  '4609': 'MYC',
#  '467': 'ATF3',
#  '4778': 'NFE2',
#  '4779': 'NRF1',
#  '4790': 'NFKB1',
#  '4800': 'NFYA',
#  '4801': 'NFYB',
#  '4899': 'NRF1',
#  '494324': 'hsa-miR-375',
#  '5079': 'PAX5',
#  '5090': 'PBX3',
#  '51341': 'ZBTB7A',
#  '51548': 'SIRT6',
#  '53335': 'BCL11A',
#  '5452': 'POU2F2',
#  '5460': 'POU5F1',
#  '55290': 'BRF2',
#  '55814': 'BDP1',
#  '5669': 'SP1',
#  '56897': 'WRNIP1',
#  '574455': 'hsa-miR-193b',
#  '574456': 'hsa-miR-497',
#  '5820': 'MYC',
#  '5885': 'RAD21',
#  '5993': 'RFX5',
#  '602': 'BCL3',
#  '619553': 'hsa-miR-484',
#  '6256': 'RXRA',
#  '639': 'PRDM1',
#  '6597': 'SMARCA4',
#  '6598': 'SMARCB1',
#  '6599': 'SMARCC1',
#  '6601': 'SMARCC2',
#  '6667': 'SP1',
#  '6668': 'SP2',
#  '6688': 'SPI1',
#  '672': 'BRCA1',
#  '6720': 'SREBF1',
#  '6721': 'SREBF2',
#  '6722': 'SRF',
#  '6772': 'STAT1',
#  '6773': 'STAT2',
#  '6774': 'STAT3',
#  '678': 'BRF2',
#  '6879': 'TAF7',
#  '6886': 'TAL1',
#  '6908': 'TBP',
#  '6925': 'TCF4',
#  '693158': 'hsa-miR-573',
#  '693174': 'hsa-miR-589',
#  '6934': 'TCF4',
#  '6935': 'ZEB1',
#  '6938': 'TCF12',
#  '7020': 'TFAP2A',
#  '7022': 'TFAP2C',
#  '7182': 'NR2C2',
#  '7391': 'USF1',
#  '7392': 'USF2',
#  '7528': 'YY1',
#  '768218': 'hsa-miR-766',
#  '7702': 'ZNF143',
#  '7936': 'RDBP',
#  '7975': 'MAFK',
#  '8061': 'FOSL1',
#  '84337': 'ELF1',
#  '8553': 'BHLHE40',
#  '905': 'CCNT2',
#  '9126': 'SMC3',
#  '9774': 'BCLAF1',
#  'ABCA3': 'ABCA3',
#  'ACAD9': 'ACAD9',
#  'ALDH1A1': 'ALDH1A1',
#  'BRD9': 'BRD9',
#  'C20orf111': 'C20orf111',
#  'STYXL1': 'STYXL1',
#  'TMEM14C': 'TMEM14C',
#  'ZNF775': 'ZNF775',
#  'hsa-let-7a': 'hsa-let-7a',
#  'hsa-miR-1': 'hsa-miR-1',
#  'hsa-miR-101': 'hsa-miR-101',
#  'hsa-miR-1205': 'hsa-miR-1205',
#  'hsa-miR-1207-3p': 'hsa-miR-1207-3p',
#  'hsa-miR-1207-5p': 'hsa-miR-1207-5p',
#  'hsa-miR-1208': 'hsa-miR-1208',
#  'hsa-miR-124': 'hsa-miR-124',
#  'hsa-miR-1245': 'hsa-miR-1245',
#  'hsa-miR-125a-3p': 'hsa-miR-125a-3p',
#  'hsa-miR-125a-5p': 'hsa-miR-125a-5p',
#  'hsa-miR-1260': 'hsa-miR-1260',
#  'hsa-miR-1279': 'hsa-miR-1279',
#  'hsa-miR-128': 'hsa-miR-128',
#  'hsa-miR-129-3p': 'hsa-miR-129-3p',
#  'hsa-miR-129-5p': 'hsa-miR-129-5p',
#  'hsa-miR-133a': 'hsa-miR-133a',
#  'hsa-miR-135a': 'hsa-miR-135a',
#  'hsa-miR-142-3p': 'hsa-miR-142-3p',
#  'hsa-miR-142-5p': 'hsa-miR-142-5p',
#  'hsa-miR-145': 'hsa-miR-145',
#  'hsa-miR-153': 'hsa-miR-153',
#  'hsa-miR-17': 'hsa-miR-17',
#  'hsa-miR-185': 'hsa-miR-185',
#  'hsa-miR-191': 'hsa-miR-191',
#  'hsa-miR-192': 'hsa-miR-192',
#  'hsa-miR-193a-3p': 'hsa-miR-193a-3p',
#  'hsa-miR-194': 'hsa-miR-194',
#  'hsa-miR-196a': 'hsa-miR-196a',
#  'hsa-miR-199b-5p': 'hsa-miR-199b-5p',
#  'hsa-miR-19a': 'hsa-miR-19a',
#  'hsa-miR-219-5p': 'hsa-miR-219-5p',
#  'hsa-miR-22': 'hsa-miR-22',
#  'hsa-miR-24': 'hsa-miR-24',
#  'hsa-miR-25': 'hsa-miR-25',
#  'hsa-miR-27b': 'hsa-miR-27b',
#  'hsa-miR-29b': 'hsa-miR-29b',
#  'hsa-miR-300': 'hsa-miR-300',
#  'hsa-miR-330-3p': 'hsa-miR-330-3p',
#  'hsa-miR-338-3p': 'hsa-miR-338-3p',
#  'hsa-miR-338-5p': 'hsa-miR-338-5p',
#  'hsa-miR-339-5p': 'hsa-miR-339-5p',
#  'hsa-miR-365': 'hsa-miR-365',
#  'hsa-miR-367': 'hsa-miR-367',
#  'hsa-miR-376a': 'hsa-miR-376a',
#  'hsa-miR-483-3p': 'hsa-miR-483-3p',
#  'hsa-miR-548c-3p': 'hsa-miR-548c-3p',
#  'hsa-miR-549': 'hsa-miR-549',
#  'hsa-miR-564': 'hsa-miR-564',
#  'hsa-miR-567': 'hsa-miR-567',
#  'hsa-miR-595': 'hsa-miR-595',
#  'hsa-miR-612': 'hsa-miR-612',
#  'hsa-miR-615-5p': 'hsa-miR-615-5p',
#  'hsa-miR-626': 'hsa-miR-626',
#  'hsa-miR-632': 'hsa-miR-632',
#  'hsa-miR-636': 'hsa-miR-636',
#  'hsa-miR-638': 'hsa-miR-638',
#  'hsa-miR-645': 'hsa-miR-645',
#  'hsa-miR-648': 'hsa-miR-648',
#  'hsa-miR-650': 'hsa-miR-650',
#  'hsa-miR-657': 'hsa-miR-657',
#  'hsa-miR-661': 'hsa-miR-661',
#  'hsa-miR-663': 'hsa-miR-663',
#  'hsa-miR-7': 'hsa-miR-7',
#  'hsa-miR-9': 'hsa-miR-9',
#  'hsa-miR-92a': 'hsa-miR-92a',
#  'hsa-miR-93': 'hsa-miR-93'}

# %%
for key,values in GO_id_map.items():
    GO_id_map[key]=set([mapping_relabel[value] for value in values])
GO_id_map
# Out:
# {'GO:0006337': {'NFE2', 'SMARCA4', 'SMARCB1', 'SMARCC1', 'SMARCC2'},
#  'GO:0030220': {'EP300', 'GATA1', 'MEF2C', 'SRF', 'TAL1'},
#  'GO:0043923': {'EP300', 'JUN', 'SMARCA4', 'SMARCB1', 'SP1'},
#  'GO:1901984': {'BRCA1', 'HDAC2', 'SIN3A', 'SPI1', 'TAF7'}}

# %%
set.union(*GO_id_map.values())
# Out:
# {'BRCA1',
#  'E2F1',
#  'E2F6',
#  'FOS',
#  'FOSL1',
#  'JUN',
#  'JUNB',
#  'JUND',
#  'MAX',
#  'SREBF1',
#  'STAT1',
#  'SUZ12'}

# %%
readout_common=set(gene for gene_res in set.union(*GO_id_map.values()) for gene in set(G[gene_res]) if gene in set.union(*readout_direct_targets.values()) )

# %%
readout_common
# Out:
# {'TRAPPC2',
#  'LONP1',
#  'NCOA4',
#  'YDJC',
#  'HDAC7',
#  'hsa-miR-302b*',
#  'SMC1B',
#  'CSNK1D',
#  'TTC37',
#  'FAM158A',
#  'CDK1',
#  'MAF1',
#  'LRRC61',
#  'hsa-miR-130b*',
#  'METTL7B',
#  'RRAS2',
#  'ATL3',
#  'VSX2',
#  'NUP155',
#  'NPM1',
#  'NOP56',
#  'RUNDC2C',
#  'SNORD32A',
#  'POLR2E',
#  'YPEL4',
#  'DARS',
#  'FAM46B',
#  'ST8SIA2',
#  'LBX2',
#  'HIGD2A',
#  'PIGZ',
#  'LOX',
#  'ADORA1',
#  'KIAA1984',
#  'GXYLT1',
#  'HAND1',
#  'QRICH1',
#  'C7orf40',
#  'RPS12',
#  'RND1',
#  'AMDHD2',
#  'CTGF',
#  'RAB11B',
#  'SERPINC1',
#  'CORO1C',
#  'GAS2L3',
#  'CLIC2',
#  'ORMDL2',
#  'NDRG2',
#  'LRG1',
#  'PCSK5',
#  'DCTN5',
#  'SDF4',
#  'ITGA5',
#  'LPAR6',
#  'KIAA0195',
#  'CHAF1A',
#  'hsa-miR-302b',
#  'SLC7A5P2',
#  'SPRYD4',
#  'C2orf18',
#  'SDPR',
#  'SFT2D2',
#  'NR1H2',
#  'WNT7B',
#  'FBXO18',
#  'ETV5',
#  'ATP6V0D1',
#  'C6orf211',
#  'MT1A',
#  'EVL',
#  'C21orf63',
#  'TTR',
#  'IKZF3',
#  'ALPK1',
#  'GCFC1',
#  'UBE2S',
#  'WDR25',
#  'C1QTNF6',
#  'ELOVL2',
#  'CDC20',
#  'C6orf108',
#  'TEX14',
#  'DMRT3',
#  'IRX5',
#  'FAHD2B',
#  'CNDP2',
#  'EPO',
#  'ALOX15B',
#  'TLR6',
#  'ARL14',
#  'SPATS2',
#  'SIAH2',
#  'HIST1H2BI',
#  'GCHFR',
#  'MED16',
#  'CAPS2',
#  'MRTO4',
#  'CLTB',
#  'FLOT1',
#  'EMX2',
#  'MUTYH',
#  'SERPINB2',
#  'RAP1A',
#  'RALGAPA1',
#  'PSAP',
#  'RAC1',
#  'PRMT8',
#  'TUBB2C',
#  'SULT1A4',
#  'CRLF1',
#  'USP53',
#  'CBX3',
#  'COQ9',
#  'CDS2',
#  'BPGM',
#  'CCNK',
#  'YAP1',
#  'BCL10',
#  'ADAMTS16',
#  'CEACAM6',
#  'AZGP1',
#  'GLTPD2',
#  'RBCK1',
#  'ATP6V1G1',
#  'BCL2L13',
#  'BCKDHA',
#  'GNS',
#  'NADK',
#  'NOL10',
#  'SNX16',
#  'ATG5',
#  'MAN1B1',
#  'CCDC86',
#  'PTPN14',
#  'PAK1IP1',
#  'WASL',
#  'hsa-miR-155*',
#  'SELV',
#  'FANCL',
#  'TMEM161A',
#  'PAX9',
#  'TIPRL',
#  'PSMA6',
#  'HMX1',
#  'CREB3L2',
#  'OSGEP',
#  'ESF1',
#  'HIST1H4D',
#  'AKR1C1',
#  'ANAPC7',
#  'B3GALT6',
#  'SULT2B1',
#  'hsa-miR-20a*',
#  'USP1',
#  'SELL',
#  'RAB42P1',
#  'METTL2B',
#  'AIFM2',
#  'RAB36',
#  'MOGAT3',
#  'SRL',
#  'PCNAAS',
#  'LOC285548',
#  'BAT4',
#  'AKR1A1',
#  'ADSS',
#  'DCLRE1B',
#  'KLK6',
#  'TSNAX-DISC1',
#  'TINF2',
#  'JHDM1D',
#  'C8orf22',
#  'CLCN7',
#  'UBE2G2',
#  'RBM18',
#  'CC2D1B',
#  'HSH2D',
#  'SLC25A1',
#  'KLK7',
#  'CLTC',
#  'PRMT3',
#  'EIF4E',
#  'TRIM73',
#  'GNAZ',
#  'COL6A1',
#  'PXK',
#  'GOLGA5',
#  'LMNB1',
#  'ASH2L',
#  'TMEM126B',
#  'KRT6A',
#  'SNORD114-20',
#  'MCM3APAS',
#  'HIST1H4A',
#  'NKX3-2',
#  'ERGIC2',
#  'C13orf31',
#  'FTL',
#  'SIX2',
#  'AP2B1',
#  'CEACAM5',
#  'DHX40',
#  'ENC1',
#  'FOXB2',
#  'HECTD2',
#  'CNOT3',
#  'DONSON',
#  'KHSRP',
#  'DYM',
#  'TNPO2',
#  'ZSWIM4',
#  'ICAM1',
#  'CYSLTR1',
#  'RTEL1',
#  'MTR',
#  'ACTC1',
#  'PUF60',
#  'TMEM59L',
#  'MCFD2',
#  'COMMD8',
#  'NCRNA00111',
#  'HOXC8',
#  'PRODH2',
#  'IPP',
#  'LMNA',
#  'GPATCH3',
#  'ZCCHC7',
#  'AP1G2',
#  'HIPK3',
#  'LOC285627',
#  'CALML5',
#  'RAN',
#  'ODC1',
#  'TAB3',
#  'ZNF587',
#  'WDR53',
#  'PMVK',
#  'MGC23284',
#  'C10orf119',
#  'C17orf82',
#  'FBXO45',
#  'MZT1',
#  'ALCAM',
#  'ZNF84',
#  'FANCA',
#  'NUBP2',
#  'CHL1',
#  'TPCN1',
#  'AGT',
#  'SHMT2',
#  'P2RY11',
#  'DOM3Z',
#  'FAF1',
#  'TRIO',
#  'MYO1B',
#  'CKLF',
#  'C22orf29',
#  'LOC100128977',
#  'MT1G',
#  'CDK12',
#  'LOC283731',
#  'PRKDC',
#  'DDX31',
#  'PIK3R3',
#  'TRIM44',
#  'FOXK1',
#  'GP1BB',
#  'KIAA0391',
#  'MAFB',
#  'GPBP1',
#  'AHI1',
#  'LENG1',
#  'TPM4',
#  'DPAGT1',
#  'CCRN4L',
#  'LZTFL1',
#  'ENSA',
#  'PARP4',
#  'RFC1',
#  'GAGE4',
#  'RNU86',
#  'CSTF2T',
#  'GPR183',
#  'TBX3',
#  'WHSC1',
#  'HIST4H4',
#  'C10orf25',
#  'ZNF718',
#  'KIAA0020',
#  'FARSB',
#  'LOC100132215',
#  'TBCB',
#  'RAD9A',
#  'TLR1',
#  'PPM1K',
#  'BEST3',
#  'PHTF2',
#  'GABPB1',
#  'BAGE2',
#  'TLR7',
#  'SF1',
#  'C19orf23',
#  'PPP1R15A',
#  'RNF168',
#  'DKFZP686I15217',
#  'HIST3H2A',
#  'PSMB9',
#  'HEXA',
#  'TMEM48',
#  'CCDC126',
#  'DNM2',
#  'BRIX1',
#  'STAM',
#  'CAMTA1',
#  'C11orf68',
#  'POLR1C',
#  'C6orf89',
#  'NR5A1',
#  'RP4-695O20__B.10',
#  'FLG',
#  'CTTNBP2NL',
#  'ACSS2',
#  'DLX6AS',
#  'OTX1',
#  'SUMF1',
#  'HIST1H3E',
#  'CD37',
#  'FAM111B',
#  'KIAA1737',
#  'RBM15',
#  'TFEB',
#  'CCDC123',
#  'XIRP1',
#  'MAP3K14',
#  'hsa-miR-541',
#  'C2CD4B',
#  'ABLIM3',
#  'C1orf43',
#  'HAUS5',
#  'TOR1A',
#  'THNSL1',
#  'C3orf37',
#  'SLC37A4',
#  'ABCB4',
#  'LDLR',
#  'FKBP9',
#  'SUPT4H1',
#  'SIX3',
#  'SEPT5',
#  'INO80C',
#  'C15orf34',
#  'HCFC1R1',
#  'FAM177A1',
#  'RAD9B',
#  'HSD17B12',
#  'UNCX',
#  'MALAT1',
#  'ZNF620',
#  'SLC25A40',
#  'SCYL3',
#  'RNF167',
#  'BPIL1',
#  'LHX6',
#  'CACNA2D4',
#  'LIMS2',
#  'C6orf27',
#  'LOC648691',
#  'TNPO1',
#  'NR2E1',
#  'LBH',
#  'ABCA11P',
#  'TAF1D',
#  'TGM1',
#  'SGK1',
#  'TPRA1',
#  'hsa-miR-19a*',
#  'POLA1',
#  'AIFM3',
#  'PRDX1',
#  'TROVE2',
#  'ACTR1B',
#  'LOC654342',
#  'RSRC1',
#  'HSD17B2',
#  'hsa-miR-1288',
#  'PKP3',
#  'GLYCTK',
#  'BIRC2',
#  'SH2B3',
#  'BAGE',
#  'ITPKA',
#  'IL8',
#  'C11orf54',
#  'NPTN',
#  'TATDN2',
#  'PRDM12',
#  'PCDHB5',
#  'SLC39A7',
#  'C3',
#  'XKR9',
#  'KLHL12',
#  'LOC399959',
#  'MBIP',
#  'HIST2H2AC',
#  'MAGEA12',
#  'LAT',
#  'CAMK2N2',
#  'FLJ35776',
#  'C16orf5',
#  'GP1BA',
#  'ARFGAP3',
#  'AGPAT1',
#  'HIF1A',
#  'UBAC1',
#  'GOLT1B',
#  'hsa-miR-1908',
#  'ERBB3',
#  'CCL14',
#  'ITGB5',
#  'CCNC',
#  'SLCO4A1',
#  'TXNRD2',
#  'SULT1A2',
#  'SLC16A14',
#  'DNAJB9',
#  'RHOXF2',
#  'SPSB3',
#  'UBXN4',
#  'EGR3',
#  'TM9SF1',
#  'AC011472.1',
#  'PMS2',
#  'EPB41L2',
#  'HLTF',
#  'C1orf110',
#  'PASD1',
#  'RNMT',
#  'BARX1',
#  'SRD5A3',
#  'YTHDF1',
#  'ANKH',
#  'FABP1',
#  'HOXC12',
#  'RNF32',
#  'GALNT2',
#  'RPL21P28',
#  'SNORA76',
#  'FOXB1',
#  'RPPH1',
#  'HIST1H2AC',
#  'RASA2',
#  'SBSN',
#  'STX5',
#  'TFPI',
#  'RAET1E',
#  'CCL3',
#  'SFRS12',
#  'TSN',
#  'DNAH14',
#  'hsa-miR-92b',
#  'NUDT1',
#  'HNRNPAB',
#  'ANO3',
#  'ZSWIM6',
#  'TRA2A',
#  'C11orf10',
#  'POLE4',
#  'NCBP1',
#  'CCNE2',
#  'FOXL1',
#  'SGCD',
#  'C1orf212',
#  'FGL1',
#  'NAIF1',
#  'TXNDC5',
#  'MBTPS1',
#  'GPR153',
#  'KCNK1',
#  'KIAA0090',
#  'RPA2',
#  'ADCYAP1',
#  'TFF3',
#  'TBCA',
#  'GNPDA2',
#  'DOCK10',
#  'SYT15',
#  'AFP',
#  'ESYT2',
#  'FCRL2',
#  'SNORD114-22',
#  'ARVCF',
#  'TERC',
#  'CENPF',
#  'AFAP1L2',
#  'HMGCS1',
#  'ZNF595',
#  'POR',
#  'TNNI3',
#  'GPR109A',
#  'CCT8',
#  'MCM4',
#  'NOM1',
#  'SCAMP1',
#  'PLEKHA6',
#  'RPUSD4',
#  'IPO7',
#  'AC136618.1',
#  'LHX5',
#  'JUP',
#  'CREB5',
#  'ESRRG',
#  'CCDC122',
#  'GET4',
#  'COPS7A',
#  'PSME3',
#  'PDS5A',
#  'HMGA1',
#  'TRNP1',
#  'FOXK2',
#  'TPM3',
#  'MT1M',
#  'XG',
#  'CCNT1',
#  'PDIK1L',
#  'TNFRSF1B',
#  'PAK1',
#  'ZC4H2',
#  'DNA2',
#  'EMX2OS',
#  'CARS',
#  'PSMD7',
#  'ATXN7L2',
#  'IL20RB',
#  'PCM1',
#  'NBLA00301',
#  'NOLC1',
#  'SLC17A9',
#  'IRF2BP2',
#  'LYPD6B',
#  'HMOX2',
#  'FAM108C1',
#  'AFTPH',
#  'ZNF774',
#  'EHD1',
#  'LYRM1',
#  'CD83',
#  'HERC5',
#  'MYO3B',
#  'S100PBP',
#  'CDCA3',
#  'ING1',
#  'LOC344967',
#  'CYP1B1',
#  'C3orf17',
#  'MMP10',
#  'CD59',
#  'ANXA2',
#  'C21orf56',
#  'PRR11',
#  'GRIK3',
#  'LILRB1',
#  'LSS',
#  'DOCK5',
#  'SNORD35A',
#  'hsa-miR-541*',
#  'RBM39',
#  'ONECUT3',
#  'LOC100133545',
#  'CPN2',
#  'KIAA1683',
#  'N4BP2',
#  'DENND1C',
#  'SGK2',
#  'LOC283922',
#  'FN1',
#  'BAT3',
#  'STAP1',
#  'APOE',
#  'ZNF335',
#  'C14orf126',
#  'PECR',
#  'C17orf89',
#  'PWWP2A',
#  'RTN4',
#  'SNORD34',
#  'MYH14',
#  'MBOAT1',
#  'PNPO',
#  'DNAJC9',
#  'FCER2',
#  'C1orf156',
#  'CD7',
#  'BAGE5',
#  'FDFT1',
#  'IER3',
#  'MYB',
#  'TMEM97',
#  'HOXC4',
#  'AKR7A2',
#  'BAX',
#  'FOXC1',
#  'MSX1',
#  'STRN3',
#  'RANBP3',
#  'hsa-miR-1469',
#  'MAPK14',
#  'SFRS3',
#  'CTDSPL2',
#  'TRMT2A',
#  'H2AFY',
#  'ANXA3',
#  'CDC7',
#  'DDX58',
#  'IL12RB1',
#  'DLX5',
#  'FAM117A',
#  'TASP1',
#  'RPL13AP5',
#  'MYEOV',
#  'UBAP2',
#  'PDE6D',
#  'FANCD2',
#  'PI4KA',
#  'IGFBPL1',
#  'E2F7',
#  'APPBP2',
#  'ZNF692',
#  'C16orf54',
#  'PNKD',
#  'RRP1',
#  'OLIG2',
#  'MRPL48',
#  'CYBASC3',
#  'CDR2',
#  'ARG2',
#  'ARSE',
#  'DKK3',
#  'ZNF497',
#  'PGS1',
#  'HIST3H2BB',
#  'HNMT',
#  'ZNF239',
#  'CASP14',
#  'GRAMD3',
#  'UPP1',
#  'RPS19',
#  'RHBDF1',
#  'IPO8',
#  'RFC4',
#  'RNF138',
#  'CARHSP1',
#  'TLK1',
#  'KRT80',
#  'PLLP',
#  'ZNF138',
#  'RAI14',
#  'ZNF341',
#  'AGFG2',
#  'PDAP1',
#  'MEPCE',
#  'SNHG10',
#  'CCBL1',
#  'NKX2-1',
#  'GPRC5C',
#  'CCT5',
#  'SH2D4A',
#  'hsa-miR-124*',
#  'HOXB6',
#  'TAF11',
#  'IRF8',
#  'POU4F1',
#  'TNFAIP3',
#  'KBTBD2',
#  'ACSM3',
#  'FRMD6',
#  'FNIP1',
#  'DGCR8',
#  'ZNF669',
#  'TDRKH',
#  'NEK6',
#  'ZNF438',
#  'HOXA11AS',
#  'FUT8',
#  'ALG3',
#  'ERRFI1',
#  'PCGF1',
#  'LRRC28',
#  'SEPP1',
#  'DPYSL2',
#  'RNF44',
#  'SPNS1',
#  'HIST1H1E',
#  'C7orf13',
#  'AKAP8L',
#  'HAND2',
#  'TMEM140',
#  'CTDSP1',
#  'SKP2',
#  'PSMA5',
#  'ANAPC11',
#  'VRK3',
#  'HNRNPR',
#  'OAS3',
#  'SIX6',
#  'UHRF2',
#  'SLBP',
#  'TAOK2',
#  'C20orf177',
#  'C12orf49',
#  'HEATR2',
#  'GOLPH3L',
#  'STARD9',
#  'CLCN6',
#  'hsa-miR-219-2-3p',
#  'PROM2',
#  'CCR7',
#  'SUPT16H',
#  'PKD1L1',
#  'CALCB',
#  'SGOL1',
#  'RPS6',
#  'WNT10A',
#  'SLC2A9',
#  'HRC',
#  'USP18',
#  'ALKBH7',
#  'ECE1',
#  'PSME4',
#  'PXMP4',
#  'SNX10',
#  'BHLHE23',
#  'MTHFSD',
#  'AGGF1',
#  'C1orf100',
#  'ERCC1',
#  'NCS1',
#  'ORC3',
#  'NUP205',
#  'HELQ',
#  'C2orf34',
#  'ANP32A',
#  'SLC3A2',
#  'NCRNA00263',
#  'BCL2L2',
#  'ACAP3',
#  'DNMBP',
#  'UNC45B',
#  'CDC5L',
#  'HSF2BP',
#  'FAM81A',
#  'UGP2',
#  'GPR19',
#  'KDM3A',
#  'ECD',
#  'GRAMD1A',
#  'SERPINB7',
#  'MXD1',
#  'MPZL1',
#  'IFI16',
#  'DEGS1',
#  'WT1',
#  'FOXF1',
#  'NTF3',
#  'RSBN1',
#  'PCK2',
#  'CSNK2B',
#  'MYBPH',
#  'IGFL3',
#  'DPYSL3',
#  'FLJ42709',
#  'ANKHD1',
#  'ATP5G1',
#  'EPM2AIP1',
#  'GAGE2B',
#  'ISOC2',
#  'SLC35E2',
#  'MESP2',
#  'RAB42',
#  'SNHG3',
#  'KCTD20',
#  'ARHGEF10L',
#  'PCK1',
#  'FRG2C',
#  'ONECUT1',
#  'DCAF17',
#  'PRMT6',
#  'CALU',
#  'TRAF3',
#  'DBI',
#  'TMEM146',
#  'LOC100133669',
#  'MSH5',
#  'SNORD114-26',
#  'LUZP4',
#  'ASXL1',
#  'RPS11',
#  'CYB561D1',
#  'P4HB',
#  'hsa-miR-10a*',
#  'IFT80',
#  'KRT23',
#  'BTBD19',
#  'ANKRD30BL',
#  'ANKRD1',
#  'DSCR8',
#  'PSMA1',
#  'TRAPPC2L',
#  'RPS13',
#  'IDI1',
#  'ENOPH1',
#  'LRCH4',
#  'MCCC1',
#  'TMCO1',
#  'ZIC1',
#  'C19orf47',
#  'ANP32E',
#  'UBASH3A',
#  'C16orf74',
#  'CECR5',
#  'FLJ45983',
#  'RASAL3',
#  'TRAPPC1',
#  'SUB1',
#  'ZC3H4',
#  'HSD11B1L',
#  'HMSD',
#  'GP6',
#  'LEMD3',
#  'SPHK1',
#  'BCR',
#  'CREB3L4',
#  'LOC399815',
#  'C8orf51',
#  'KLK11',
#  'NXNL2',
#  'TMEM18',
#  'SOX17',
#  'AIMP2',
#  'DHFRL1',
#  'C11orf86',
#  'SARNP',
#  'CROCCL1',
#  'PHOX2B',
#  'TOMM5',
#  'CAMLG',
#  'SOD3',
#  'PANK3',
#  'SLC7A5',
#  'C1orf228',
#  'GPR87',
#  'SPC25',
#  'SSBP2',
#  'SH3TC2',
#  'ZFYVE27',
#  'C19orf48',
#  'C2orf7',
#  'GCC1',
#  'SLC25A37',
#  'PMEPA1',
#  'METTL8',
#  'TYROBP',
#  'PSMD3',
#  'IRF2',
#  'AC068580.3',
#  'UBXN11',
#  'CLIP3',
#  'PRDM8',
#  'MTRNR2L8',
#  'APOBR',
#  'RSPH1',
#  'ICAM4',
#  'C19orf62',
#  'GSDMA',
#  'ZNF280B',
#  'KIF21A',
#  'ZFP36L2',
#  'TMEM114',
#  'POLE',
#  'C10orf46',
#  'OSBP',
#  'MSH2',
#  'KRT14',
#  'DARS2',
#  'TUBGCP3',
#  'SNORD114-28',
#  'MED15',
#  'HIST1H4L',
#  'AGR2',
#  'STAT5B',
#  'CENPA',
#  'SEC22B',
#  'WDR62',
#  'THOC6',
#  'LOC254559',
#  'ZNF584',
#  'HGS',
#  'HMX3',
#  'RNFT1',
#  'PARP9',
#  'RNF31',
#  'EGLN3',
#  'C2orf44',
#  'C20orf24',
#  'KLK10',
#  'OAS2',
#  'TUBA1C',
#  'TXNRD1',
#  'ITGAX',
#  'JPH4',
#  'MAP2K3',
#  'SVEP1',
#  'HM13',
#  'HPS3',
#  'CEACAM21',
#  'PPFIBP2',
#  'ATP9B',
#  'CCND1',
#  'FAM53C',
#  'DIP2A',
#  'FOXD4L1',
#  'MRPL45',
#  'SNORD12',
#  'PRDM13',
#  'TEAD1',
#  'MAPK1',
#  'TXNIP',
#  'ITPR3',
#  'CHP',
#  'OIP5',
#  'SHC1',
#  'CYCS',
#  'ROCK2',
#  'IQCE',
#  'HIST1H3F',
#  'KIAA0406',
#  'CARD6',
#  'ARRDC2',
#  'EMR1',
#  'ESM1',
#  'TOX2',
#  'DHX32',
#  'THAP8',
#  'UTP11L',
#  'HNF1B',
#  'KIAA1632',
#  'HIST1H2AB',
#  'HEG1',
#  'RANBP1',
#  'DCN',
#  'LOC400891',
#  'MAP1LC3B',
#  'ARF6',
#  'LATS1',
#  'C9orf30',
#  'HSPA5',
#  'CCDC103',
#  'RPL27A',
#  'NCRNA00245',
#  'MEX3D',
#  'RPL10A',
#  'IFT122',
#  'KIAA1731',
#  'LHX2',
#  'PLEK2',
#  'DEK',
#  'NOL9',
#  'BTG3',
#  'PAX7',
#  'INSIG2',
#  'PDXP',
#  'SERPIND1',
#  'WSB2',
#  'DDA1',
#  'CSAG1',
#  'MAN2A1',
#  'HNRPDL',
#  'NAA35',
#  'MBNL3',
#  'TPP1',
#  'SLC25A11',
#  'CACNG1',
#  'LHX3',
#  'ENO1',
#  'PRKACA',
#  'EPS8L2',
#  'C21orf49',
#  'TCF19',
#  'EFNA1',
#  'DDX42',
#  'ALB',
#  'NUDT2',
#  'UHRF1BP1',
#  'PUS7',
#  'GATAD2A',
#  'PCNT',
#  'WBP1',
#  'CSTF3',
#  'ADM',
#  'GPR162',
#  ...}

# %%
def get_len(item):
    return len(net.in_edges(item))

# %%
lista=[(gene,len(G.in_edges(gene))) for gene in readout_common]

# %%
len_innodes_gene=defaultdict(set)
for el in lista:
    len_innodes_gene[el[1]].add(el[0])
len_innodes_gene[5]
# Out:
# {'AARS',
#  'AATF',
#  'ABCA17P',
#  'ABCB8',
#  'ACTL6A',
#  'AIFM2',
#  'AIMP2',
#  'APTX',
#  'ARRDC2',
#  'ATP5G1',
#  'AVPI1',
#  'C10orf88',
#  'C11orf59',
#  'C13orf29',
#  'C14orf119',
#  'C16orf74',
#  'C19orf40',
#  'C19orf51',
#  'C1QTNF6',
#  'C1orf107',
#  'C1orf228',
#  'C20orf24',
#  'C21orf58',
#  'C5orf39',
#  'C5orf51',
#  'C6orf89',
#  'C7orf40',
#  'C8orf55',
#  'C9orf3',
#  'CABC1',
#  'CCBL1',
#  'CCDC123',
#  'CCNT1',
#  'CDC5L',
#  'CDR2',
#  'CENPL',
#  'CISD2',
#  'CNTLN',
#  'COX5A',
#  'CPB2',
#  'CREB3L4',
#  'CSPG4',
#  'CYP51A1',
#  'DAGLB',
#  'DARS2',
#  'DDIT3',
#  'DDX47',
#  'DENND4A',
#  'DEPDC4',
#  'DLX4',
#  'DNA2',
#  'DNAJC9',
#  'DOCK10',
#  'DRAP1',
#  'DSCC1',
#  'ENOPH1',
#  'ERGIC2',
#  'EXD1',
#  'FLJ31306',
#  'FLJ45983',
#  'FOXE1',
#  'GADD45A',
#  'GIMAP4',
#  'GLDC',
#  'GPATCH3',
#  'GPBP1',
#  'HELQ',
#  'HES4',
#  'HGSNAT',
#  'HIGD2A',
#  'HMX2',
#  'HOXA2',
#  'HOXD8',
#  'HRC',
#  'HSF2BP',
#  'HSPBAP1',
#  'ICAM1',
#  'IFI6',
#  'IQCD',
#  'ISLR2',
#  'ITPR3',
#  'KDM3A',
#  'KEAP1',
#  'KIAA0406',
#  'KNCN',
#  'LBX1',
#  'LBX2',
#  'LENG1',
#  'LHX5',
#  'LIMS1',
#  'LIN37',
#  'LMNB1',
#  'LOC729082',
#  'LONP1',
#  'LOXL1',
#  'LOXL2',
#  'LSMD1',
#  'MAP1D',
#  'MBIP',
#  'MBOAT1',
#  'MCOLN1',
#  'MED22',
#  'MLF1IP',
#  'MPV17L2',
#  'MYO1G',
#  'NKX2-5',
#  'NLRC5',
#  'NOC3L',
#  'NOL11',
#  'NPHP4',
#  'NUDT2',
#  'NUP107',
#  'ODF3B',
#  'OSR2',
#  'PARP9',
#  'PASD1',
#  'PAWR',
#  'PCNT',
#  'PCSK9',
#  'PLA2G6',
#  'PLD6',
#  'PNO1',
#  'PNPT1',
#  'POLA1',
#  'POLE4',
#  'POLR2E',
#  'PPARG',
#  'PQLC2',
#  'PRDX2',
#  'RBBP8',
#  'RBCK1',
#  'RBM18',
#  'RECQL',
#  'RFPL4B',
#  'RGS12',
#  'RNF7',
#  'RNFT1',
#  'RPL24',
#  'RPS8',
#  'RPS9',
#  'RSAD1',
#  'RSAD2',
#  'S100A6',
#  'SAE1',
#  'SARNP',
#  'SCAMP3',
#  'SDF4',
#  'SDPR',
#  'SEC31A',
#  'SGOL1',
#  'SH2D4A',
#  'SIM1',
#  'SIX1',
#  'SKIL',
#  'SLC15A4',
#  'SLC25A11',
#  'SLC25A24',
#  'SNORA76',
#  'SNORD35B',
#  'SP9',
#  'STARD4',
#  'STRADA',
#  'SUPT4H1',
#  'TARS',
#  'TASP1',
#  'TCP11L1',
#  'TCTEX1D4',
#  'THADA',
#  'THAP8',
#  'TM2D2',
#  'TM7SF3',
#  'TMEM140',
#  'TMEM159',
#  'TMEM161A',
#  'TMEM201',
#  'TMEM45A',
#  'TRIP13',
#  'TRPM7',
#  'TSPAN31',
#  'TUBGCP3',
#  'TYK2',
#  'UBE2C',
#  'UBE2L6',
#  'UBE2S',
#  'UNG',
#  'USP18',
#  'VRTN',
#  'WBP1',
#  'WDR36',
#  'WDR4',
#  'WDR89',
#  'WT1',
#  'XPC',
#  'YTHDC2',
#  'ZFYVE27',
#  'ZNF564',
#  'ZNF593',
#  'ZNF691',
#  'ZNF785',
#  'ZXDB',
#  'hsa-miR-302d',
#  'hsa-miR-302d*',
#  'hsa-miR-367*',
#  'hsa-miR-483-5p',
#  'hsa-miR-9*'}

# %%
set_common=[]
for GO_term in GO_id_map.keys():
    print()
    print(GO_term)
    for gene_view in GO_id_map[GO_term]:
        print(gene_view,"",set(G[gene_view]) & len_innodes_gene[5])
        set_common.append(set(G[gene_view]) & len_innodes_gene[5])
# Out:
# GO:0070317
# BRCA1  {'CCNT1', 'NOL11', 'THADA', 'GPBP1', 'GPATCH3', 'CDC5L', 'SLC25A11', 'SNORD35B', 'NUDT2', 'POLR2E', 'XPC', 'LSMD1', 'MED22', 'C6orf89', 'SLC15A4', 'ERGIC2'}
# MAX  {'LONP1', 'PLD6', 'LOXL1', 'RPS8', 'SAE1', 'SCAMP3', 'TASP1', 'SGOL1', 'NOC3L', 'ZNF785', 'C11orf59', 'HES4', 'HRC', 'UBE2S', 'POLE4', 'CCNT1', 'WDR36', 'MCOLN1', 'EXD1', 'ABCA17P', 'POLR2E', 'CABC1', 'HELQ', 'HIGD2A', 'AIMP2', 'WDR4', 'DOCK10', 'WDR89', 'HSPBAP1', 'C7orf40', 'HSF2BP', 'THAP8', 'KDM3A', 'ENOPH1', 'C1orf107', 'GLDC', 'THADA', 'ZFYVE27', 'SNORA76', 'AATF', 'C10orf88', 'MAP1D', 'PNO1'}
# E2F1  {'SH2D4A', 'DSCC1', 'SUPT4H1', 'LMNB1', 'AVPI1', 'PQLC2', 'TM7SF3', 'SLC25A24', 'HGSNAT', 'RSAD1', 'HES4', 'CREB3L4', 'CENPL', 'RBBP8', 'TMEM159', 'SKIL', 'DARS2', 'TUBGCP3', 'PAWR', 'OSR2', 'ITPR3', 'POLA1', 'C8orf55', 'TCP11L1', 'TRPM7', 'TMEM201', 'MBOAT1', 'ARRDC2', 'HSF2BP', 'DNAJC9', 'COX5A', 'AIFM2', 'TRIP13', 'RNFT1', 'STRADA', 'C16orf74', 'CCBL1'}
# SUZ12  {'SP9', 'hsa-miR-9*', 'SIM1', 'HOXA2', 'DLX4', 'WT1', 'HMX2', 'LBX1', 'NKX2-5', 'FLJ45983', 'HOXD8', 'ISLR2', 'AATF', 'SIX1', 'LBX2', 'OSR2', 'LHX5', 'FOXE1'}
# E2F6  {'CNTLN', 'PQLC2', 'ZNF785', 'HES4', 'HRC', 'POLE4', 'WDR36', 'DNA2', 'KEAP1', 'EXD1', 'ABCA17P', 'CISD2', 'CABC1', 'AIMP2', 'C8orf55', 'HSPBAP1', 'SP9', 'KIAA0406', 'HSF2BP', 'ENOPH1', 'AATF', 'C10orf88', 'SDF4', 'RBM18'}
#
# GO:0051591
# STAT1  {'USP18', 'RPS9', 'C1QTNF6', 'DENND4A', 'NLRC5', 'TARS', 'ICAM1', 'C5orf39', 'PARP9', 'KNCN', 'RSAD2', 'NUP107', 'TMEM140', 'PNPT1', 'UBE2L6', 'ODF3B', 'IFI6'}
# JUNB  set()
# FOS  {'C19orf40', 'C21orf58', 'TCTEX1D4', 'NPHP4', 'C13orf29', 'ATP5G1', 'LIMS1', 'ZNF691', 'ACTL6A', 'MPV17L2', 'LIN37', 'GIMAP4', 'AARS', 'LOXL2', 'CABC1', 'TMEM161A', 'CDR2', 'RECQL', 'TM2D2', 'UNG', 'SARNP', 'S100A6', 'LOC729082', 'ABCB8', 'C19orf51', 'LENG1', 'C1orf228', 'FLJ31306', 'ZNF564', 'CCDC123', 'CSPG4', 'GADD45A', 'PCNT', 'WBP1', 'TMEM45A', 'TYK2', 'UBE2C', 'IQCD'}
# FOSL1  {'DRAP1'}
# JUN  {'C13orf29', 'TCTEX1D4', 'ATP5G1', 'PASD1', 'RPL24', 'LIMS1', 'SEC31A', 'SDPR', 'RBCK1', 'DDX47', 'MBIP', 'C20orf24', 'GIMAP4', 'ZNF593', 'TM2D2', 'CSPG4', 'DDIT3'}
# SREBF1  {'C14orf119', 'CYP51A1', 'RBCK1', 'PLA2G6', 'PCSK9', 'C5orf51', 'STARD4'}
# JUND  {'C13orf29', 'ATP5G1', 'PPARG', 'RBCK1', 'TSPAN31', 'DEPDC4', 'RFPL4B', 'MYO1G', 'CPB2', 'HES4', 'APTX', 'hsa-miR-302d*', 'hsa-miR-302d', 'ZXDB', 'MLF1IP', 'YTHDC2', 'PASD1', 'RNF7', 'CDC5L', 'hsa-miR-483-5p', 'C9orf3', 'DAGLB', 'ZNF593', 'RPL24', 'RGS12', 'THADA', 'hsa-miR-367*', 'PRDX2', 'ZFYVE27', 'MBIP', 'C20orf24', 'VRTN', 'CCBL1'}

# %%
i=range(0,len(set_common))
for index,el in enumerate(set_common):
    print(index)
    for number in i:
        if number != index:
            print(el & set_common[number])
# Out:
# 0
# set()
# {'CCNT1', 'POLR2E', 'THADA'}
# set()
# set()
# set()
# {'CDC5L', 'THADA'}
# set()
# set()
# set()
# set()
# set()
# 1
# set()
# {'ZNF785', 'ENOPH1', 'ABCA17P', 'CABC1', 'ACAD9', 'HRC', 'ABCA3', 'HSF2BP', 'AATF', 'AIMP2', 'C10orf88', 'EXD1', 'HSPBAP1', 'POLE4', 'HES4', 'WDR36'}
# {'SP9', 'AATF'}
# {'C8orf55', 'PQLC2', 'HES4', 'HSF2BP'}
# set()
# {'ACAD9', 'HES4'}
# {'CABC1'}
# set()
# set()
# set()
# set()
# 2
# {'CCNT1', 'POLR2E', 'THADA'}
# {'ZNF785', 'ENOPH1', 'ABCA17P', 'CABC1', 'ACAD9', 'HRC', 'ABCA3', 'HSF2BP', 'AATF', 'AIMP2', 'C10orf88', 'EXD1', 'HSPBAP1', 'POLE4', 'HES4', 'WDR36'}
# {'AATF'}
# {'HES4', 'HSF2BP'}
# set()
# {'ACAD9', 'HES4', 'THADA', 'ZFYVE27'}
# {'CABC1'}
# set()
# set()
# {'ALDH1A1'}
# set()
# 3
# set()
# {'SP9', 'AATF'}
# {'AATF'}
# {'OSR2'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# 4
# set()
# {'C8orf55', 'PQLC2', 'HES4', 'HSF2BP'}
# {'HES4', 'HSF2BP'}
# {'OSR2'}
# set()
# {'HES4', 'CCBL1'}
# set()
# set()
# set()
# set()
# set()
# 5
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# 6
# {'CDC5L', 'THADA'}
# {'ACAD9', 'HES4'}
# {'ACAD9', 'HES4', 'THADA', 'ZFYVE27'}
# set()
# {'HES4', 'CCBL1'}
# set()
# {'C13orf29', 'ATP5G1'}
# set()
# {'RBCK1'}
# {'ATP5G1', 'ZNF593', 'RPL24', 'C20orf24', 'RBCK1', 'PASD1', 'C13orf29', 'MBIP'}
# set()
# 7
# set()
# {'CABC1'}
# {'CABC1'}
# set()
# set()
# set()
# {'C13orf29', 'ATP5G1'}
# set()
# {'ZNF775'}
# {'TM2D2', 'ATP5G1', 'CSPG4', 'TCTEX1D4', 'LIMS1', 'C13orf29', 'GIMAP4'}
# set()
# 8
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# 9
# set()
# set()
# set()
# set()
# set()
# set()
# {'RBCK1'}
# {'ZNF775'}
# set()
# {'RBCK1'}
# set()
# 10
# set()
# set()
# {'ALDH1A1'}
# set()
# set()
# set()
# {'ATP5G1', 'ZNF593', 'RPL24', 'C20orf24', 'RBCK1', 'PASD1', 'C13orf29', 'MBIP'}
# {'TM2D2', 'ATP5G1', 'CSPG4', 'TCTEX1D4', 'LIMS1', 'C13orf29', 'GIMAP4'}
# set()
# {'RBCK1'}
# set()
# 11
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()

# %%
for gene in len_innodes_gene[10]:
    
    genes_res_no_go=set(edge[0] for edge in G.in_edges(gene) if edge[0] not in set.union(*GO_id_map.values()))
    
    if genes_res_no_go.intersection(set(net.nodes())) != genes_res_no_go:
        continue
    print(gene)
    for key in GO_id_map.keys():
        print(key)
        print(set(gene_res for edge in G.in_edges(gene) for gene_res in GO_id_map[key] if gene_res in edge[0] ))
   
    print(genes_res_no_go)
   
    print()
# Out:
# IVL
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'BCL11A', 'EBF1', 'SPI1', 'CEBPB', 'PBX3', 'EP300', 'IRF4', 'BATF', 'TAL1'}
#
# SPHK1
# GO:0070317
# {'E2F6', 'E2F1'}
# GO:0051591
# {'JUN', 'FOS', 'JUND'}
# {'CTCF', 'SPI1', 'MYC', 'EP300', 'RAD21', 'hsa-miR-124', 'FOSL2'}
#
# TMEM116
# GO:0070317
# {'MAX', 'E2F6'}
# GO:0051591
# set()
# {'SPI1', 'CEBPB', 'USF1', 'NFE2', 'BATF', 'GTF2B', 'E2F4', 'USF2'}
#
# LOC100129726
# GO:0070317
# {'E2F1'}
# GO:0051591
# {'JUN', 'JUND'}
# {'MYC', 'FOXA1', 'HNF4A', 'HNF4G', 'RAD21', 'FOXA2', 'SMC3', 'PPARGC1A'}
#
# LOC147727
# GO:0070317
# {'MAX', 'E2F6'}
# GO:0051591
# set()
# {'ATF3', 'MYC', 'USF1', 'NFE2', 'MAFK', 'MAFF', 'YY1', 'USF2'}
#
# GPR108
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'SP2', 'NFYB', 'SPI1', 'PBX3', 'EP300', 'IRF3', 'NFYA', 'SIX5', 'SP1'}
#
# LOC440925
# GO:0070317
# set()
# GO:0051591
# {'JUN', 'JUND'}
# {'TCF4', 'RXRA', 'EP300', 'MAFK', 'FOXA1', 'HNF4A', 'MAFF', 'HNF4G', 'FOXA2'}
#
# BST2
# GO:0070317
# {'MAX', 'E2F6'}
# GO:0051591
# {'STAT1', 'FOS'}
# {'NFYB', 'EP300', 'USF1', 'NFYA', 'STAT2', 'GTF2B'}
#
# TUBB1
# GO:0070317
# {'MAX', 'E2F6'}
# GO:0051591
# set()
# {'NFYB', 'TCF4', 'CTCF', 'MYC', 'EP300', 'RAD21', 'hsa-miR-133a', 'TAL1'}
#
# APOM
# GO:0070317
# set()
# GO:0051591
# {'FOSL1', 'JUN', 'FOS', 'JUND'}
# {'EP300', 'FOXA1', 'HNF4A', 'HNF4G', 'SP1', 'FOXA2', 'hsa-miR-766', 'GTF2B'}

# %%
GO_007={readout_gene : { edge[0] for edge in G.in_edges(readout_gene) if edge[0] in net.nodes()}for readout_gene in ["STYXL1","BRD9","TUBB1"]}
np.save('GO_007.npy',GO_007) 
GO_007
# Out:
# {'BRD9': {'E2F1', 'E2F4', 'GABPA', 'MYC', 'SIN3A'},
#  'STYXL1': {'BRCA1', 'ELF1', 'ETS1', 'GABPA', 'ZBTB33'},
#  'TUBB1': {'CTCF',
#   'E2F6',
#   'EP300',
#   'MAX',
#   'MYC',
#   'NFYB',
#   'RAD21',
#   'TAL1',
#   'TCF4',
#   'hsa-miR-133a'}}

# %%
GO_007_005= {readout_gene :{ edge[0] for edge in G.in_edges(readout_gene) if edge[0] in net.nodes()}for readout_gene in ["SPHK1","ACAD9","BST2"]}
np.save('GO_007and005.npy',GO_007_005)

# %%
GO_005={readout_gene : { edge[0] for edge in G.in_edges(readout_gene)} for readout_gene in ["UBE2C","hsa-miR-483-5p","C20orf111"]}
np.save('GO_005.npy',GO_005)

# %%
[key for dici in [GO_005,GO_007,GO_007_005] for key in dici]
# Out:
# ['ZNF775',
#  'TMEM14C',
#  'C20orf111',
#  'STYXL1',
#  'BRD9',
#  'ABCA3',
#  'ALDH1A1',
#  'ACAD9']

# %%
## Win test
res_size=207
in_size=1
i_scaling=1

# %%
matrix,dict_pos=build_adj_weighted_matrix(file,mapping_relabel)

# %%
Win=np.zeros((res_size,1+in_size))*i_scaling
Win[1,]

# %%
#print(GO_id_map["GO:0030220"])
for gene in GO_id_map["GO:0030220"]:
    print(dict_pos[gene])
    Win[dict_pos[gene],]=2
print(np.where(Win==2))

# %%
def input_matrix_just_genes_GOterm(Win,GOterm,GO_id_map):
    for gene in GO_id_map[GOterm]:
        Win[dict_pos[gene],]=np.random.uniform(0,1)
    return Win

# %%
Win=np.zeros((res_size,1+in_size))*i_scaling
input_matrix_just_genes_GOterm(Win,"GO:0030220",GO_id_map)

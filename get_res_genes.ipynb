# %%
import networkx as nx
import numpy as np
import os
import random as rand
from collections import defaultdict

# %%
def get_r_dictionaries(file,mapping=True):
    with open(file, "r") as in_file:
        dict_map={}
        for line in in_file:
            line.strip()
            if mapping:
                dict_map[line.split()[1]]=line.split()[0]
            else:
                dict_map[line.split()[0]]=set(line.split()[1:])
    return dict_map

# %%
def get_cyclic_net(filename):
    G=nx.read_edgelist(filename, comments='#', delimiter="\t", nodetype =str,  data=(('mode',str),), create_using=nx.DiGraph())
    G.remove_nodes_from(["Source", "Target"])
    selfloops=G.selfloop_edges()
    G.remove_edges_from(G.selfloop_edges())

    while 0 in [d[1] for d in G.in_degree()] or 0 in [d[1] for d in G.out_degree()]:
        nodes_to_remove=[node for node in G if G.in_degree(node) == 0 or G.out_degree(node) == 0]
        G.remove_nodes_from(nodes_to_remove)
        
        
    selfloops_in_reservoir=[edge for edge in selfloops if edge[0] in G.nodes()]
    G.add_edges_from(selfloops_in_reservoir)

    return G

# %%
def build_adj_weighted_matrix(filename,mapping):
        #NETWORK v2.0
    net=get_cyclic_net(filename)
    nx.relabel_nodes(net,mapping,copy=False)
    dict_pos=dict((node,pos) for (pos,node) in enumerate(net.nodes()))
    for edge in net.edges(data="mode", default=0):
        source,target,mode=edge
        if mode== "+":
            net[source][target]["weight"]= abs(rand.gauss(0,1))
        elif mode== "-":
            net[source][target]["weight"]= rand.gauss(0,1)*-1
        elif mode== 0:
            net[source][target]["weight"]= rand.gauss(0,1)
        
    return nx.to_numpy_matrix(net),dict_pos

# %%
def write_nodes_file(out_file,filename,net):
    with open("%s_%s"%(out_file,filename),"w") as out:
        for gene in net.nodes():
            if "hsa" in gene:
                gene=gene[4:].lower()
            out.write(gene +"\n")

# %%
file="Dataset1/network_edge_list_ENCODE.csv"
net=get_cyclic_net("Dataset1/network_edge_list_ENCODE.csv")
G=nx.read_edgelist(file, comments='#', delimiter="\t", nodetype =str,  data=(('mode',str),), create_using=nx.DiGraph())

# %%
readout_direct_targets=defaultdict(set)

for source, target in G.edges():
    if source in net.nodes() and target not in net.nodes():
        readout_direct_targets[source].add(target)

readout_direct_targets["MAX"]
    #print(target)
# Out:
# {'AATF',
#  'ABCA17P',
#  'ABCA3',
#  'ABCB4',
#  'ABCF1',
#  'ABCG1',
#  'AC011472.1',
#  'AC013553.1',
#  'AC044799.1',
#  'AC136618.1',
#  'ACAD9',
#  'ACAP1',
#  'ACTC1',
#  'ADAM19',
#  'ADAMTS16',
#  'ADH6',
#  'ADM',
#  'ADORA1',
#  'AFMID',
#  'AFP',
#  'AGFG2',
#  'AGT',
#  'AIMP2',
#  'AIP',
#  'AK2',
#  'AKR1A1',
#  'AKR1C1',
#  'AKR1C3',
#  'AKT1S1',
#  'ALB',
#  'ALDH1A1',
#  'ALDOC',
#  'ALG2',
#  'ALG3',
#  'ALOX15B',
#  'AMDHD2',
#  'AMN',
#  'AMPD3',
#  'ANAPC7',
#  'ANG',
#  'ANK1',
#  'ANKRD12',
#  'ANKRD30BL',
#  'ANO3',
#  'ANP32B',
#  'AOC3',
#  'AP1G2',
#  'AP1S1',
#  'AP2M1',
#  'AP4M1',
#  'APBB3',
#  'APEX1',
#  'APOBR',
#  'APOC1',
#  'APOC2',
#  'APOE',
#  'APOH',
#  'APRT',
#  'ARHGAP24',
#  'ARSK',
#  'ASGR1',
#  'ASGR2',
#  'ASPSCR1',
#  'ATL3',
#  'ATP13A4',
#  'ATP6V0B',
#  'ATP6V0D1',
#  'ATP8B1',
#  'ATXN3',
#  'BAT3',
#  'BAX',
#  'BCAS3',
#  'BCKDHA',
#  'BCL2',
#  'BCR',
#  'BIN1',
#  'BLOC1S3',
#  'BMP4',
#  'BOLA1',
#  'BPIL1',
#  'BST2',
#  'BUB3',
#  'C10orf116',
#  'C10orf18',
#  'C10orf46',
#  'C10orf76',
#  'C10orf88',
#  'C11orf59',
#  'C12orf24',
#  'C12orf49',
#  'C13orf23',
#  'C16orf5',
#  'C16orf54',
#  'C16orf73',
#  'C17orf86',
#  'C17orf87',
#  'C18orf19',
#  'C19orf24',
#  'C19orf47',
#  'C19orf48',
#  'C19orf70',
#  'C1R',
#  'C1S',
#  'C1orf107',
#  'C1orf110',
#  'C1orf212',
#  'C1orf43',
#  'C1orf51',
#  'C1orf55',
#  'C20orf12',
#  'C21orf49',
#  'C22orf29',
#  'C2CD4B',
#  'C2orf34',
#  'C3',
#  'C3orf17',
#  'C3orf26',
#  'C5orf33',
#  'C5orf4',
#  'C5orf41',
#  'C6orf108',
#  'C6orf211',
#  'C6orf52',
#  'C7orf13',
#  'C7orf40',
#  'C9orf156',
#  'C9orf43',
#  'C9orf86',
#  'CA5A',
#  'CABC1',
#  'CACNA2D4',
#  'CACNG1',
#  'CALCB',
#  'CAPG',
#  'CARD6',
#  'CASP14',
#  'CBX5',
#  'CC2D1B',
#  'CCDC103',
#  'CCDC116',
#  'CCDC47',
#  'CCDC86',
#  'CCDC99',
#  'CCL14',
#  'CCL22',
#  'CCND1',
#  'CCNJ',
#  'CCNT1',
#  'CCR7',
#  'CD164',
#  'CD19',
#  'CD248',
#  'CD37',
#  'CD4',
#  'CD7',
#  'CD70',
#  'CD79A',
#  'CD79B',
#  'CD82',
#  'CDH11',
#  'CDH15',
#  'CDK15',
#  'CDK4',
#  'CEACAM1',
#  'CEACAM21',
#  'CEACAM5',
#  'CENPF',
#  'CENPM',
#  'CENPP',
#  'CHI3L1',
#  'CHP',
#  'CKLF',
#  'CKS1B',
#  'CLCN6',
#  'CLCN7',
#  'CLDN5',
#  'CLEC17A',
#  'CLIP3',
#  'CLN3',
#  'CLUAP1',
#  'COL4A2',
#  'COL6A1',
#  'COL9A1',
#  'COL9A3',
#  'COMMD8',
#  'COPS7A',
#  'COQ4',
#  'CORO1A',
#  'CORO1C',
#  'CPN2',
#  'CPVL',
#  'CRCT1',
#  'CRKL',
#  'CRLF1',
#  'CSF1',
#  'CSTF3',
#  'CTNNA1',
#  'CTSH',
#  'CTU2',
#  'CUTA',
#  'CXCL16',
#  'CXCR4',
#  'CYP1B1',
#  'CYSLTR1',
#  'CYTIP',
#  'DAB2',
#  'DAK',
#  'DBP',
#  'DCAF17',
#  'DCN',
#  'DDR2',
#  'DDX21',
#  'DDX42',
#  'DENND1C',
#  'DERL3',
#  'DFFA',
#  'DGCR8',
#  'DHDDS',
#  'DHRS2',
#  'DHX35',
#  'DHX40',
#  'DKK3',
#  'DLK1',
#  'DMPK',
#  'DNAH14',
#  'DNAJB9',
#  'DNAJC11',
#  'DNAJC16',
#  'DNAJC30',
#  'DNAJC8',
#  'DNLZ',
#  'DOCK10',
#  'DOK7',
#  'DPAGT1',
#  'DPEP1',
#  'DSCR4',
#  'DSCR8',
#  'DUS3L',
#  'DUSP10',
#  'DUSP9',
#  'DVL2',
#  'DYM',
#  'DYNC1H1',
#  'DYRK1B',
#  'EAF2',
#  'EBI3',
#  'EBNA1BP2',
#  'ECD',
#  'ECE1',
#  'ECE2',
#  'EDN1',
#  'EFTUD2',
#  'EIF2B3',
#  'EIF3B',
#  'EIF3K',
#  'EIF4A1',
#  'EIF4E',
#  'EIF4EBP3',
#  'EIF4H',
#  'EIF5A2',
#  'ELOVL2',
#  'ELOVL3',
#  'EML4',
#  'EMR1',
#  'ENKUR',
#  'ENO1',
#  'ENOPH1',
#  'ENPP2',
#  'EPB41L2',
#  'EPO',
#  'EPS8L2',
#  'ERBB3',
#  'ERCC6',
#  'ERP29',
#  'ETFB',
#  'ETV4',
#  'EXD1',
#  'EXOSC5',
#  'FABP1',
#  'FABP3',
#  'FADS3',
#  'FAF1',
#  'FAM103A1',
#  'FAM111A',
#  'FAM118B',
#  'FAM126A',
#  'FAM129C',
#  'FAM183A',
#  'FAM21C',
#  'FAM65C',
#  'FAM70B',
#  'FAM76A',
#  'FAM78A',
#  'FARSB',
#  'FCER2',
#  'FCRL2',
#  'FCRL5',
#  'FGF21',
#  'FGFR3',
#  'FGL1',
#  'FJX1',
#  'FLAD1',
#  'FLG',
#  'FLJ39582',
#  'FN1',
#  'FNBP1',
#  'FNIP1',
#  'FOXF1',
#  'FTCD',
#  'FTSJD1',
#  'FUT3',
#  'FUT5',
#  'FUT6',
#  'FXYD1',
#  'FXYD3',
#  'FYB',
#  'G6PC',
#  'G6PC3',
#  'GABPB1',
#  'GALK2',
#  'GALNS',
#  'GAPDH',
#  'GCFC1',
#  'GET4',
#  'GFI1',
#  'GGA1',
#  'GGTLC2',
#  'GLDC',
#  'GLTPD2',
#  'GLTSCR2',
#  'GLYR1',
#  'GNB1L',
#  'GNG11',
#  'GNPDA2',
#  'GNS',
#  'GOLGA5',
#  'GP1BB',
#  'GPN3',
#  'GPR114',
#  'GPR132',
#  'GPR153',
#  'GPR162',
#  'GPR180',
#  'GPR37',
#  'GPR87',
#  'GPRC5C',
#  'GPX2',
#  'GRAMD1A',
#  'GRAMD3',
#  'GRK4',
#  'GTF2A1',
#  'GTF2H1',
#  'HAMP',
#  'HAVCR2',
#  'HBP1',
#  'HCLS1',
#  'HDGFRP2',
#  'HECW2',
#  'HELQ',
#  'HEPACAM',
#  'HES4',
#  'HIGD2A',
#  'HINFP',
#  'HIRA',
#  'HLCS',
#  'HLF',
#  'HLTF',
#  'HMOX2',
#  'HMSD',
#  'HNF1A',
#  'HNRNPA1',
#  'HNRNPF',
#  'HNRNPR',
#  'HNRPA1L-2',
#  'HNRPDL',
#  'HOXA3',
#  'HOXA4',
#  'HOXA7',
#  'HOXA9',
#  'HOXC5',
#  'HOXC6',
#  'HP',
#  'HPD',
#  'HPN',
#  'HPS5',
#  'HRC',
#  'HSD11B1L',
#  'HSD17B2',
#  'HSF2BP',
#  'HSP90AB1',
#  'HSPA9',
#  'HSPB3',
#  'HSPB6',
#  'HSPBAP1',
#  'HYAL1',
#  'HYOU1',
#  'IARS',
#  'IGFBP1',
#  'IGSF1',
#  'IKZF3',
#  'IL12RB1',
#  'IL13RA2',
#  'IL1RN',
#  'IL2RG',
#  'IL4I1',
#  'IL7R',
#  'ILF3',
#  'IMMP2L',
#  'INPPL1',
#  'INSIG2',
#  'IP6K1',
#  'IPO13',
#  'IPO4',
#  'IQCG',
#  'IRF8',
#  'IRX4',
#  'ISM2',
#  'ITFG2',
#  'ITGA5',
#  'ITGAL',
#  'ITGB1BP1',
#  'ITIH2',
#  'ITPR1',
#  'IVL',
#  'JHDM1D',
#  'JUP',
#  'KAL1',
#  'KAT5',
#  'KCNH4',
#  'KDM3A',
#  'KHDRBS1',
#  'KIAA0090',
#  'KIAA0391',
#  'KIAA0415',
#  'KIAA0748',
#  'KIAA0930',
#  'KIAA1199',
#  'KIAA1407',
#  'KIAA1530',
#  'KIAA1737',
#  'KIAA1919',
#  'KIAA1984',
#  'KIF2A',
#  'KLF1',
#  'KLF11',
#  'KLF9',
#  'KLHL12',
#  'KLHL22',
#  'KLK8',
#  'KRT17',
#  'KRTDAP',
#  'LACTB2',
#  'LAMA4',
#  'LAMP1',
#  'LAT',
#  'LBH',
#  'LCN15',
#  'LEMD3',
#  'LGALS7',
#  'LGALS7B',
#  'LGR5',
#  'LIPC',
#  'LOC100130581',
#  'LOC100289341',
#  'LOC147727',
#  'LOC283922',
#  'LOC284023',
#  'LOC388796',
#  'LOC401242',
#  'LOC648691',
#  'LONP1',
#  'LOXL1',
#  'LRG1',
#  'LRPPRC',
#  'LRRC32',
#  'LRRC61',
#  'LSR',
#  'LY86',
#  'LYL1',
#  'LYPD6B',
#  'LYZ',
#  'LZTFL1',
#  'LZTR1',
#  'MAB21L1',
#  'MAGEA9',
#  'MAGEC2',
#  'MAMSTR',
#  'MAN1B1',
#  'MAN1C1',
#  'MAP1D',
#  'MAPK1',
#  'MARCH8',
#  'MBNL3',
#  'MCCC1',
#  'MCOLN1',
#  'MDN1',
#  'MEST',
#  'METTL1',
#  'METTL7B',
#  'METTL8',
#  'MFAP1',
#  'MFAP3L',
#  'MGA',
#  'MGST2',
#  'MLF1',
#  'MMD',
#  'MOGAT2',
#  'MOGAT3',
#  'MPP6',
#  'MRGPRF',
#  'MRPL40',
#  'MRPL45',
#  'MRPS18C',
#  'MRTO4',
#  'MSC',
#  'MSH5',
#  'MST1',
#  'MTHFD2',
#  'MTHFR',
#  'MTRNR2L4',
#  'MTTP',
#  'MYBPH',
#  'MYEOV',
#  'MYH14',
#  'MYL2',
#  'MYLPF',
#  'MYO16',
#  'MYO3B',
#  'MYO7A',
#  'MYOG',
#  'N6AMT1',
#  'NAPA',
#  'NAPSA',
#  'NAT10',
#  'NBPF1',
#  'NCAM1',
#  'NCL',
#  'NDRG2',
#  'NDUFA4',
#  'NEK3',
#  'NEK6',
#  'NFX1',
#  'NHLRC3',
#  'NKD1',
#  'NLE1',
#  'NME1',
#  'NME1-NME2',
#  'NMRAL1',
#  'NMU',
#  'NNMT',
#  'NOC3L',
#  'NOL7',
#  'NOL8',
#  'NOM1',
#  'NOP10',
#  'NOP14',
#  'NOP16',
#  'NOTUM',
#  'NPIP',
#  'NR0B2',
#  'NR1D1',
#  'NR1D2',
#  'NR5A1',
#  'NRBF2',
#  'NSUN5',
#  'NTF3',
#  'NUCB2',
#  'NUDT1',
#  'NUP205',
#  'NUP214',
#  'NUP62',
#  'ODC1',
#  'OPA1',
#  'OPTN',
#  'ORMDL3',
#  'OSGEP',
#  'P2RY8',
#  'PACRGL',
#  'PADI2',
#  'PAICS',
#  'PAK1IP1',
#  'PARVG',
#  'PCDHB5',
#  'PCYT1B',
#  'PDCD6IP',
#  'PDE12',
#  'PDE4D',
#  'PDGFRA',
#  'PDGFRB',
#  'PDIA4',
#  'PECR',
#  'PES1',
#  'PGK1',
#  'PHF19',
#  'PHF20',
#  'PI4KA',
#  'PIGZ',
#  'PIK3R3',
#  'PIK3R5',
#  'PIP5K1A',
#  'PLCG2',
#  'PLD3',
#  'PLD6',
#  'PLEKHA6',
#  'PNO1',
#  'PNPO',
#  'POLE4',
#  'POLR2E',
#  'POLR2J3',
#  'POLR3F',
#  'POSTN',
#  'PPA1',
#  'PPAN-P2RY11',
#  'PPAT',
#  'PPFIA4',
#  'PPIA',
#  'PPID',
#  'PPIL2',
#  'PPP2R3C',
#  'PPP2R5C',
#  'PRAME',
#  'PREPL',
#  'PRMT1',
#  'PRODH2',
#  'PRR15L',
#  'PSG5',
#  'PSMD9',
#  'PSME3',
#  'PTBP1',
#  'PTGIR',
#  'PTGS1',
#  'PTP4A2',
#  'PTPN7',
#  'PUS7',
#  'QKI',
#  'QSOX1',
#  'QTRT1',
#  'QTRTD1',
#  'RAB17',
#  'RAB34',
#  'RAB36',
#  'RAB3IL1',
#  'RAB42',
#  'RAB42P1',
#  'RAD23A',
#  'RAD9A',
#  'RAD9B',
#  'RAET1E',
#  'RAI14',
#  'RAMP2',
#  'RANBP1',
#  'RAPGEF1',
#  'RASAL3',
#  'RASGRP1',
#  'RBBP4',
#  'RBBP5',
#  'RBM15',
#  'RBP4',
#  'RBPJ',
#  'RCCD1',
#  'REPIN1',
#  'RFC1',
#  'RFTN1',
#  'RGS1',
#  'RGS13',
#  'RGS16',
#  'RHBDL1',
#  'RHBG',
#  'RIBC2',
#  'RIOK2',
#  'RMND1',
#  'RMRP',
#  'RNASE1',
#  'RNASE4',
#  'RNASEH2A',
#  'RNASET2',
#  'RNF130',
#  'RNF166',
#  'RNF32',
#  'RNFT2',
#  'RNMT',
#  'ROCK1P1',
#  'RP11-1212A22.4',
#  'RP11-35N6.1',
#  'RP11-383H13.1',
#  'RPA2',
#  'RPL10A',
#  'RPL12',
#  'RPL13A',
#  'RPL14',
#  'RPL21',
#  'RPL21P28',
#  'RPL23A',
#  'RPL32',
#  'RPL35A',
#  'RPS12',
#  'RPS8',
#  'RPSA',
#  'RPUSD4',
#  'RRAGD',
#  'RRAS2',
#  'RRP1',
#  'RRP1B',
#  'S100PBP',
#  'SAE1',
#  'SAMSN1',
#  'SBSN',
#  'SCAMP3',
#  'SCAND3',
#  'SCARNA2',
#  'SCFD2',
#  'SCN5A',
#  'SDF2L1',
#  'SDR42E1',
#  'SEC1',
#  'SEC61B',
#  'SELL',
#  'SEPHS2',
#  'SEPP1',
#  'SERF2',
#  'SERPINB10',
#  'SERPINC1',
#  'SERPINE2',
#  'SERPINF1',
#  'SERPINF2',
#  'SETD6',
#  'SFRP1',
#  'SFRS13A',
#  'SFRS18',
#  'SFRS2IP',
#  'SFRS7',
#  'SGCD',
#  'SGK1',
#  'SGOL1',
#  'SGPL1',
#  'SGPP2',
#  'SGTA',
#  'SHC1',
#  'SHD',
#  'SHISA9',
#  'SIRPB1',
#  'SIRT1',
#  'SKAP1',
#  'SLC13A3',
#  'SLC13A5',
#  'SLC16A1',
#  'SLC17A9',
#  'SLC25A1',
#  'SLC2A5',
#  'SLC35A4',
#  'SLC35A5',
#  'SLC39A5',
#  'SLC3A2',
#  'SLC40A1',
#  'SLC7A5P1',
#  'SLC7A5P2',
#  'SLCO4A1',
#  'SMC1B',
#  'SNAP29',
#  'SNHG1',
#  'SNHG7',
#  'SNORA76',
#  'SNORD104',
#  'SNORD55',
#  'SNRPA',
#  'SNX20',
#  'SNX5',
#  'SOAT2',
#  'SOCS5',
#  'SORL1',
#  'SP5',
#  'SPN',
#  'SPNS1',
#  'SPON2',
#  'SPOP',
#  'SPRYD4',
#  'SRP19',
#  'ST8SIA2',
#  'STAM',
#  'STAR',
#  'STAT5A',
#  'STK25',
#  'STMN1',
#  'SUB1',
#  'SULT1A1',
#  'SULT1A2',
#  'SULT1A3',
#  'SULT1A4',
#  'SULT2A1',
#  'SUMF1',
#  'SUPV3L1',
#  'TAF12',
#  'TAF4B',
#  'TAGLN',
#  'TAOK2',
#  'TASP1',
#  'TBC1D15',
#  'TBC1D16',
#  'TBC1D17',
#  'TBCB',
#  'TBX2',
#  'TBX4',
#  'TCERG1',
#  'TDG',
#  'TESC',
#  'TFEB',
#  'THADA',
#  'THAP5',
#  'THAP7',
#  'THAP8',
#  'THBS1',
#  'THNSL1',
#  'TIMM13',
#  'TINAGL1',
#  'TLCD1',
#  'TLK1',
#  'TM4SF5',
#  'TM9SF4',
#  'TMC8',
#  'TMED1',
#  'TMEM116',
#  'TMEM146',
#  'TMEM194A',
#  'TMEM233',
#  'TMEM37',
#  'TMEM40',
#  'TMEM42',
#  'TMEM48',
#  'TMEM55B',
#  'TNFRSF1A',
#  'TNFRSF9',
#  'TNNI3',
#  'TNPO2',
#  'TNS3',
#  'TOR1A',
#  'TPM1',
#  'TRA2A',
#  'TRAPPC2L',
#  'TRIM50',
#  'TRIM55',
#  'TRIM59',
#  'TRIM61',
#  'TRIM73',
#  'TRMT2A',
#  'TRUB2',
#  'TSN',
#  'TSNAX',
#  'TSNAX-DISC1',
#  'TTC37',
#  'TTC39B',
#  'TTR',
#  'TUBB1',
#  'TUBGCP2',
#  'TXNRD1',
#  'TXNRD2',
#  'TYROBP',
#  'UBA52',
#  'UBAC1',
#  'UBAP2',
#  'UBAP2L',
#  'UBASH3A',
#  'UBE2B',
#  'UBE2G2',
#  'UBE2Q1',
#  'UBE2S',
#  'UBXN11',
#  'URB2',
#  'USP14',
#  'USP20',
#  'USP36',
#  'UTP11L',
#  'VARS',
#  'VIM',
#  'VPS29',
#  'VSNL1',
#  'WDR36',
#  'WDR4',
#  'WDR62',
#  'WDR65',
#  'WDR74',
#  'WDR81',
#  'WDR89',
#  'WDR90',
#  'WDR92',
#  'WFDC1',
#  'WNT7A',
#  'XIRP1',
#  'XKR9',
#  'YBX1',
#  'YDJC',
#  'YPEL1',
#  'ZBTB40',
#  'ZC3H10',
#  'ZCCHC7',
#  'ZCWPW1',
#  'ZFR',
#  'ZFYVE27',
#  'ZIK1',
#  'ZIM2',
#  'ZKSCAN2',
#  'ZMYND8',
#  'ZNF239',
#  'ZNF280A',
#  'ZNF280D',
#  'ZNF292',
#  'ZNF3',
#  'ZNF628',
#  'ZNF692',
#  'ZNF74',
#  'ZNF785',
#  'ZNF84',
#  'hsa-miR-17*',
#  'hsa-miR-18a*',
#  'hsa-miR-19a*',
#  'hsa-miR-19b',
#  'hsa-miR-19b-1*',
#  'hsa-miR-20a*',
#  'hsa-miR-663b',
#  'hsa-miR-92a-1*'}

# %%
len(set(net["SRF"]))
# Out:
# 12

# %%
len(net.out_edges("SRF"))
# Out:
# 12

# %%
len(set.union(*readout_direct_targets.values()))
# Out:
# 13397

# %%
filename=file[file.index("list")+5:file.index(".csv")]

# %%
write_nodes_file("all_gene",filename,G)

# %%
len(net.nodes())
# Out:
# 207

# %%
## Get R dictionaries
## GO term -> set ids
GO_id_map=get_r_dictionaries("test.txt",mapping=False)
#print(GO_id_map)

## id to ENTREZ id
edgeid_ezid_map=get_r_dictionaries("mapping_id_to_entrez.txt")
print(edgeid_ezid_map)
# Out:
# {'5669': 'SP1', '6667': 'SP1', '199699': 'SP1', '6668': 'SP2', '2623': 'GATA1', '672': 'BRCA1', '3172': 'HNF4A', '1876': 'E2F6', '406920': 'hsa-miR-130b', '4208': 'MEF2C', '140690': 'CTCFL', '5452': 'POU2F2', '406982': 'hsa-miR-20a', '406953': 'hsa-miR-18a', '7702': 'ZNF143', '23462': 'HEY1', '6721': 'SREBF2', '25942': 'SIN3A', '2355': 'FOSL2', '53335': 'BCL11A', '7182': 'NR2C2', '147912': 'SIX5', '4149': 'MAX', '4601': 'MXI1', '10891': 'PPARGC1A', '4801': 'NFYB', '1958': 'EGR1', '1051': 'CEBPB', '5993': 'RFX5', '6688': 'SPI1', '9774': 'BCLAF1', '6938': 'TCF12', '639': 'PRDM1', '3066': 'HDAC2', '6256': 'RXRA', '4779': 'NRF1', '4899': 'NRF1', '6886': 'TAL1', '6925': 'TCF4', '6934': 'TCF4', '2099': 'ESR1', '905': 'CCNT2', '10664': 'CTCF', '5090': 'PBX3', '11128': 'POLR3A', '10009': 'ZBTB33', '3659': 'IRF1', '2033': 'EP300', '2113': 'ETS1', '2908': 'NR3C1', '51341': 'ZBTB7A', '1869': 'E2F1', '6722': 'SRF', '3661': 'IRF3', '2353': 'FOS', '8061': 'FOSL1', '3726': 'JUNB', '10535': 'JUNB', '6599': 'SMARCC1', '1879': 'EBF1', '4800': 'NFYA', '1106': 'CHD2', '1826': 'CHD2', '6908': 'TBP', '2551': 'GABPA', '1488': 'CTBP2', '3727': 'JUND', '6597': 'SMARCA4', '3662': 'IRF4', '3174': 'HNF4G', '3169': 'FOXA1', '4778': 'NFE2', '7936': 'RDBP', '6773': 'STAT2', '2005': 'ELK4', '406903': 'hsa-miR-10b', '26469': 'BDP1', '55814': 'BDP1', '7392': 'USF2', '23512': 'SUZ12', '678': 'BRF2', '55290': 'BRF2', '7391': 'USF1', '1874': 'E2F4', '6935': 'ZEB1', '4205': 'MEF2A', '602': 'BCL3', '574455': 'hsa-miR-193b', '8553': 'BHLHE40', '7022': 'TFAP2C', '10538': 'BATF', '2624': 'GATA2', '10155': 'TRIM28', '4790': 'NFKB1', '442904': 'hsa-miR-335', '5460': 'POU5F1', '51548': 'SIRT6', '100302232': 'hsa-miR-1226', '100302201': 'hsa-miR-1228', '7020': 'TFAP2A', '2959': 'GTF2B', '4609': 'MYC', '5820': 'MYC', '5079': 'PAX5', '3725': 'JUN', '3170': 'FOXA2', '7975': 'MAFK', '7528': 'YY1', '467': 'ATF3', '406998': 'hsa-miR-216a', '100126319': 'hsa-miR-216b', '407029': 'hsa-miR-30a', '406936': 'hsa-miR-144', '406999': 'hsa-miR-217', '6601': 'SMARCC2', '100126348': 'hsa-miR-760', '6772': 'STAT1', '406942': 'hsa-miR-150', '442900': 'hsa-miR-326', '406884': 'hsa-let-7b', '494324': 'hsa-miR-375', '406919': 'hsa-miR-130a', '442895': 'hsa-miR-302c', '407028': 'hsa-miR-302a', '100302143': 'hsa-miR-1248', '693158': 'hsa-miR-573', '406947': 'hsa-miR-155', '406921': 'hsa-miR-132', '693174': 'hsa-miR-589', '5885': 'RAD21', '23764': 'MAFF', '6720': 'SREBF1', '3297': 'HSF1', '6774': 'STAT3', '6879': 'TAF7', '10127': 'ZNF263', '56897': 'WRNIP1', '406985': 'hsa-miR-200c', '407011': 'hsa-miR-23b', '406994': 'hsa-miR-212', '1997': 'ELF1', '84337': 'ELF1', '9126': 'SMC3', '768218': 'hsa-miR-766', '574456': 'hsa-miR-497', '442891': 'hsa-miR-135b', '619553': 'hsa-miR-484', '6598': 'SMARCB1', '406902': 'hsa-miR-10a', '100126340': 'hsa-miR-944'}

# %%
## Primero: Hay que cambiarle el id del res al id de ENTREZ
## hay que hacer un mapping dictionary con la info que tenemos de los nodos de GO.term
##Como no todos están anotados es mejor crear un diccionario 
mapping_relabel = edgeid_ezid_map
for node in net.nodes():
    if node not in edgeid_ezid_map.values():
        mapping_relabel[node]=node
mapping_relabel
# Out:
# {'10009': 'ZBTB33',
#  '100126319': 'hsa-miR-216b',
#  '100126340': 'hsa-miR-944',
#  '100126348': 'hsa-miR-760',
#  '100302143': 'hsa-miR-1248',
#  '100302201': 'hsa-miR-1228',
#  '100302232': 'hsa-miR-1226',
#  '10127': 'ZNF263',
#  '10155': 'TRIM28',
#  '1051': 'CEBPB',
#  '10535': 'JUNB',
#  '10538': 'BATF',
#  '10664': 'CTCF',
#  '10891': 'PPARGC1A',
#  '1106': 'CHD2',
#  '11128': 'POLR3A',
#  '140690': 'CTCFL',
#  '147912': 'SIX5',
#  '1488': 'CTBP2',
#  '1826': 'CHD2',
#  '1869': 'E2F1',
#  '1874': 'E2F4',
#  '1876': 'E2F6',
#  '1879': 'EBF1',
#  '1958': 'EGR1',
#  '199699': 'SP1',
#  '1997': 'ELF1',
#  '2005': 'ELK4',
#  '2033': 'EP300',
#  '2099': 'ESR1',
#  '2113': 'ETS1',
#  '23462': 'HEY1',
#  '23512': 'SUZ12',
#  '2353': 'FOS',
#  '2355': 'FOSL2',
#  '23764': 'MAFF',
#  '2551': 'GABPA',
#  '25942': 'SIN3A',
#  '2623': 'GATA1',
#  '2624': 'GATA2',
#  '26469': 'BDP1',
#  '2908': 'NR3C1',
#  '2959': 'GTF2B',
#  '3066': 'HDAC2',
#  '3169': 'FOXA1',
#  '3170': 'FOXA2',
#  '3172': 'HNF4A',
#  '3174': 'HNF4G',
#  '3297': 'HSF1',
#  '3659': 'IRF1',
#  '3661': 'IRF3',
#  '3662': 'IRF4',
#  '3725': 'JUN',
#  '3726': 'JUNB',
#  '3727': 'JUND',
#  '406884': 'hsa-let-7b',
#  '406902': 'hsa-miR-10a',
#  '406903': 'hsa-miR-10b',
#  '406919': 'hsa-miR-130a',
#  '406920': 'hsa-miR-130b',
#  '406921': 'hsa-miR-132',
#  '406936': 'hsa-miR-144',
#  '406942': 'hsa-miR-150',
#  '406947': 'hsa-miR-155',
#  '406953': 'hsa-miR-18a',
#  '406982': 'hsa-miR-20a',
#  '406985': 'hsa-miR-200c',
#  '406994': 'hsa-miR-212',
#  '406998': 'hsa-miR-216a',
#  '406999': 'hsa-miR-217',
#  '407011': 'hsa-miR-23b',
#  '407028': 'hsa-miR-302a',
#  '407029': 'hsa-miR-30a',
#  '4149': 'MAX',
#  '4205': 'MEF2A',
#  '4208': 'MEF2C',
#  '442891': 'hsa-miR-135b',
#  '442895': 'hsa-miR-302c',
#  '442900': 'hsa-miR-326',
#  '442904': 'hsa-miR-335',
#  '4601': 'MXI1',
#  '4609': 'MYC',
#  '467': 'ATF3',
#  '4778': 'NFE2',
#  '4779': 'NRF1',
#  '4790': 'NFKB1',
#  '4800': 'NFYA',
#  '4801': 'NFYB',
#  '4899': 'NRF1',
#  '494324': 'hsa-miR-375',
#  '5079': 'PAX5',
#  '5090': 'PBX3',
#  '51341': 'ZBTB7A',
#  '51548': 'SIRT6',
#  '53335': 'BCL11A',
#  '5452': 'POU2F2',
#  '5460': 'POU5F1',
#  '55290': 'BRF2',
#  '55814': 'BDP1',
#  '5669': 'SP1',
#  '56897': 'WRNIP1',
#  '574455': 'hsa-miR-193b',
#  '574456': 'hsa-miR-497',
#  '5820': 'MYC',
#  '5885': 'RAD21',
#  '5993': 'RFX5',
#  '602': 'BCL3',
#  '619553': 'hsa-miR-484',
#  '6256': 'RXRA',
#  '639': 'PRDM1',
#  '6597': 'SMARCA4',
#  '6598': 'SMARCB1',
#  '6599': 'SMARCC1',
#  '6601': 'SMARCC2',
#  '6667': 'SP1',
#  '6668': 'SP2',
#  '6688': 'SPI1',
#  '672': 'BRCA1',
#  '6720': 'SREBF1',
#  '6721': 'SREBF2',
#  '6722': 'SRF',
#  '6772': 'STAT1',
#  '6773': 'STAT2',
#  '6774': 'STAT3',
#  '678': 'BRF2',
#  '6879': 'TAF7',
#  '6886': 'TAL1',
#  '6908': 'TBP',
#  '6925': 'TCF4',
#  '693158': 'hsa-miR-573',
#  '693174': 'hsa-miR-589',
#  '6934': 'TCF4',
#  '6935': 'ZEB1',
#  '6938': 'TCF12',
#  '7020': 'TFAP2A',
#  '7022': 'TFAP2C',
#  '7182': 'NR2C2',
#  '7391': 'USF1',
#  '7392': 'USF2',
#  '7528': 'YY1',
#  '768218': 'hsa-miR-766',
#  '7702': 'ZNF143',
#  '7936': 'RDBP',
#  '7975': 'MAFK',
#  '8061': 'FOSL1',
#  '84337': 'ELF1',
#  '8553': 'BHLHE40',
#  '905': 'CCNT2',
#  '9126': 'SMC3',
#  '9774': 'BCLAF1',
#  'hsa-let-7a': 'hsa-let-7a',
#  'hsa-miR-1': 'hsa-miR-1',
#  'hsa-miR-101': 'hsa-miR-101',
#  'hsa-miR-1205': 'hsa-miR-1205',
#  'hsa-miR-1207-3p': 'hsa-miR-1207-3p',
#  'hsa-miR-1207-5p': 'hsa-miR-1207-5p',
#  'hsa-miR-1208': 'hsa-miR-1208',
#  'hsa-miR-124': 'hsa-miR-124',
#  'hsa-miR-1245': 'hsa-miR-1245',
#  'hsa-miR-125a-3p': 'hsa-miR-125a-3p',
#  'hsa-miR-125a-5p': 'hsa-miR-125a-5p',
#  'hsa-miR-1260': 'hsa-miR-1260',
#  'hsa-miR-1279': 'hsa-miR-1279',
#  'hsa-miR-128': 'hsa-miR-128',
#  'hsa-miR-129-3p': 'hsa-miR-129-3p',
#  'hsa-miR-129-5p': 'hsa-miR-129-5p',
#  'hsa-miR-133a': 'hsa-miR-133a',
#  'hsa-miR-135a': 'hsa-miR-135a',
#  'hsa-miR-142-3p': 'hsa-miR-142-3p',
#  'hsa-miR-142-5p': 'hsa-miR-142-5p',
#  'hsa-miR-145': 'hsa-miR-145',
#  'hsa-miR-153': 'hsa-miR-153',
#  'hsa-miR-17': 'hsa-miR-17',
#  'hsa-miR-185': 'hsa-miR-185',
#  'hsa-miR-191': 'hsa-miR-191',
#  'hsa-miR-192': 'hsa-miR-192',
#  'hsa-miR-193a-3p': 'hsa-miR-193a-3p',
#  'hsa-miR-194': 'hsa-miR-194',
#  'hsa-miR-196a': 'hsa-miR-196a',
#  'hsa-miR-199b-5p': 'hsa-miR-199b-5p',
#  'hsa-miR-19a': 'hsa-miR-19a',
#  'hsa-miR-219-5p': 'hsa-miR-219-5p',
#  'hsa-miR-22': 'hsa-miR-22',
#  'hsa-miR-24': 'hsa-miR-24',
#  'hsa-miR-25': 'hsa-miR-25',
#  'hsa-miR-27b': 'hsa-miR-27b',
#  'hsa-miR-29b': 'hsa-miR-29b',
#  'hsa-miR-300': 'hsa-miR-300',
#  'hsa-miR-330-3p': 'hsa-miR-330-3p',
#  'hsa-miR-338-3p': 'hsa-miR-338-3p',
#  'hsa-miR-338-5p': 'hsa-miR-338-5p',
#  'hsa-miR-339-5p': 'hsa-miR-339-5p',
#  'hsa-miR-365': 'hsa-miR-365',
#  'hsa-miR-367': 'hsa-miR-367',
#  'hsa-miR-376a': 'hsa-miR-376a',
#  'hsa-miR-483-3p': 'hsa-miR-483-3p',
#  'hsa-miR-548c-3p': 'hsa-miR-548c-3p',
#  'hsa-miR-549': 'hsa-miR-549',
#  'hsa-miR-564': 'hsa-miR-564',
#  'hsa-miR-567': 'hsa-miR-567',
#  'hsa-miR-595': 'hsa-miR-595',
#  'hsa-miR-612': 'hsa-miR-612',
#  'hsa-miR-615-5p': 'hsa-miR-615-5p',
#  'hsa-miR-626': 'hsa-miR-626',
#  'hsa-miR-632': 'hsa-miR-632',
#  'hsa-miR-636': 'hsa-miR-636',
#  'hsa-miR-638': 'hsa-miR-638',
#  'hsa-miR-645': 'hsa-miR-645',
#  'hsa-miR-648': 'hsa-miR-648',
#  'hsa-miR-650': 'hsa-miR-650',
#  'hsa-miR-657': 'hsa-miR-657',
#  'hsa-miR-661': 'hsa-miR-661',
#  'hsa-miR-663': 'hsa-miR-663',
#  'hsa-miR-7': 'hsa-miR-7',
#  'hsa-miR-9': 'hsa-miR-9',
#  'hsa-miR-92a': 'hsa-miR-92a',
#  'hsa-miR-93': 'hsa-miR-93'}

# %%
for key,values in GO_id_map.items():
    GO_id_map[key]=set([mapping_relabel[value] for value in values])
GO_id_map
# Out:
# {'GO:0051591': {'FOS', 'FOSL1', 'JUN', 'JUNB', 'JUND', 'SREBF1', 'STAT1'},
#  'GO:0070317': {'BRCA1', 'E2F1', 'E2F6', 'MAX', 'SUZ12'}}

# %%
set.union(*GO_id_map.values())
# Out:
# {'BRCA1',
#  'E2F1',
#  'E2F6',
#  'FOS',
#  'FOSL1',
#  'JUN',
#  'JUNB',
#  'JUND',
#  'MAX',
#  'SREBF1',
#  'STAT1',
#  'SUZ12'}

# %%
readout_common=set(gene for gene_res in set.union(*GO_id_map.values()) for gene in set(G[gene_res]) if gene in set.union(*readout_direct_targets.values()) )

# %%
readout_common
# Out:
# {'SNORD114-24',
#  'HLCS',
#  'BLM',
#  'TRIP13',
#  'KIAA0101',
#  'C2orf44',
#  'ZIC4',
#  'DHX58',
#  'APBB3',
#  'TRIM34',
#  'LHX9',
#  'CD164',
#  'NR4A1',
#  'STX6',
#  'PES1',
#  'TARS2',
#  'SNORD104',
#  'hsa-miR-17*',
#  'KCNJ4',
#  'CTDSPL2',
#  'RND1',
#  'FAM24B',
#  'LRRC61',
#  'TMEM14C',
#  'RPA2',
#  'IRX5',
#  'RIF1',
#  'DMRTA2',
#  'UBE2C',
#  'ENOPH1',
#  'RNF32',
#  'ONECUT1',
#  'GBP4',
#  'DHRS13',
#  'STARD4',
#  'ATP13A4',
#  'MDP1',
#  'TMEM126B',
#  'NR2F1',
#  'RUVBL1',
#  'LBH',
#  'RPS12',
#  'AFMID',
#  'ARPP19',
#  'LMO7',
#  'LIMS2',
#  'CLNK',
#  'hsa-miR-196b',
#  'IMMP1L',
#  'HIF1A',
#  'SERBP1',
#  'LMBRD2',
#  'PIKFYVE',
#  'CCDC99',
#  'KIAA0947',
#  'HAVCR2',
#  'GPCPD1',
#  'PFDN4',
#  'RFWD3',
#  'C1orf156',
#  'SFRS15',
#  'MSH2',
#  'PIGX',
#  'OSR2',
#  'ARL16',
#  'ACTC1',
#  'RPL28',
#  'ANG',
#  'C19orf62',
#  'WDR65',
#  'ZNF341',
#  'CCND3',
#  'TIPIN',
#  'EML4',
#  'MRPS18C',
#  'HRC',
#  'AGRN',
#  'LOC645166',
#  'SBSN',
#  'BPGM',
#  'MRP63',
#  'C2orf34',
#  'C21orf49',
#  'GTF2A1',
#  'SELL',
#  'TPP1',
#  'LGALS7',
#  'PPP1CB',
#  'TESC',
#  'SEPT5',
#  'TLR10',
#  'OTP',
#  'HOXA11AS',
#  'SC5DL',
#  'HSPA5',
#  'TBCCD1',
#  'NKX6-1',
#  'GSG2',
#  'CXCL16',
#  'ZNF503',
#  'SPTBN1',
#  'ALG8',
#  'DAK',
#  'PDGFRA',
#  'NCK1',
#  'POU3F3',
#  'ITGAX',
#  'TXNRD2',
#  'PTHLH',
#  'FOXK2',
#  'hsa-miR-611',
#  'SHOX2',
#  'GLO1',
#  'LOC285548',
#  'DENR',
#  'LILRB1',
#  'GPR162',
#  'MSL2',
#  'VTRNA1-2',
#  'ETV4',
#  'GOLT1B',
#  'SIRPB1',
#  'KHNYN',
#  'DBP',
#  'URB2',
#  'MPG',
#  'PACRGL',
#  'GPR55',
#  'TMEM40',
#  'PERP',
#  'SAC3D1',
#  'PRKACA',
#  'TM4SF18',
#  'FADS2',
#  'IQCG',
#  'DEK',
#  'TLR7',
#  'UBXN11',
#  'C6orf48',
#  'TOR1AIP2',
#  'CPVL',
#  'C1orf116',
#  'NRN1',
#  'THAP2',
#  'TBX2',
#  'C19orf57',
#  'UGP2',
#  'MTHFSD',
#  'LRSAM1',
#  'SYT8',
#  'KLHL21',
#  'GALNT2',
#  'HMX2',
#  'SHARPIN',
#  'HP',
#  'HOXB4',
#  'NOS3',
#  'TPM3',
#  'LEAP2',
#  'FOXG1',
#  'LZTFL1',
#  'MYO16',
#  'FRMD6',
#  'HGSNAT',
#  'QSOX1',
#  'ANKRD39',
#  'PRKDC',
#  'LYPD1',
#  'KAL1',
#  'SNORD55',
#  'WDR25',
#  'DGKZ',
#  'SEC61B',
#  'hsa-miR-302d*',
#  'C16orf75',
#  'hsa-miR-10a*',
#  'P2RX6',
#  'STK17A',
#  'TUBGCP3',
#  'SNORD12C',
#  'ANAPC7',
#  'RECQL5',
#  'FARSB',
#  'RALGAPA1',
#  'HIST1H3F',
#  'BFSP1',
#  'ARSK',
#  'FOXN2',
#  'DHCR7',
#  'RSAD2',
#  'BRD9',
#  'SNORA68',
#  'PPARG',
#  'WDR81',
#  'NMU',
#  'WDR90',
#  'KLHL22',
#  'EIF4E',
#  'GGT5',
#  'TNFRSF10B',
#  'HNRNPU',
#  'CPB2',
#  'RUNDC2C',
#  'PVT1',
#  'METT10D',
#  'GRWD1',
#  'FNIP1',
#  'ARHGEF7',
#  'GNAS',
#  'CLDN5',
#  'ARRDC4',
#  'ZNF217',
#  'DIS3L',
#  'ARNTL',
#  'OSGEP',
#  'GPR98',
#  'HPCAL4',
#  'LOC100289341',
#  'C6orf52',
#  'MTHFR',
#  'DHX40',
#  'TUBGCP2',
#  'FOXC1',
#  'C10orf25',
#  'SLC25A24',
#  'TUBA1B',
#  'PSME2',
#  'RRAS2',
#  'UBE2L3',
#  'BEST3',
#  'PTTG1IP',
#  'PECR',
#  'MED16',
#  'SHMT2',
#  'SIAH2',
#  'IDI1',
#  'HECW2',
#  'DUSP9',
#  'FGF21',
#  'FAM103A1',
#  'MEX3D',
#  'CAMKK2',
#  'TMEM161A',
#  'APEX1',
#  'AC013553.1',
#  'HOXD1',
#  'EIF5A2',
#  'TASP1',
#  'HNRNPA1',
#  'IGF2',
#  'TTC32',
#  'SNORD35B',
#  'HIST1H2BL',
#  'SERPINB13',
#  'C18orf45',
#  'STAG1',
#  'TMEM39A',
#  'STIP1',
#  'SP9',
#  'LOC100132215',
#  'HNRNPUL2',
#  'SOX17',
#  'RAMP2',
#  'MAPK14',
#  'SC4MOL',
#  'C20orf111',
#  'TIPRL',
#  'THBS1',
#  'EHD1',
#  'MRAS',
#  'HSPA1B',
#  'PAIP2B',
#  'S100A2',
#  'STAT5A',
#  'DPEP1',
#  'TRAF3',
#  'DEGS2',
#  'HOXA2',
#  'PRMT8',
#  'RSPO1',
#  'RHOXF2B',
#  'GGA1',
#  'SUPV3L1',
#  'TMEM114',
#  'WFDC1',
#  'STXBP4',
#  'GSDMA',
#  'ASF1B',
#  'TCTEX1D4',
#  'CAPG',
#  'RPL13AP20',
#  'EDEM2',
#  'RFC5',
#  'MYH14',
#  'EVI2B',
#  'HOXA11',
#  'GPR180',
#  'KIAA1407',
#  'RPS4X',
#  'GPR37',
#  'RBBP5',
#  'ZNF687',
#  'WDR77',
#  'CC2D1A',
#  'COL6A1',
#  'EMX2OS',
#  'TOMM5',
#  'STRADA',
#  'FANCA',
#  'TUBD1',
#  'MT1DP',
#  'C10orf78',
#  'FAM124B',
#  'HMSD',
#  'COX11',
#  'MFAP1',
#  'PPFIBP2',
#  'CARD6',
#  'TOM1L2',
#  'NOL10',
#  'SCYL3',
#  'EFTUD2',
#  'TMEM201',
#  'PTMA',
#  'ING4',
#  'HOXA1',
#  'TMCO1',
#  'UCKL1',
#  'C8orf55',
#  'DCTN2',
#  'SEC62',
#  'OIP5',
#  'VIM',
#  'SENP3',
#  'GCLC',
#  'ROCK2',
#  'FOXO3',
#  'LOC283922',
#  'BIRC2',
#  'AC008810.1',
#  'FAF1',
#  'ERRFI1',
#  'HOXD4',
#  'CGGBP1',
#  'PTGER4',
#  'HYAL1',
#  'NR2E1',
#  'AIMP2',
#  'ELOVL3',
#  'PPIA',
#  'LIN7C',
#  'SMARCD2',
#  'CCL4L1',
#  'TAGLN',
#  'NCRNA00261',
#  'SNORD83A',
#  'hsa-miR-124*',
#  'C9orf96',
#  'WDR53',
#  'DGCR8',
#  'C3orf58',
#  'NOTCH3',
#  'FN1',
#  'SEH1L',
#  'GAGE1',
#  'HIST1H4I',
#  'ARHGAP24',
#  'ARPC1A',
#  'FAM151B',
#  'EOMES',
#  'RBM42',
#  'EXOSC5',
#  'ESX1',
#  'LMO2',
#  'PXK',
#  'PITX1',
#  'ZNF775',
#  'UHRF1BP1',
#  'CRTAP',
#  'hsa-miR-1538',
#  'ZBTB25',
#  'TADA2A',
#  'SDF2L1',
#  'DOLPP1',
#  'MLPH',
#  'BUB3',
#  'ZNF555',
#  'LHX2',
#  'ATAD2',
#  'PPCDC',
#  'HDGFRP2',
#  'SEMA7A',
#  'LYL1',
#  'EPC1',
#  'C9orf43',
#  'SMC4',
#  'ZBTB20',
#  'HES4',
#  'RAB27A',
#  'TRADD',
#  'NUBPL',
#  'hsa-miR-19b-1*',
#  'BMP7',
#  'HOXB13',
#  'RPS11',
#  'THADA',
#  'TNS1',
#  'SGTA',
#  'FLJ41350',
#  'SLC41A2',
#  'ITPR3',
#  'FLJ10038',
#  'C1orf51',
#  'PDE3B',
#  'RPL12',
#  'TMEM18',
#  'ADIPOR2',
#  'GATA4',
#  'ATPIF1',
#  'ZZZ3',
#  'HPD',
#  'EEF1A1',
#  'NT5M',
#  'ABCA3',
#  'C10orf116',
#  'HOXB6',
#  'C5orf27',
#  'LGALS3BP',
#  'DOT1L',
#  'SCD',
#  'ALOX15B',
#  'LOC100216545',
#  'HMGA1',
#  'HIST1H2AK',
#  'RHOBTB3',
#  'ATF2',
#  'RNF130',
#  'GPR183',
#  'STMN1',
#  'DARS2',
#  'C20orf7',
#  'BLK',
#  'TM7SF3',
#  'KCNK1',
#  'SETD6',
#  'AGR2',
#  'SOCS3',
#  'AKR1A1',
#  'ZFP36L2',
#  'LAMC3',
#  'NIPAL3',
#  'ECD',
#  'TTC37',
#  'PRRX1',
#  'BMPR1A',
#  'EPB41L2',
#  'ZNF564',
#  'NCAM1',
#  'DUS3L',
#  'INO80C',
#  'RNASEK',
#  'SEC22B',
#  'RPL9',
#  'HNRNPA3',
#  'AFG3L2',
#  'HTRA1',
#  'AP2M1',
#  'CENPP',
#  'LOC654342',
#  'IGFBP5',
#  'SGOL1',
#  'CCNO',
#  'DNAJC27',
#  'HCLS1',
#  'CD68',
#  'ZNF473',
#  'ZNF8',
#  'TNFRSF8',
#  'DUSP1',
#  'SRP54',
#  'C14orf45',
#  'TRIM33',
#  'TLR4',
#  'DCAF15',
#  'STK4',
#  'ITGAL',
#  'MPP4',
#  'B3GAT3',
#  'LOC100131496',
#  'HEPACAM',
#  'GNB4',
#  'ASH2L',
#  'COL1A2',
#  'SPINK5',
#  'PHTF2',
#  'APOB',
#  'CALM3',
#  'LYPD6B',
#  'ZNF280D',
#  'hsa-miR-302d',
#  'THAP7',
#  'GCHFR',
#  'C1orf43',
#  'PRH1',
#  'C11orf35',
#  'SLC3A2',
#  'ERGIC2',
#  'SLC39A5',
#  'NOM1',
#  'SHKBP1',
#  'TTBK2',
#  'TRIB1',
#  'ESYT2',
#  'ZNF184',
#  'MPV17L2',
#  'TIFA',
#  'PAX9',
#  'HIST1H3H',
#  'CA5A',
#  'MYO3B',
#  'PRDM13',
#  'G6PC',
#  'BCKDHA',
#  'NPM1',
#  'HOXA3',
#  'TOP2A',
#  'SFT2D2',
#  'SOAT2',
#  'EIF3K',
#  'C1R',
#  'THBS2',
#  'ATP6V0B',
#  'KCTD9',
#  'COL9A3',
#  'NKX2-2',
#  'AP1G2',
#  'ITGB1BP1',
#  'INHBB',
#  'hsa-miR-483-5p',
#  'RRM2',
#  'PRR15L',
#  'RPL14',
#  'SNORD48',
#  'YPEL4',
#  'DENND1C',
#  'THSD4',
#  'CLIC1',
#  'LSR',
#  'GDF15',
#  'CTDSP1',
#  'RECQL',
#  'HIST1H2AL',
#  'PAGE1',
#  'SFRS12',
#  'NFATC2IP',
#  'FAM21A',
#  'RHD',
#  'SAMD11',
#  'SNORD33',
#  'TRIM61',
#  'UNK',
#  'FAM117A',
#  'hsa-miR-26b',
#  'RAB34',
#  'ANXA3',
#  'ANKFY1',
#  'ICAM4',
#  'C11orf86',
#  'SCFD2',
#  'KRT1',
#  'FAM173B',
#  'PDXP',
#  'TARS',
#  'DHX9',
#  'NCRNA00171',
#  'SHH',
#  'TUBB2C',
#  'ALKBH7',
#  'CCL5',
#  'HERC5',
#  'CORO1A',
#  'GOLGA5',
#  'CD37',
#  'FAM178A',
#  'NKX2-1',
#  'FRG1',
#  'TSNAX',
#  'CKS1B',
#  'SIX3',
#  'APOF',
#  'VWDE',
#  'USP36',
#  'SRD5A3',
#  'CNOT1',
#  'ZNF74',
#  'METTL2A',
#  'hsa-miR-1908',
#  'DCAF11',
#  'DHRS1',
#  'GPRC5C',
#  'PSMD7',
#  'ATXN1',
#  'KLK6',
#  'PRAME',
#  'JUB',
#  'CNTROB',
#  'GNS',
#  'MYEOV',
#  'RNASE7',
#  'C13orf29',
#  'GGA2',
#  'LOC100130581',
#  'FAM65C',
#  'TMEM183A',
#  'THTPA',
#  'IFT27',
#  'CACNG1',
#  'UFD1L',
#  'RPPH1',
#  'hsa-miR-1293',
#  'LBR',
#  'SUPT4H1',
#  'RBM27',
#  'OSGIN2',
#  'MST1',
#  'NCAPG',
#  'ARHGEF25',
#  'ABCB4',
#  'ALPK1',
#  'NME1-NME2',
#  'SARNP',
#  'H2AFJ',
#  'ZNF595',
#  'CCL3',
#  'CARHSP1',
#  'hsa-miR-21*',
#  'ECE2',
#  'PAX2',
#  'FAM158A',
#  'SNORD32A',
#  'NDRG2',
#  'BCL2L13',
#  'LAP3',
#  'KIAA1310',
#  'MAGOHB',
#  'SORT1',
#  'MYLPF',
#  'SAT1',
#  'CDCA4',
#  'FUT8',
#  'MGC23284',
#  'FA2H',
#  'AP3M2',
#  'LOC728619',
#  'RBPJ',
#  'SATB2',
#  'POLR1C',
#  'MTMR4',
#  'SLC4A1',
#  'SCARNA2',
#  'ACTR1B',
#  'DNAJC11',
#  'JHDM1D',
#  'TTC39B',
#  'ABCB10',
#  'EPO',
#  'ABCE1',
#  'FUNDC2',
#  'SPOP',
#  'CD53',
#  'INTS7',
#  'GNA15',
#  'CCDC47',
#  'LCLAT1',
#  'DUSP2',
#  'DNAJC9',
#  'TMEM194A',
#  'CNDP2',
#  'NF1',
#  'MSH6',
#  'LHX6',
#  'SNORD114-22',
#  'SLC18A3',
#  'BCL2',
#  'C11orf20',
#  'ZNF239',
#  'MPND',
#  'CDX2',
#  'MSC',
#  'LAMB1',
#  'PLCG2',
#  'FTCD',
#  'FSIP1',
#  'RFC1',
#  'MSH5',
#  'NOL9',
#  'C19orf23',
#  'ANO3',
#  'hsa-miR-196b*',
#  'FEV',
#  'FTSJD1',
#  'ZNF672',
#  'PDIK1L',
#  'LOC153684',
#  'DOCK9',
#  'NOC3L',
#  'GPR65',
#  'LAMA4',
#  'HNRNPR',
#  'PIK3R5',
#  'HDAC1',
#  'KIAA0907',
#  'ZC3HAV1',
#  'GRIK3',
#  'LBX1',
#  'FABP1',
#  'ACSM3',
#  'GAPDH',
#  'SKIL',
#  'NUDT1',
#  'SUPT16H',
#  'UHRF1',
#  'HOXC9',
#  'ME3',
#  'PIM1',
#  'COMT',
#  'LMX1A',
#  'PRDM12',
#  'HLTF',
#  'RAB3A',
#  'LY6E',
#  'MAGEA9',
#  'LY86',
#  'CADPS2',
#  'DYM',
#  'DDIT3',
#  'S100A10',
#  'PCDHB5',
#  'RPL31',
#  'COPZ1',
#  'PWWP2A',
#  'CAV1',
#  'CSNK2B',
#  'FUT5',
#  'ERP29',
#  'C12orf11',
#  'CBX3',
#  'SNORD27',
#  'CASP2',
#  'MT1E',
#  'DNA2',
#  'KDM4B',
#  'SGPP2',
#  'CSTF1',
#  'PROC',
#  'HGS',
#  'GBX2',
#  'THOC4',
#  'AMN',
#  'BNIP3L',
#  'IL24',
#  'HELB',
#  'CNFN',
#  'LOC151300',
#  'SPEN',
#  'FBXO45',
#  'FDPS',
#  'PQLC2',
#  'RAG1AP1',
#  'hsa-miR-302b*',
#  'CDC45',
#  'LRG1',
#  'XPC',
#  'ZMYND8',
#  'SNX20',
#  'NR1D2',
#  'PCSK9',
#  'FAM70B',
#  'LOC646999',
#  'PARP4',
#  'HNRNPF',
#  'TOMM40',
#  'KRT75',
#  'KLK9',
#  'RPS8',
#  'TUBA1A',
#  'FAM53C',
#  'TLK1',
#  'CCNE2',
#  'PMEPA1',
#  'SHD',
#  'TRIM48',
#  'GPR153',
#  'CAND1',
#  'SNHG10',
#  'NAPSA',
#  'TRIM59',
#  'GGTLC2',
#  'RNASEH2A',
#  'HIST1H2AH',
#  'hsa-miR-150*',
#  'HIST1H4F',
#  'HSPA9',
#  'AKR7A2',
#  'XPOT',
#  'PTOV1',
#  'ABL1',
#  'IVL',
#  'RNF7',
#  'GOT1',
#  'TMEM135',
#  'XPO5',
#  'TBX21',
#  'KRBA1',
#  'DVL2',
#  'HCFC1R1',
#  'LTB4R2',
#  'ZDHHC23',
#  'NUP62',
#  'MTRNR2L1',
#  'PDS5A',
#  'HMGCR',
#  'RHCG',
#  'LHX3',
#  'DLX6AS',
#  'SSTR1',
#  'GIMAP4',
#  'HIST1H4D',
#  'MAPRE2',
#  'HMGCS1',
#  'YTHDF1',
#  'AMPD3',
#  'SH2B3',
#  'ADCK4',
#  'LMNA',
#  'TMEM183B',
#  'PKD1L1',
#  'IGF2AS',
#  'SPHK1',
#  'MTMR11',
#  'ZNF346',
#  'CLCC1',
#  'MAMSTR',
#  'SNX10',
#  'CIRBP',
#  'NCS1',
#  'AC136618.1',
#  'CHI3L1',
#  'ZXDB',
#  'BRP44',
#  'VPS24',
#  'UBE2H',
#  'ALG3',
#  'TOP1',
#  'COL6A3',
#  'HSD17B2',
#  'CCDC123',
#  'LOC401242',
#  'CSAG1',
#  'LOC645323',
#  'TTLL5',
#  'NFIX',
#  'GFM2',
#  'EZH2',
#  'CD79B',
#  'HIST1H2BO',
#  'MDN1',
#  'HIST2H2AC',
#  'FLJ31306',
#  'FBXO5',
#  'MTMR12',
#  'LRRC48',
#  'C16orf74',
#  'PPM1D',
#  'FIBCD1',
#  'GCFC1',
#  'GPR18',
#  'HOXA4',
#  'ORC3',
#  'BAGE',
#  'SET',
#  'MYOG',
#  'CDH11',
#  'NFIC',
#  'NUMB',
#  'RTN3',
#  'SCAND3',
#  'ZNF587',
#  'NUDT18',
#  'TRIM73',
#  'MTRNR2L4',
#  'CENPA',
#  'C17orf56',
#  'PASD1',
#  'NKX2-3',
#  'LEMD3',
#  'ZNF669',
#  'OFD1',
#  'EPS15',
#  'PICALM',
#  'HOMEZ',
#  'KCNK4',
#  'KIAA0020',
#  'FRG1B',
#  'G6PC3',
#  'RHBDF1',
#  'DGCR14',
#  'DSCR8',
#  'WDR92',
#  'SLC25A25',
#  'CREBZF',
#  'SHC4',
#  'ENPP2',
#  'PDX1',
#  'GNAZ',
#  'POLR2J3',
#  'PTPN4',
#  'PFN1',
#  'SEPP1',
#  'CLUAP1',
#  'TMSB10',
#  'SEMA4B',
#  'HSPA4',
#  'TXNRD1',
#  'SPRED2',
#  'LIPC',
#  'MCFD2',
#  'GAS2L3',
#  'OAS1',
#  'TCERG1',
#  'PAX3',
#  'C1S',
#  'SLC2A5',
#  'hsa-miR-1306',
#  'CECR6',
#  'ESF1',
#  'OAS3',
#  'PNPT1',
#  'APOL6',
#  'FDFT1',
#  'S100PBP',
#  'SNX16',
#  'GPX2',
#  'RSRC1',
#  'C17orf82',
#  'PTP4A1',
#  'EVL',
#  'LOC25845',
#  'FAM43A',
#  'IRX1',
#  'CRYBA2',
#  'HLX',
#  'PCGF1',
#  'C2orf76',
#  'VRTN',
#  'DCAF7',
#  'PIK3CG',
#  'PNPO',
#  'IARS',
#  'ELAVL2',
#  'VKORC1',
#  'SPIB',
#  'STARD9',
#  'SLC16A3',
#  'RBM14',
#  'C8orf22',
#  'GRIA1',
#  'ASCL1',
#  'TMEM45A',
#  'SIRT1',
#  'ANKRD30BL',
#  'PPM1F',
#  'FRG2C',
#  'PAX8',
#  'PPA1',
#  'MBIP',
#  'PXMP4',
#  'RAD9B',
#  'SERPINA1',
#  'C1orf59',
#  'THPO',
#  'HNF1B',
#  'SERPINC1',
#  'GALE',
#  'C10orf137',
#  'HNRNPC',
#  'KPNB1',
#  'ATXN7L2',
#  'HNRNPL',
#  'EN2',
#  'COL2A1',
#  'ADNP2',
#  'MFHAS1',
#  'CCNT1',
#  'ADAR',
#  'ORMDL3',
#  'TFF3',
#  'GALNT5',
#  'RTN2',
#  'SNORA76',
#  ...}

# %%
def get_len(item):
    return len(net.in_edges(item))

# %%
lista=[(gene,len(G.in_edges(gene))) for gene in readout_common]

# %%
len_innodes_gene=defaultdict(set)
for el in lista:
    len_innodes_gene[el[1]].add(el[0])
len_innodes_gene[5]
# Out:
# {'AARS',
#  'AATF',
#  'ABCA17P',
#  'ABCA3',
#  'ABCB8',
#  'ACAD9',
#  'ACTL6A',
#  'AIFM2',
#  'AIMP2',
#  'ALDH1A1',
#  'APTX',
#  'ARRDC2',
#  'ATP5G1',
#  'AVPI1',
#  'BRD9',
#  'C10orf88',
#  'C11orf59',
#  'C13orf29',
#  'C14orf119',
#  'C16orf74',
#  'C19orf40',
#  'C19orf51',
#  'C1QTNF6',
#  'C1orf107',
#  'C1orf228',
#  'C20orf111',
#  'C20orf24',
#  'C21orf58',
#  'C5orf39',
#  'C5orf51',
#  'C6orf89',
#  'C7orf40',
#  'C8orf55',
#  'C9orf3',
#  'CABC1',
#  'CCBL1',
#  'CCDC123',
#  'CCNT1',
#  'CDC5L',
#  'CDR2',
#  'CENPL',
#  'CISD2',
#  'CNTLN',
#  'COX5A',
#  'CPB2',
#  'CREB3L4',
#  'CSPG4',
#  'CYP51A1',
#  'DAGLB',
#  'DARS2',
#  'DDIT3',
#  'DDX47',
#  'DENND4A',
#  'DEPDC4',
#  'DLX4',
#  'DNA2',
#  'DNAJC9',
#  'DOCK10',
#  'DRAP1',
#  'DSCC1',
#  'ENOPH1',
#  'ERGIC2',
#  'EXD1',
#  'FLJ31306',
#  'FLJ45983',
#  'FOXE1',
#  'GADD45A',
#  'GIMAP4',
#  'GLDC',
#  'GPATCH3',
#  'GPBP1',
#  'HELQ',
#  'HES4',
#  'HGSNAT',
#  'HIGD2A',
#  'HMX2',
#  'HOXA2',
#  'HOXD8',
#  'HRC',
#  'HSF2BP',
#  'HSPBAP1',
#  'ICAM1',
#  'IFI6',
#  'IQCD',
#  'ISLR2',
#  'ITPR3',
#  'KDM3A',
#  'KEAP1',
#  'KIAA0406',
#  'KNCN',
#  'LBX1',
#  'LBX2',
#  'LENG1',
#  'LHX5',
#  'LIMS1',
#  'LIN37',
#  'LMNB1',
#  'LOC729082',
#  'LONP1',
#  'LOXL1',
#  'LOXL2',
#  'LSMD1',
#  'MAP1D',
#  'MBIP',
#  'MBOAT1',
#  'MCOLN1',
#  'MED22',
#  'MLF1IP',
#  'MPV17L2',
#  'MYO1G',
#  'NKX2-5',
#  'NLRC5',
#  'NOC3L',
#  'NOL11',
#  'NPHP4',
#  'NUDT2',
#  'NUP107',
#  'ODF3B',
#  'OSR2',
#  'PARP9',
#  'PASD1',
#  'PAWR',
#  'PCNT',
#  'PCSK9',
#  'PLA2G6',
#  'PLD6',
#  'PNO1',
#  'PNPT1',
#  'POLA1',
#  'POLE4',
#  'POLR2E',
#  'PPARG',
#  'PQLC2',
#  'PRDX2',
#  'RBBP8',
#  'RBCK1',
#  'RBM18',
#  'RECQL',
#  'RFPL4B',
#  'RGS12',
#  'RNF7',
#  'RNFT1',
#  'RPL24',
#  'RPS8',
#  'RPS9',
#  'RSAD1',
#  'RSAD2',
#  'S100A6',
#  'SAE1',
#  'SARNP',
#  'SCAMP3',
#  'SDF4',
#  'SDPR',
#  'SEC31A',
#  'SGOL1',
#  'SH2D4A',
#  'SIM1',
#  'SIX1',
#  'SKIL',
#  'SLC15A4',
#  'SLC25A11',
#  'SLC25A24',
#  'SNORA76',
#  'SNORD35B',
#  'SP9',
#  'STARD4',
#  'STRADA',
#  'STYXL1',
#  'SUPT4H1',
#  'TARS',
#  'TASP1',
#  'TCP11L1',
#  'TCTEX1D4',
#  'THADA',
#  'THAP8',
#  'TM2D2',
#  'TM7SF3',
#  'TMEM140',
#  'TMEM14C',
#  'TMEM159',
#  'TMEM161A',
#  'TMEM201',
#  'TMEM45A',
#  'TRIP13',
#  'TRPM7',
#  'TSPAN31',
#  'TUBGCP3',
#  'TYK2',
#  'UBE2C',
#  'UBE2L6',
#  'UBE2S',
#  'UNG',
#  'USP18',
#  'VRTN',
#  'WBP1',
#  'WDR36',
#  'WDR4',
#  'WDR89',
#  'WT1',
#  'XPC',
#  'YTHDC2',
#  'ZFYVE27',
#  'ZNF564',
#  'ZNF593',
#  'ZNF691',
#  'ZNF775',
#  'ZNF785',
#  'ZXDB',
#  'hsa-miR-302d',
#  'hsa-miR-302d*',
#  'hsa-miR-367*',
#  'hsa-miR-483-5p',
#  'hsa-miR-9*'}

# %%
set_common=[]
for GO_term in GO_id_map.keys():
    print()
    print(GO_term)
    for gene_view in GO_id_map[GO_term]:
        print(gene_view,"",set(G[gene_view]) & len_innodes_gene[5])
        set_common.append(set(G[gene_view]) & len_innodes_gene[5])
# Out:
# GO:0070317
# SUZ12  {'WT1', 'NKX2-5', 'hsa-miR-9*', 'SIM1', 'SIX1', 'LHX5', 'FLJ45983', 'ISLR2', 'LBX2', 'OSR2', 'HOXD8', 'SP9', 'AATF', 'FOXE1', 'HMX2', 'LBX1', 'DLX4', 'HOXA2'}
# BRCA1  {'NOL11', 'SLC15A4', 'SNORD35B', 'STYXL1', 'ERGIC2', 'POLR2E', 'GPBP1', 'GPATCH3', 'CDC5L', 'SLC25A11', 'XPC', 'C6orf89', 'THADA', 'LSMD1', 'MED22', 'NUDT2', 'CCNT1'}
# MAX  {'HSF2BP', 'C11orf59', 'NOC3L', 'PNO1', 'POLR2E', 'SNORA76', 'LOXL1', 'AIMP2', 'AATF', 'THADA', 'SGOL1', 'HIGD2A', 'CABC1', 'TASP1', 'ACAD9', 'HRC', 'SCAMP3', 'RPS8', 'LONP1', 'EXD1', 'POLE4', 'UBE2S', 'ENOPH1', 'PLD6', 'GLDC', 'ABCA3', 'HSPBAP1', 'DOCK10', 'WDR36', 'HELQ', 'THAP8', 'ABCA17P', 'ZFYVE27', 'MAP1D', 'SAE1', 'MCOLN1', 'C7orf40', 'KDM3A', 'WDR89', 'C1orf107', 'ALDH1A1', 'C10orf88', 'ZNF785', 'HES4', 'WDR4', 'CCNT1'}
# E2F6  {'KIAA0406', 'HSF2BP', 'PQLC2', 'AIMP2', 'AATF', 'CABC1', 'ACAD9', 'HRC', 'SP9', 'KEAP1', 'EXD1', 'POLE4', 'ENOPH1', 'CNTLN', 'ABCA3', 'HSPBAP1', 'WDR36', 'ABCA17P', 'DNA2', 'RBM18', 'C8orf55', 'SDF4', 'C10orf88', 'ZNF785', 'CISD2', 'HES4'}
# E2F1  {'HSF2BP', 'PQLC2', 'TRIP13', 'AVPI1', 'OSR2', 'LMNB1', 'ITPR3', 'SKIL', 'AIFM2', 'TUBGCP3', 'POLA1', 'STRADA', 'BRD9', 'SUPT4H1', 'RSAD1', 'TCP11L1', 'DNAJC9', 'TRPM7', 'RBBP8', 'CCBL1', 'TMEM159', 'PAWR', 'ARRDC2', 'CENPL', 'TMEM201', 'DSCC1', 'DARS2', 'COX5A', 'C8orf55', 'SH2D4A', 'TM7SF3', 'SLC25A24', 'C16orf74', 'RNFT1', 'CREB3L4', 'HGSNAT', 'HES4', 'MBOAT1'}
#
# GO:0051591
# JUNB  set()
# FOSL1  {'DRAP1'}
# STAT1  {'IFI6', 'PNPT1', 'ICAM1', 'RPS9', 'TARS', 'NLRC5', 'KNCN', 'NUP107', 'DENND4A', 'C5orf39', 'PARP9', 'ODF3B', 'UBE2L6', 'RSAD2', 'C1QTNF6', 'TMEM140', 'USP18'}
# FOS  {'NPHP4', 'WBP1', 'ACTL6A', 'GIMAP4', 'C13orf29', 'CSPG4', 'GADD45A', 'LOC729082', 'CABC1', 'TMEM161A', 'LENG1', 'S100A6', 'C21orf58', 'C1orf228', 'AARS', 'UNG', 'ZNF691', 'UBE2C', 'IQCD', 'TMEM45A', 'TM2D2', 'ZNF775', 'ABCB8', 'SARNP', 'CCDC123', 'RECQL', 'CDR2', 'TYK2', 'PCNT', 'LIMS1', 'LOXL2', 'C19orf51', 'FLJ31306', 'LIN37', 'ATP5G1', 'ZNF564', 'MPV17L2', 'C19orf40', 'TCTEX1D4'}
# JUND  {'RFPL4B', 'C13orf29', 'MLF1IP', 'DAGLB', 'PRDX2', 'RBCK1', 'MYO1G', 'TSPAN31', 'THADA', 'hsa-miR-302d*', 'DEPDC4', 'VRTN', 'PASD1', 'ACAD9', 'YTHDC2', 'C9orf3', 'hsa-miR-483-5p', 'PPARG', 'ZXDB', 'C20orf111', 'CPB2', 'CCBL1', 'hsa-miR-302d', 'C20orf24', 'APTX', 'ZFYVE27', 'MBIP', 'RGS12', 'ZNF593', 'RNF7', 'CDC5L', 'ATP5G1', 'hsa-miR-367*', 'RPL24', 'HES4'}
# SREBF1  {'CYP51A1', 'ZNF775', 'STARD4', 'TMEM14C', 'C5orf51', 'RBCK1', 'PLA2G6', 'C14orf119', 'PCSK9'}
# JUN  {'ZNF593', 'LIMS1', 'TM2D2', 'PASD1', 'GIMAP4', 'C13orf29', 'SEC31A', 'CSPG4', 'C20orf24', 'DDX47', 'SDPR', 'ATP5G1', 'RBCK1', 'ALDH1A1', 'MBIP', 'RPL24', 'DDIT3', 'TCTEX1D4'}

# %%
i=range(0,len(set_common))
for index,el in enumerate(set_common):
    print(index)
    for number in i:
        if number != index:
            print(el & set_common[number])
# Out:
# 0
# set()
# {'C8orf55', 'HSF2BP', 'HES4', 'PQLC2'}
# {'OSR2'}
# {'HSF2BP', 'HES4'}
# set()
# {'CCBL1', 'HES4'}
# set()
# set()
# set()
# set()
# set()
# 1
# set()
# set()
# set()
# {'THADA', 'CCNT1', 'POLR2E'}
# set()
# {'THADA', 'CDC5L'}
# set()
# set()
# set()
# set()
# set()
# 2
# {'C8orf55', 'HSF2BP', 'HES4', 'PQLC2'}
# set()
# {'AATF', 'SP9'}
# {'C10orf88', 'AATF', 'HSF2BP', 'ABCA3', 'WDR36', 'HRC', 'HES4', 'AIMP2', 'CABC1', 'ENOPH1', 'POLE4', 'EXD1', 'ABCA17P', 'ACAD9', 'ZNF785', 'HSPBAP1'}
# set()
# {'ACAD9', 'HES4'}
# set()
# {'CABC1'}
# set()
# set()
# set()
# 3
# {'OSR2'}
# set()
# {'AATF', 'SP9'}
# {'AATF'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# 4
# {'HSF2BP', 'HES4'}
# {'THADA', 'CCNT1', 'POLR2E'}
# {'C10orf88', 'AATF', 'HSF2BP', 'ABCA3', 'WDR36', 'HRC', 'HES4', 'AIMP2', 'CABC1', 'ENOPH1', 'POLE4', 'EXD1', 'ABCA17P', 'ACAD9', 'ZNF785', 'HSPBAP1'}
# {'AATF'}
# set()
# {'THADA', 'ACAD9', 'ZFYVE27', 'HES4'}
# set()
# {'CABC1'}
# {'ALDH1A1'}
# set()
# set()
# 5
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# 6
# {'CCBL1', 'HES4'}
# {'THADA', 'CDC5L'}
# {'ACAD9', 'HES4'}
# set()
# {'THADA', 'ACAD9', 'ZFYVE27', 'HES4'}
# set()
# {'RBCK1'}
# {'C13orf29', 'ATP5G1'}
# {'ATP5G1', 'C20orf24', 'PASD1', 'RBCK1', 'MBIP', 'C13orf29', 'ZNF593', 'RPL24'}
# set()
# set()
# 7
# set()
# set()
# set()
# set()
# set()
# set()
# {'RBCK1'}
# {'ZNF775'}
# {'RBCK1'}
# set()
# set()
# 8
# set()
# set()
# {'CABC1'}
# set()
# {'CABC1'}
# set()
# {'C13orf29', 'ATP5G1'}
# {'ZNF775'}
# {'ATP5G1', 'GIMAP4', 'C13orf29', 'TCTEX1D4', 'TM2D2', 'LIMS1', 'CSPG4'}
# set()
# set()
# 9
# set()
# set()
# set()
# set()
# {'ALDH1A1'}
# set()
# {'ATP5G1', 'C20orf24', 'PASD1', 'RBCK1', 'MBIP', 'C13orf29', 'ZNF593', 'RPL24'}
# {'RBCK1'}
# {'ATP5G1', 'GIMAP4', 'C13orf29', 'TCTEX1D4', 'TM2D2', 'LIMS1', 'CSPG4'}
# set()
# set()
# 10
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# 11
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()

# %%
for gene in len_innodes_gene[5]:
    
    genes_res_no_go=set(edge[0] for edge in G.in_edges(gene) if edge[0] not in set.union(*GO_id_map.values()))
    
    if genes_res_no_go.intersection(set(net.nodes())) != genes_res_no_go:
        continue
    print(gene)
    for key in GO_id_map.keys():
        print(key)
        print(set(gene_res for edge in G.in_edges(gene) for gene_res in GO_id_map[key] if gene_res in edge[0] ))
   
    print(genes_res_no_go)
   
    print()
# Out:
# C11orf59
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'USF2', 'ATF3', 'NFE2', 'USF1'}
#
# RFPL4B
# GO:0070317
# set()
# GO:0051591
# {'JUND', 'JUN'}
# {'STAT3', 'EP300', 'RFX5', 'CEBPB'}
#
# STYXL1
# GO:0070317
# {'BRCA1'}
# GO:0051591
# set()
# {'ELF1', 'ZBTB33', 'GABPA', 'ETS1'}
#
# TRIP13
# GO:0070317
# {'E2F1'}
# GO:0051591
# set()
# {'MYC', 'SIN3A', 'E2F4', 'GABPA'}
#
# AVPI1
# GO:0070317
# {'E2F1'}
# GO:0051591
# set()
# {'TFAP2C', 'TFAP2A', 'EGR1', 'NR3C1'}
#
# DAGLB
# GO:0070317
# set()
# GO:0051591
# {'JUN', 'FOS', 'JUND'}
# {'GTF2B', 'TAL1', 'NRF1', 'FOSL2'}
#
# RBCK1
# GO:0070317
# set()
# GO:0051591
# {'SREBF1', 'JUND', 'JUN'}
# {'EP300', 'SREBF2'}
#
# SGOL1
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'USF2', 'E2F4', 'NFE2', 'USF1'}
#
# TMEM161A
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'TCF4', 'PBX3', 'NFYB', 'NFYA'}
#
# S100A6
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'TFAP2C', 'TFAP2A', 'SMARCA4', 'SMARCB1'}
#
# SNORD35B
# GO:0070317
# {'BRCA1'}
# GO:0051591
# set()
# {'BCL3', 'SMARCA4', 'ZBTB33', 'ETS1'}
#
# ACAD9
# GO:0070317
# {'MAX', 'E2F6'}
# GO:0051591
# {'JUND', 'JUN'}
# {'ATF3', 'NRF1'}
#
# TMEM14C
# GO:0070317
# set()
# GO:0051591
# {'SREBF1'}
# {'MAFK', 'MAFF', 'SP1', 'NR3C1'}
#
# C6orf89
# GO:0070317
# {'BRCA1'}
# GO:0051591
# set()
# {'ELF1', 'ZBTB33', 'GABPA', 'CTCF'}
#
# SP9
# GO:0070317
# {'SUZ12', 'E2F6'}
# GO:0051591
# set()
# {'TCF12', 'TCF4', 'CTBP2'}
#
# UBE2C
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'IRF3', 'E2F4', 'SP1', 'EP300'}
#
# IQCD
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'PBX3', 'NFYB', 'SP1', 'NFYA'}
#
# STARD4
# GO:0070317
# set()
# GO:0051591
# {'SREBF1'}
# {'TFAP2C', 'TFAP2A', 'hsa-miR-129-3p', 'SREBF2'}
#
# C20orf111
# GO:0070317
# set()
# GO:0051591
# {'JUND', 'JUN'}
# {'SIN3A', 'NRF1', 'RAD21', 'CTCF'}
#
# hsa-miR-302d
# GO:0070317
# set()
# GO:0051591
# {'JUND', 'JUN'}
# {'BCL3', 'BCL11A', 'POU5F1', 'TAF7'}
#
# SLC25A11
# GO:0070317
# {'BRCA1'}
# GO:0051591
# set()
# {'BCL3', 'ZBTB33', 'ETS1', 'POU2F2'}
#
# THAP8
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'USF2', 'NFYB', 'CTCF', 'USF1'}
#
# ABCA17P
# GO:0070317
# {'MAX', 'E2F6'}
# GO:0051591
# set()
# {'NRF1', 'CTCF', 'CTCFL'}
#
# HOXA2
# GO:0070317
# {'SUZ12'}
# GO:0051591
# set()
# {'TCF12', 'hsa-miR-760', 'CTBP2', 'GATA2'}
#
# ZNF593
# GO:0070317
# set()
# GO:0051591
# {'JUND', 'JUN'}
# {'MYC', 'CTCF', 'ZNF263'}
#
# DENND4A
# GO:0070317
# set()
# GO:0051591
# {'STAT1'}
# {'MEF2A', 'NFKB1', 'EGR1', 'ZNF263'}
#
# LIN37
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'PBX3', 'SP1', 'SIX5', 'CEBPB'}
#
# MPV17L2
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'SP2', 'NFYB', 'SP1', 'NFYA'}
#
# C19orf40
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'E2F4', 'NFYB', 'SP1', 'NFYA'}
#
# LOC729082
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'IRF3', 'PBX3', 'NFYB', 'NFYA'}
#
# C1orf228
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'SP2', 'PBX3', 'NFYA', 'SP1'}
#
# hsa-miR-483-5p
# GO:0070317
# set()
# GO:0051591
# {'JUN', 'FOS', 'JUND'}
# {'MYC', 'FOSL2', 'HEY1', 'FOXA1'}
#
# ODF3B
# GO:0070317
# set()
# GO:0051591
# {'STAT1'}
# {'STAT3', 'STAT2', 'NFKB1', 'POU2F2'}
#
# PLD6
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'USF1', 'MYC', 'EGR1', 'PAX5'}
#
# TMEM45A
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'hsa-miR-19a', 'PBX3', 'NFYB', 'NFYA'}
#
# CCBL1
# GO:0070317
# {'E2F1'}
# GO:0051591
# {'JUND', 'JUN'}
# {'YY1', 'ELF1', 'GATA2'}
#
# ABCB8
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'SP2', 'NFYB', 'SP1', 'NFYA'}
#
# TYK2
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'NFKB1', 'NFYB', 'SP1', 'NFYA'}
#
# MAP1D
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'USF1', 'SIN3A', 'YY1', 'MYC'}
#
# PCNT
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'TAL1', 'E2F4', 'NFYB', 'GATA2'}
#
# C8orf55
# GO:0070317
# {'E2F1', 'E2F6'}
# GO:0051591
# set()
# {'TFAP2C', 'TFAP2A', 'CTCF'}
#
# C19orf51
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'EP300', 'NFYB', 'CTCF', 'NFYA'}
#
# LHX5
# GO:0070317
# {'SUZ12'}
# GO:0051591
# set()
# {'TCF12', 'CTBP2', 'hsa-miR-9', 'hsa-miR-133a'}
#
# C10orf88
# GO:0070317
# {'MAX', 'E2F6'}
# GO:0051591
# set()
# {'TCF4', 'E2F4', 'NRF1'}
#
# CCNT1
# GO:0070317
# {'BRCA1', 'MAX'}
# GO:0051591
# set()
# {'USF2', 'EGR1', 'USF1'}
#
# IFI6
# GO:0070317
# set()
# GO:0051591
# {'STAT1'}
# {'STAT2', 'IRF1', 'ZEB1', 'CTCF'}
#
# POLR2E
# GO:0070317
# {'BRCA1', 'MAX'}
# GO:0051591
# set()
# {'MYC', 'BATF', 'ZBTB33'}
#
# SNORA76
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'USF2', 'MYC', 'TBP', 'USF1'}
#
# AIMP2
# GO:0070317
# {'MAX', 'E2F6'}
# GO:0051591
# set()
# {'MYC', 'NFYB', 'NFYA'}
#
# PRDX2
# GO:0070317
# set()
# GO:0051591
# {'JUND', 'JUN'}
# {'SMARCA4', 'EP300', 'SMARCB1', 'SRF'}
#
# MYO1G
# GO:0070317
# set()
# GO:0051591
# {'JUND', 'JUN'}
# {'TFAP2C', 'EP300', 'EBF1', 'CEBPB'}
#
# AATF
# GO:0070317
# {'SUZ12', 'MAX', 'E2F6'}
# GO:0051591
# set()
# {'USF1', 'ELF1'}
#
# NUDT2
# GO:0070317
# {'BRCA1'}
# GO:0051591
# set()
# {'E2F4', 'NFYB', 'ELK4', 'NFYA'}
#
# SIX1
# GO:0070317
# {'SUZ12'}
# GO:0051591
# set()
# {'TCF12', 'EP300', 'CTBP2', 'ZNF263'}
#
# C21orf58
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'TAL1', 'E2F4', 'NFYB', 'GATA2'}
#
# SCAMP3
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'USF2', 'hsa-miR-128', 'hsa-miR-145', 'USF1'}
#
# DDX47
# GO:0070317
# set()
# GO:0051591
# {'JUN'}
# {'YY1', 'RAD21', 'CTCF', 'GATA2'}
#
# C5orf51
# GO:0070317
# set()
# GO:0051591
# {'SREBF1'}
# {'USF2', 'ELK4', 'SRF', 'USF1'}
#
# ZNF691
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'hsa-miR-125a-5p', 'NFYB', 'SP1', 'NFYA'}
#
# SLC15A4
# GO:0070317
# {'BRCA1'}
# GO:0051591
# set()
# {'TCF12', 'hsa-miR-124', 'ZBTB33', 'EBF1'}
#
# ZNF775
# GO:0070317
# set()
# GO:0051591
# {'SREBF1', 'FOS'}
# {'TCF4', 'NFYB', 'NFYA'}
#
# NUP107
# GO:0070317
# set()
# GO:0051591
# {'STAT1'}
# {'STAT3', 'NRF1', 'NR2C2', 'GABPA'}
#
# C20orf24
# GO:0070317
# set()
# GO:0051591
# {'JUND', 'JUN'}
# {'SPI1', 'RAD21', 'CTCF'}
#
# SAE1
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'USF2', 'MYC', 'CTCFL', 'USF1'}
#
# MCOLN1
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'USF2', 'ATF3', 'NFE2', 'USF1'}
#
# C1orf107
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'MYC', 'ATF3', 'ELK4', 'GATA2'}
#
# ATP5G1
# GO:0070317
# set()
# GO:0051591
# {'FOS', 'JUND', 'JUN'}
# {'NFYA', 'SP1'}
#
# ALDH1A1
# GO:0070317
# {'MAX'}
# GO:0051591
# {'JUN'}
# {'USF1', 'RAD21', 'CTCF'}
#
# hsa-miR-367*
# GO:0070317
# set()
# GO:0051591
# {'JUND', 'JUN'}
# {'BCL3', 'BCL11A', 'POU5F1', 'TAF7'}
#
# HES4
# GO:0070317
# {'E2F1', 'MAX', 'E2F6'}
# GO:0051591
# {'JUND', 'JUN'}
# {'ZBTB7A'}
#
# NPHP4
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'PBX3', 'NFYB', 'SP1', 'NFYA'}
#
# HSF2BP
# GO:0070317
# {'E2F1', 'MAX', 'E2F6'}
# GO:0051591
# set()
# {'MYC', 'TCF4'}
#
# FLJ45983
# GO:0070317
# {'SUZ12'}
# GO:0051591
# set()
# {'CTBP2', 'TCF12', 'RAD21', 'CTCF'}
#
# C13orf29
# GO:0070317
# set()
# GO:0051591
# {'FOS', 'JUND', 'JUN'}
# {'TFAP2C', 'TFAP2A'}
#
# MLF1IP
# GO:0070317
# set()
# GO:0051591
# {'JUND', 'JUN'}
# {'E2F4', 'NRF1', 'SP1', 'NR3C1'}
#
# THADA
# GO:0070317
# {'BRCA1', 'MAX'}
# GO:0051591
# {'JUND', 'JUN'}
# {'SIN3A', 'ZBTB33'}
#
# CABC1
# GO:0070317
# {'MAX', 'E2F6'}
# GO:0051591
# {'FOS'}
# {'NFYB', 'NFYA'}
#
# hsa-miR-302d*
# GO:0070317
# set()
# GO:0051591
# {'JUND', 'JUN'}
# {'BCL3', 'BCL11A', 'POU5F1', 'TAF7'}
#
# NOL11
# GO:0070317
# {'BRCA1'}
# GO:0051591
# set()
# {'ZBTB33', 'CTCFL', 'CTCF', 'CEBPB'}
#
# LONP1
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'USF2', 'ATF3', 'MYC', 'USF1'}
#
# BRD9
# GO:0070317
# {'E2F1'}
# GO:0051591
# set()
# {'MYC', 'SIN3A', 'E2F4', 'GABPA'}
#
# LSMD1
# GO:0070317
# {'BRCA1'}
# GO:0051591
# set()
# {'GATA1', 'ZBTB33', 'ETS1', 'GATA2'}
#
# ABCA3
# GO:0070317
# {'MAX', 'E2F6'}
# GO:0051591
# set()
# {'NRF1', 'CTCF', 'CTCFL'}
#
# HSPBAP1
# GO:0070317
# {'MAX', 'E2F6'}
# GO:0051591
# set()
# {'USF2', 'NFE2', 'USF1'}
#
# CPB2
# GO:0070317
# set()
# GO:0051591
# {'JUND', 'JUN'}
# {'TCF4', 'EP300', 'TAL1', 'MAFK'}
#
# DOCK10
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'MYC', 'hsa-miR-19a', 'EP300', 'CEBPB'}
#
# SARNP
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'IRF3', 'NFYB', 'SP1', 'NFYA'}
#
# CCDC123
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'E2F4', 'NFYB', 'SP1', 'NFYA'}
#
# HELQ
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'USF2', 'NRF1', 'GABPA', 'USF1'}
#
# FLJ31306
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'IRF3', 'NFYB', 'SP1', 'NFYA'}
#
# CDC5L
# GO:0070317
# {'BRCA1'}
# GO:0051591
# {'JUND', 'JUN'}
# {'NRF1', 'ZBTB33', 'ETS1'}
#
# C16orf74
# GO:0070317
# {'E2F1'}
# GO:0051591
# set()
# {'EP300', 'ESR1', 'CTCF', 'SPI1'}
#
# ZNF564
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'PBX3', 'NFYB', 'SP1', 'NFYA'}
#
# CREB3L4
# GO:0070317
# {'E2F1'}
# GO:0051591
# set()
# {'PBX3', 'NFYB', 'NFYA', 'FOXA1'}

# %%
GO_007={readout_gene : { edge[0] for edge in G.in_edges(readout_gene) if edge[0] in net.nodes()}for readout_gene in ["STYXL1","BRD9","ABCA3"]}
np.save('GO_007.npy',GO_007)

# %%
GO_007_005= {readout_gene :{ edge[0] for edge in G.in_edges(readout_gene) if edge[0] in net.nodes()}for readout_gene in ["ALDH1A1","ACAD9"]}
np.save('GO_007and005.npy',GO_007_005)

# %%
GO_005={readout_gene : { edge[0] for edge in G.in_edges(readout_gene)} for readout_gene in ["ZNF775","TMEM14C","C20orf111"]}
np.save('GO_005.npy',GO_005)

# %%
## Win test
res_size=207
in_size=1
i_scaling=1

# %%
matrix,dict_pos=build_adj_weighted_matrix(file,mapping_relabel)

# %%
Win=np.zeros((res_size,1+in_size))*i_scaling
Win[1,]

# %%
#print(GO_id_map["GO:0030220"])
for gene in GO_id_map["GO:0030220"]:
    print(dict_pos[gene])
    Win[dict_pos[gene],]=2
print(np.where(Win==2))

# %%
def input_matrix_just_genes_GOterm(Win,GOterm,GO_id_map):
    for gene in GO_id_map[GOterm]:
        Win[dict_pos[gene],]=np.random.uniform(0,1)
    return Win

# %%
Win=np.zeros((res_size,1+in_size))*i_scaling
input_matrix_just_genes_GOterm(Win,"GO:0030220",GO_id_map)

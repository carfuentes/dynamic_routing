# %%
import networkx as nx
import numpy as np
import os
import random as rand
from collections import defaultdict
import matplotlib.pyplot as plt

# %%
def get_r_dictionaries(file,mapping=True):
    with open(file, "r") as in_file:
        dict_map={}
        for line in in_file:
            line.strip()
            if mapping:
                dict_map[line.split()[1]]=line.split()[0]
            else:
                dict_map[line.split()[0]]=set(line.split()[1:])
    return dict_map

# %%
def get_cyclic_net(filename):
    G=nx.read_edgelist(filename, comments='#', delimiter="\t", nodetype =str,  data=(('mode',str),), create_using=nx.DiGraph())
    G.remove_nodes_from(["Source", "Target"])
    selfloops=G.selfloop_edges()
    G.remove_edges_from(G.selfloop_edges())

    while 0 in [d[1] for d in G.in_degree()] or 0 in [d[1] for d in G.out_degree()]:
        nodes_to_remove=[node for node in G if G.in_degree(node) == 0 or G.out_degree(node) == 0]
        G.remove_nodes_from(nodes_to_remove)
        
        
    selfloops_in_reservoir=[edge for edge in selfloops if edge[0] in G.nodes()]
    G.add_edges_from(selfloops_in_reservoir)

    return G

# %%
def build_adj_weighted_matrix(filename,mapping):
        #NETWORK v2.0
    net=get_cyclic_net(filename)
    nx.relabel_nodes(net,mapping,copy=False)
    dict_pos=dict((node,pos) for (pos,node) in enumerate(net.nodes()))
    for edge in net.edges(data="mode", default=0):
        source,target,mode=edge
        if mode== "+":
            net[source][target]["weight"]= abs(rand.gauss(0,1))
        elif mode== "-":
            net[source][target]["weight"]= rand.gauss(0,1)*-1
        elif mode== 0:
            net[source][target]["weight"]= rand.gauss(0,1)
        
    return nx.to_numpy_matrix(net),dict_pos

# %%
def write_nodes_file(out_file,filename,net):
    with open("%s_%s"%(out_file,filename),"w") as out:
        for gene in net.nodes():
            if "hsa" in gene:
                gene=gene[4:].lower()
            out.write(gene +"\n")

# %%
file="Dataset1/network_edge_list_ENCODE.csv"
net=get_cyclic_net("Dataset1/network_edge_list_ENCODE.csv")
G=nx.read_edgelist(file, comments='#', delimiter="\t", nodetype =str,  data=(('mode',str),), create_using=nx.DiGraph())

# %%
G.in_edges("TMEM14C")
# Out:
# InEdgeDataView([('SP1', 'TMEM14C'), ('NR3C1', 'TMEM14C'), ('SREBF1', 'TMEM14C'), ('MAFK', 'TMEM14C'), ('MAFF', 'TMEM14C')])

# %%
readout_to_cyclic=['ZNF775',
 'TMEM14C',
 'C20orf111',
 'STYXL1',
 'BRD9',
 'ABCA3',
 'ALDH1A1',
 'ACAD9']

# %%
input_nodes=[(go,readout) for go,set_readout in GO_id_map.items() for readout in set_readout ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-64eca7748b53> in <module>()
# ----> 1 input_nodes=[(go,readout) for go,set_readout in GO_id_map.items() for readout in set_readout ]
#
# NameError: name 'GO_id_map' is not defined

# %%
edges_readout=[edge for edge in G.edges() if edge[1] in readout_to_cyclic and edge[0] in net.nodes()]

# %%
edges_readout

# %%
net.add_edges_from(edges_readout)
net.add_edges_from(input_nodes)
nx.write_gexf(net, "test.gexf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-1443bc66cec6> in <module>()
# ----> 1 net.add_edges_from(edges_readout)
#       2 net.add_edges_from(input_nodes)
#       3 nx.write_gexf(net, "test.gexf")
#
# NameError: name 'edges_readout' is not defined

# %%
G.add_edges_from(input_nodes)
nx.write_gexf(G, "full.gexf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-f29cc4ac20b4> in <module>()
# ----> 1 G.add_edges_from(input_nodes)
#       2 nx.write_gexf(G, "full.gexf")
#
# NameError: name 'input_nodes' is not defined

# %%
readout_direct_targets=defaultdict(set)

for source, target in G.edges():
    if source in net.nodes() and target not in net.nodes():
        readout_direct_targets[source].add(target)

readout_direct_targets["MAX"]
    #print(target)
# Out:
# {'AATF',
#  'ABCA17P',
#  'ABCB4',
#  'ABCF1',
#  'ABCG1',
#  'AC011472.1',
#  'AC013553.1',
#  'AC044799.1',
#  'AC136618.1',
#  'ACAP1',
#  'ACTC1',
#  'ADAM19',
#  'ADAMTS16',
#  'ADH6',
#  'ADM',
#  'ADORA1',
#  'AFMID',
#  'AFP',
#  'AGFG2',
#  'AGT',
#  'AIMP2',
#  'AIP',
#  'AK2',
#  'AKR1A1',
#  'AKR1C1',
#  'AKR1C3',
#  'AKT1S1',
#  'ALB',
#  'ALDOC',
#  'ALG2',
#  'ALG3',
#  'ALOX15B',
#  'AMDHD2',
#  'AMN',
#  'AMPD3',
#  'ANAPC7',
#  'ANG',
#  'ANK1',
#  'ANKRD12',
#  'ANKRD30BL',
#  'ANO3',
#  'ANP32B',
#  'AOC3',
#  'AP1G2',
#  'AP1S1',
#  'AP2M1',
#  'AP4M1',
#  'APBB3',
#  'APEX1',
#  'APOBR',
#  'APOC1',
#  'APOC2',
#  'APOE',
#  'APOH',
#  'APRT',
#  'ARHGAP24',
#  'ARSK',
#  'ASGR1',
#  'ASGR2',
#  'ASPSCR1',
#  'ATL3',
#  'ATP13A4',
#  'ATP6V0B',
#  'ATP6V0D1',
#  'ATP8B1',
#  'ATXN3',
#  'BAT3',
#  'BAX',
#  'BCAS3',
#  'BCKDHA',
#  'BCL2',
#  'BCR',
#  'BIN1',
#  'BLOC1S3',
#  'BMP4',
#  'BOLA1',
#  'BPIL1',
#  'BST2',
#  'BUB3',
#  'C10orf116',
#  'C10orf18',
#  'C10orf46',
#  'C10orf76',
#  'C10orf88',
#  'C11orf59',
#  'C12orf24',
#  'C12orf49',
#  'C13orf23',
#  'C16orf5',
#  'C16orf54',
#  'C16orf73',
#  'C17orf86',
#  'C17orf87',
#  'C18orf19',
#  'C19orf24',
#  'C19orf47',
#  'C19orf48',
#  'C19orf70',
#  'C1R',
#  'C1S',
#  'C1orf107',
#  'C1orf110',
#  'C1orf212',
#  'C1orf43',
#  'C1orf51',
#  'C1orf55',
#  'C20orf12',
#  'C21orf49',
#  'C22orf29',
#  'C2CD4B',
#  'C2orf34',
#  'C3',
#  'C3orf17',
#  'C3orf26',
#  'C5orf33',
#  'C5orf4',
#  'C5orf41',
#  'C6orf108',
#  'C6orf211',
#  'C6orf52',
#  'C7orf13',
#  'C7orf40',
#  'C9orf156',
#  'C9orf43',
#  'C9orf86',
#  'CA5A',
#  'CABC1',
#  'CACNA2D4',
#  'CACNG1',
#  'CALCB',
#  'CAPG',
#  'CARD6',
#  'CASP14',
#  'CBX5',
#  'CC2D1B',
#  'CCDC103',
#  'CCDC116',
#  'CCDC47',
#  'CCDC86',
#  'CCDC99',
#  'CCL14',
#  'CCL22',
#  'CCND1',
#  'CCNJ',
#  'CCNT1',
#  'CCR7',
#  'CD164',
#  'CD19',
#  'CD248',
#  'CD37',
#  'CD4',
#  'CD7',
#  'CD70',
#  'CD79A',
#  'CD79B',
#  'CD82',
#  'CDH11',
#  'CDH15',
#  'CDK15',
#  'CDK4',
#  'CEACAM1',
#  'CEACAM21',
#  'CEACAM5',
#  'CENPF',
#  'CENPM',
#  'CENPP',
#  'CHI3L1',
#  'CHP',
#  'CKLF',
#  'CKS1B',
#  'CLCN6',
#  'CLCN7',
#  'CLDN5',
#  'CLEC17A',
#  'CLIP3',
#  'CLN3',
#  'CLUAP1',
#  'COL4A2',
#  'COL6A1',
#  'COL9A1',
#  'COL9A3',
#  'COMMD8',
#  'COPS7A',
#  'COQ4',
#  'CORO1A',
#  'CORO1C',
#  'CPN2',
#  'CPVL',
#  'CRCT1',
#  'CRKL',
#  'CRLF1',
#  'CSF1',
#  'CSTF3',
#  'CTNNA1',
#  'CTSH',
#  'CTU2',
#  'CUTA',
#  'CXCL16',
#  'CXCR4',
#  'CYP1B1',
#  'CYSLTR1',
#  'CYTIP',
#  'DAB2',
#  'DAK',
#  'DBP',
#  'DCAF17',
#  'DCN',
#  'DDR2',
#  'DDX21',
#  'DDX42',
#  'DENND1C',
#  'DERL3',
#  'DFFA',
#  'DGCR8',
#  'DHDDS',
#  'DHRS2',
#  'DHX35',
#  'DHX40',
#  'DKK3',
#  'DLK1',
#  'DMPK',
#  'DNAH14',
#  'DNAJB9',
#  'DNAJC11',
#  'DNAJC16',
#  'DNAJC30',
#  'DNAJC8',
#  'DNLZ',
#  'DOCK10',
#  'DOK7',
#  'DPAGT1',
#  'DPEP1',
#  'DSCR4',
#  'DSCR8',
#  'DUS3L',
#  'DUSP10',
#  'DUSP9',
#  'DVL2',
#  'DYM',
#  'DYNC1H1',
#  'DYRK1B',
#  'EAF2',
#  'EBI3',
#  'EBNA1BP2',
#  'ECD',
#  'ECE1',
#  'ECE2',
#  'EDN1',
#  'EFTUD2',
#  'EIF2B3',
#  'EIF3B',
#  'EIF3K',
#  'EIF4A1',
#  'EIF4E',
#  'EIF4EBP3',
#  'EIF4H',
#  'EIF5A2',
#  'ELOVL2',
#  'ELOVL3',
#  'EML4',
#  'EMR1',
#  'ENKUR',
#  'ENO1',
#  'ENOPH1',
#  'ENPP2',
#  'EPB41L2',
#  'EPO',
#  'EPS8L2',
#  'ERBB3',
#  'ERCC6',
#  'ERP29',
#  'ETFB',
#  'ETV4',
#  'EXD1',
#  'EXOSC5',
#  'FABP1',
#  'FABP3',
#  'FADS3',
#  'FAF1',
#  'FAM103A1',
#  'FAM111A',
#  'FAM118B',
#  'FAM126A',
#  'FAM129C',
#  'FAM183A',
#  'FAM21C',
#  'FAM65C',
#  'FAM70B',
#  'FAM76A',
#  'FAM78A',
#  'FARSB',
#  'FCER2',
#  'FCRL2',
#  'FCRL5',
#  'FGF21',
#  'FGFR3',
#  'FGL1',
#  'FJX1',
#  'FLAD1',
#  'FLG',
#  'FLJ39582',
#  'FN1',
#  'FNBP1',
#  'FNIP1',
#  'FOXF1',
#  'FTCD',
#  'FTSJD1',
#  'FUT3',
#  'FUT5',
#  'FUT6',
#  'FXYD1',
#  'FXYD3',
#  'FYB',
#  'G6PC',
#  'G6PC3',
#  'GABPB1',
#  'GALK2',
#  'GALNS',
#  'GAPDH',
#  'GCFC1',
#  'GET4',
#  'GFI1',
#  'GGA1',
#  'GGTLC2',
#  'GLDC',
#  'GLTPD2',
#  'GLTSCR2',
#  'GLYR1',
#  'GNB1L',
#  'GNG11',
#  'GNPDA2',
#  'GNS',
#  'GOLGA5',
#  'GP1BB',
#  'GPN3',
#  'GPR114',
#  'GPR132',
#  'GPR153',
#  'GPR162',
#  'GPR180',
#  'GPR37',
#  'GPR87',
#  'GPRC5C',
#  'GPX2',
#  'GRAMD1A',
#  'GRAMD3',
#  'GRK4',
#  'GTF2A1',
#  'GTF2H1',
#  'HAMP',
#  'HAVCR2',
#  'HBP1',
#  'HCLS1',
#  'HDGFRP2',
#  'HECW2',
#  'HELQ',
#  'HEPACAM',
#  'HES4',
#  'HIGD2A',
#  'HINFP',
#  'HIRA',
#  'HLCS',
#  'HLF',
#  'HLTF',
#  'HMOX2',
#  'HMSD',
#  'HNF1A',
#  'HNRNPA1',
#  'HNRNPF',
#  'HNRNPR',
#  'HNRPA1L-2',
#  'HNRPDL',
#  'HOXA3',
#  'HOXA4',
#  'HOXA7',
#  'HOXA9',
#  'HOXC5',
#  'HOXC6',
#  'HP',
#  'HPD',
#  'HPN',
#  'HPS5',
#  'HRC',
#  'HSD11B1L',
#  'HSD17B2',
#  'HSF2BP',
#  'HSP90AB1',
#  'HSPA9',
#  'HSPB3',
#  'HSPB6',
#  'HSPBAP1',
#  'HYAL1',
#  'HYOU1',
#  'IARS',
#  'IGFBP1',
#  'IGSF1',
#  'IKZF3',
#  'IL12RB1',
#  'IL13RA2',
#  'IL1RN',
#  'IL2RG',
#  'IL4I1',
#  'IL7R',
#  'ILF3',
#  'IMMP2L',
#  'INPPL1',
#  'INSIG2',
#  'IP6K1',
#  'IPO13',
#  'IPO4',
#  'IQCG',
#  'IRF8',
#  'IRX4',
#  'ISM2',
#  'ITFG2',
#  'ITGA5',
#  'ITGAL',
#  'ITGB1BP1',
#  'ITIH2',
#  'ITPR1',
#  'IVL',
#  'JHDM1D',
#  'JUP',
#  'KAL1',
#  'KAT5',
#  'KCNH4',
#  'KDM3A',
#  'KHDRBS1',
#  'KIAA0090',
#  'KIAA0391',
#  'KIAA0415',
#  'KIAA0748',
#  'KIAA0930',
#  'KIAA1199',
#  'KIAA1407',
#  'KIAA1530',
#  'KIAA1737',
#  'KIAA1919',
#  'KIAA1984',
#  'KIF2A',
#  'KLF1',
#  'KLF11',
#  'KLF9',
#  'KLHL12',
#  'KLHL22',
#  'KLK8',
#  'KRT17',
#  'KRTDAP',
#  'LACTB2',
#  'LAMA4',
#  'LAMP1',
#  'LAT',
#  'LBH',
#  'LCN15',
#  'LEMD3',
#  'LGALS7',
#  'LGALS7B',
#  'LGR5',
#  'LIPC',
#  'LOC100130581',
#  'LOC100289341',
#  'LOC147727',
#  'LOC283922',
#  'LOC284023',
#  'LOC388796',
#  'LOC401242',
#  'LOC648691',
#  'LONP1',
#  'LOXL1',
#  'LRG1',
#  'LRPPRC',
#  'LRRC32',
#  'LRRC61',
#  'LSR',
#  'LY86',
#  'LYL1',
#  'LYPD6B',
#  'LYZ',
#  'LZTFL1',
#  'LZTR1',
#  'MAB21L1',
#  'MAGEA9',
#  'MAGEC2',
#  'MAMSTR',
#  'MAN1B1',
#  'MAN1C1',
#  'MAP1D',
#  'MAPK1',
#  'MARCH8',
#  'MBNL3',
#  'MCCC1',
#  'MCOLN1',
#  'MDN1',
#  'MEST',
#  'METTL1',
#  'METTL7B',
#  'METTL8',
#  'MFAP1',
#  'MFAP3L',
#  'MGA',
#  'MGST2',
#  'MLF1',
#  'MMD',
#  'MOGAT2',
#  'MOGAT3',
#  'MPP6',
#  'MRGPRF',
#  'MRPL40',
#  'MRPL45',
#  'MRPS18C',
#  'MRTO4',
#  'MSC',
#  'MSH5',
#  'MST1',
#  'MTHFD2',
#  'MTHFR',
#  'MTRNR2L4',
#  'MTTP',
#  'MYBPH',
#  'MYEOV',
#  'MYH14',
#  'MYL2',
#  'MYLPF',
#  'MYO16',
#  'MYO3B',
#  'MYO7A',
#  'MYOG',
#  'N6AMT1',
#  'NAPA',
#  'NAPSA',
#  'NAT10',
#  'NBPF1',
#  'NCAM1',
#  'NCL',
#  'NDRG2',
#  'NDUFA4',
#  'NEK3',
#  'NEK6',
#  'NFX1',
#  'NHLRC3',
#  'NKD1',
#  'NLE1',
#  'NME1',
#  'NME1-NME2',
#  'NMRAL1',
#  'NMU',
#  'NNMT',
#  'NOC3L',
#  'NOL7',
#  'NOL8',
#  'NOM1',
#  'NOP10',
#  'NOP14',
#  'NOP16',
#  'NOTUM',
#  'NPIP',
#  'NR0B2',
#  'NR1D1',
#  'NR1D2',
#  'NR5A1',
#  'NRBF2',
#  'NSUN5',
#  'NTF3',
#  'NUCB2',
#  'NUDT1',
#  'NUP205',
#  'NUP214',
#  'NUP62',
#  'ODC1',
#  'OPA1',
#  'OPTN',
#  'ORMDL3',
#  'OSGEP',
#  'P2RY8',
#  'PACRGL',
#  'PADI2',
#  'PAICS',
#  'PAK1IP1',
#  'PARVG',
#  'PCDHB5',
#  'PCYT1B',
#  'PDCD6IP',
#  'PDE12',
#  'PDE4D',
#  'PDGFRA',
#  'PDGFRB',
#  'PDIA4',
#  'PECR',
#  'PES1',
#  'PGK1',
#  'PHF19',
#  'PHF20',
#  'PI4KA',
#  'PIGZ',
#  'PIK3R3',
#  'PIK3R5',
#  'PIP5K1A',
#  'PLCG2',
#  'PLD3',
#  'PLD6',
#  'PLEKHA6',
#  'PNO1',
#  'PNPO',
#  'POLE4',
#  'POLR2E',
#  'POLR2J3',
#  'POLR3F',
#  'POSTN',
#  'PPA1',
#  'PPAN-P2RY11',
#  'PPAT',
#  'PPFIA4',
#  'PPIA',
#  'PPID',
#  'PPIL2',
#  'PPP2R3C',
#  'PPP2R5C',
#  'PRAME',
#  'PREPL',
#  'PRMT1',
#  'PRODH2',
#  'PRR15L',
#  'PSG5',
#  'PSMD9',
#  'PSME3',
#  'PTBP1',
#  'PTGIR',
#  'PTGS1',
#  'PTP4A2',
#  'PTPN7',
#  'PUS7',
#  'QKI',
#  'QSOX1',
#  'QTRT1',
#  'QTRTD1',
#  'RAB17',
#  'RAB34',
#  'RAB36',
#  'RAB3IL1',
#  'RAB42',
#  'RAB42P1',
#  'RAD23A',
#  'RAD9A',
#  'RAD9B',
#  'RAET1E',
#  'RAI14',
#  'RAMP2',
#  'RANBP1',
#  'RAPGEF1',
#  'RASAL3',
#  'RASGRP1',
#  'RBBP4',
#  'RBBP5',
#  'RBM15',
#  'RBP4',
#  'RBPJ',
#  'RCCD1',
#  'REPIN1',
#  'RFC1',
#  'RFTN1',
#  'RGS1',
#  'RGS13',
#  'RGS16',
#  'RHBDL1',
#  'RHBG',
#  'RIBC2',
#  'RIOK2',
#  'RMND1',
#  'RMRP',
#  'RNASE1',
#  'RNASE4',
#  'RNASEH2A',
#  'RNASET2',
#  'RNF130',
#  'RNF166',
#  'RNF32',
#  'RNFT2',
#  'RNMT',
#  'ROCK1P1',
#  'RP11-1212A22.4',
#  'RP11-35N6.1',
#  'RP11-383H13.1',
#  'RPA2',
#  'RPL10A',
#  'RPL12',
#  'RPL13A',
#  'RPL14',
#  'RPL21',
#  'RPL21P28',
#  'RPL23A',
#  'RPL32',
#  'RPL35A',
#  'RPS12',
#  'RPS8',
#  'RPSA',
#  'RPUSD4',
#  'RRAGD',
#  'RRAS2',
#  'RRP1',
#  'RRP1B',
#  'S100PBP',
#  'SAE1',
#  'SAMSN1',
#  'SBSN',
#  'SCAMP3',
#  'SCAND3',
#  'SCARNA2',
#  'SCFD2',
#  'SCN5A',
#  'SDF2L1',
#  'SDR42E1',
#  'SEC1',
#  'SEC61B',
#  'SELL',
#  'SEPHS2',
#  'SEPP1',
#  'SERF2',
#  'SERPINB10',
#  'SERPINC1',
#  'SERPINE2',
#  'SERPINF1',
#  'SERPINF2',
#  'SETD6',
#  'SFRP1',
#  'SFRS13A',
#  'SFRS18',
#  'SFRS2IP',
#  'SFRS7',
#  'SGCD',
#  'SGK1',
#  'SGOL1',
#  'SGPL1',
#  'SGPP2',
#  'SGTA',
#  'SHC1',
#  'SHD',
#  'SHISA9',
#  'SIRPB1',
#  'SIRT1',
#  'SKAP1',
#  'SLC13A3',
#  'SLC13A5',
#  'SLC16A1',
#  'SLC17A9',
#  'SLC25A1',
#  'SLC2A5',
#  'SLC35A4',
#  'SLC35A5',
#  'SLC39A5',
#  'SLC3A2',
#  'SLC40A1',
#  'SLC7A5P1',
#  'SLC7A5P2',
#  'SLCO4A1',
#  'SMC1B',
#  'SNAP29',
#  'SNHG1',
#  'SNHG7',
#  'SNORA76',
#  'SNORD104',
#  'SNORD55',
#  'SNRPA',
#  'SNX20',
#  'SNX5',
#  'SOAT2',
#  'SOCS5',
#  'SORL1',
#  'SP5',
#  'SPN',
#  'SPNS1',
#  'SPON2',
#  'SPOP',
#  'SPRYD4',
#  'SRP19',
#  'ST8SIA2',
#  'STAM',
#  'STAR',
#  'STAT5A',
#  'STK25',
#  'STMN1',
#  'SUB1',
#  'SULT1A1',
#  'SULT1A2',
#  'SULT1A3',
#  'SULT1A4',
#  'SULT2A1',
#  'SUMF1',
#  'SUPV3L1',
#  'TAF12',
#  'TAF4B',
#  'TAGLN',
#  'TAOK2',
#  'TASP1',
#  'TBC1D15',
#  'TBC1D16',
#  'TBC1D17',
#  'TBCB',
#  'TBX2',
#  'TBX4',
#  'TCERG1',
#  'TDG',
#  'TESC',
#  'TFEB',
#  'THADA',
#  'THAP5',
#  'THAP7',
#  'THAP8',
#  'THBS1',
#  'THNSL1',
#  'TIMM13',
#  'TINAGL1',
#  'TLCD1',
#  'TLK1',
#  'TM4SF5',
#  'TM9SF4',
#  'TMC8',
#  'TMED1',
#  'TMEM116',
#  'TMEM146',
#  'TMEM194A',
#  'TMEM233',
#  'TMEM37',
#  'TMEM40',
#  'TMEM42',
#  'TMEM48',
#  'TMEM55B',
#  'TNFRSF1A',
#  'TNFRSF9',
#  'TNNI3',
#  'TNPO2',
#  'TNS3',
#  'TOR1A',
#  'TPM1',
#  'TRA2A',
#  'TRAPPC2L',
#  'TRIM50',
#  'TRIM55',
#  'TRIM59',
#  'TRIM61',
#  'TRIM73',
#  'TRMT2A',
#  'TRUB2',
#  'TSN',
#  'TSNAX',
#  'TSNAX-DISC1',
#  'TTC37',
#  'TTC39B',
#  'TTR',
#  'TUBB1',
#  'TUBGCP2',
#  'TXNRD1',
#  'TXNRD2',
#  'TYROBP',
#  'UBA52',
#  'UBAC1',
#  'UBAP2',
#  'UBAP2L',
#  'UBASH3A',
#  'UBE2B',
#  'UBE2G2',
#  'UBE2Q1',
#  'UBE2S',
#  'UBXN11',
#  'URB2',
#  'USP14',
#  'USP20',
#  'USP36',
#  'UTP11L',
#  'VARS',
#  'VIM',
#  'VPS29',
#  'VSNL1',
#  'WDR36',
#  'WDR4',
#  'WDR62',
#  'WDR65',
#  'WDR74',
#  'WDR81',
#  'WDR89',
#  'WDR90',
#  'WDR92',
#  'WFDC1',
#  'WNT7A',
#  'XIRP1',
#  'XKR9',
#  'YBX1',
#  'YDJC',
#  'YPEL1',
#  'ZBTB40',
#  'ZC3H10',
#  'ZCCHC7',
#  'ZCWPW1',
#  'ZFR',
#  'ZFYVE27',
#  'ZIK1',
#  'ZIM2',
#  'ZKSCAN2',
#  'ZMYND8',
#  'ZNF239',
#  'ZNF280A',
#  'ZNF280D',
#  'ZNF292',
#  'ZNF3',
#  'ZNF628',
#  'ZNF692',
#  'ZNF74',
#  'ZNF785',
#  'ZNF84',
#  'hsa-miR-17*',
#  'hsa-miR-18a*',
#  'hsa-miR-19a*',
#  'hsa-miR-19b',
#  'hsa-miR-19b-1*',
#  'hsa-miR-20a*',
#  'hsa-miR-663b',
#  'hsa-miR-92a-1*'}

# %%
len(set(net["SRF"]))
# Out:
# 12

# %%
len(net.out_edges("SRF"))
# Out:
# 12

# %%
len(set.union(*readout_direct_targets.values()))
# Out:
# 13389

# %%
filename=file[file.index("list")+5:file.index(".csv")]

# %%
write_nodes_file("all_gene",filename,G)

# %%
len(net.nodes())
# Out:
# 215

# %%
## Get R dictionaries
## GO term -> set ids
GO_id_map=get_r_dictionaries("test.txt",mapping=False)
#print(GO_id_map)

## id to ENTREZ id
edgeid_ezid_map=get_r_dictionaries("mapping_id_to_entrez.txt")
print(edgeid_ezid_map)
# Out:
# {'5669': 'SP1', '6667': 'SP1', '199699': 'SP1', '6668': 'SP2', '2623': 'GATA1', '672': 'BRCA1', '3172': 'HNF4A', '1876': 'E2F6', '406920': 'hsa-miR-130b', '4208': 'MEF2C', '140690': 'CTCFL', '5452': 'POU2F2', '406982': 'hsa-miR-20a', '406953': 'hsa-miR-18a', '7702': 'ZNF143', '23462': 'HEY1', '6721': 'SREBF2', '25942': 'SIN3A', '2355': 'FOSL2', '53335': 'BCL11A', '7182': 'NR2C2', '147912': 'SIX5', '4149': 'MAX', '4601': 'MXI1', '10891': 'PPARGC1A', '4801': 'NFYB', '1958': 'EGR1', '1051': 'CEBPB', '5993': 'RFX5', '6688': 'SPI1', '9774': 'BCLAF1', '6938': 'TCF12', '639': 'PRDM1', '3066': 'HDAC2', '6256': 'RXRA', '4779': 'NRF1', '4899': 'NRF1', '6886': 'TAL1', '6925': 'TCF4', '6934': 'TCF4', '2099': 'ESR1', '905': 'CCNT2', '10664': 'CTCF', '5090': 'PBX3', '11128': 'POLR3A', '10009': 'ZBTB33', '3659': 'IRF1', '2033': 'EP300', '2113': 'ETS1', '2908': 'NR3C1', '51341': 'ZBTB7A', '1869': 'E2F1', '6722': 'SRF', '3661': 'IRF3', '2353': 'FOS', '8061': 'FOSL1', '3726': 'JUNB', '10535': 'JUNB', '6599': 'SMARCC1', '1879': 'EBF1', '4800': 'NFYA', '1106': 'CHD2', '1826': 'CHD2', '6908': 'TBP', '2551': 'GABPA', '1488': 'CTBP2', '3727': 'JUND', '6597': 'SMARCA4', '3662': 'IRF4', '3174': 'HNF4G', '3169': 'FOXA1', '4778': 'NFE2', '7936': 'RDBP', '6773': 'STAT2', '2005': 'ELK4', '406903': 'hsa-miR-10b', '26469': 'BDP1', '55814': 'BDP1', '7392': 'USF2', '23512': 'SUZ12', '678': 'BRF2', '55290': 'BRF2', '7391': 'USF1', '1874': 'E2F4', '6935': 'ZEB1', '4205': 'MEF2A', '602': 'BCL3', '574455': 'hsa-miR-193b', '8553': 'BHLHE40', '7022': 'TFAP2C', '10538': 'BATF', '2624': 'GATA2', '10155': 'TRIM28', '4790': 'NFKB1', '442904': 'hsa-miR-335', '5460': 'POU5F1', '51548': 'SIRT6', '100302232': 'hsa-miR-1226', '100302201': 'hsa-miR-1228', '7020': 'TFAP2A', '2959': 'GTF2B', '4609': 'MYC', '5820': 'MYC', '5079': 'PAX5', '3725': 'JUN', '3170': 'FOXA2', '7975': 'MAFK', '7528': 'YY1', '467': 'ATF3', '406998': 'hsa-miR-216a', '100126319': 'hsa-miR-216b', '407029': 'hsa-miR-30a', '406936': 'hsa-miR-144', '406999': 'hsa-miR-217', '6601': 'SMARCC2', '100126348': 'hsa-miR-760', '6772': 'STAT1', '406942': 'hsa-miR-150', '442900': 'hsa-miR-326', '406884': 'hsa-let-7b', '494324': 'hsa-miR-375', '406919': 'hsa-miR-130a', '442895': 'hsa-miR-302c', '407028': 'hsa-miR-302a', '100302143': 'hsa-miR-1248', '693158': 'hsa-miR-573', '406947': 'hsa-miR-155', '406921': 'hsa-miR-132', '693174': 'hsa-miR-589', '5885': 'RAD21', '23764': 'MAFF', '6720': 'SREBF1', '3297': 'HSF1', '6774': 'STAT3', '6879': 'TAF7', '10127': 'ZNF263', '56897': 'WRNIP1', '406985': 'hsa-miR-200c', '407011': 'hsa-miR-23b', '406994': 'hsa-miR-212', '1997': 'ELF1', '84337': 'ELF1', '9126': 'SMC3', '768218': 'hsa-miR-766', '574456': 'hsa-miR-497', '442891': 'hsa-miR-135b', '619553': 'hsa-miR-484', '6598': 'SMARCB1', '406902': 'hsa-miR-10a', '100126340': 'hsa-miR-944'}

# %%
## Primero: Hay que cambiarle el id del res al id de ENTREZ
## hay que hacer un mapping dictionary con la info que tenemos de los nodos de GO.term
##Como no todos están anotados es mejor crear un diccionario 
mapping_relabel = edgeid_ezid_map
for node in net.nodes():
    if node not in edgeid_ezid_map.values():
        mapping_relabel[node]=node
mapping_relabel
# Out:
# {'10009': 'ZBTB33',
#  '100126319': 'hsa-miR-216b',
#  '100126340': 'hsa-miR-944',
#  '100126348': 'hsa-miR-760',
#  '100302143': 'hsa-miR-1248',
#  '100302201': 'hsa-miR-1228',
#  '100302232': 'hsa-miR-1226',
#  '10127': 'ZNF263',
#  '10155': 'TRIM28',
#  '1051': 'CEBPB',
#  '10535': 'JUNB',
#  '10538': 'BATF',
#  '10664': 'CTCF',
#  '10891': 'PPARGC1A',
#  '1106': 'CHD2',
#  '11128': 'POLR3A',
#  '140690': 'CTCFL',
#  '147912': 'SIX5',
#  '1488': 'CTBP2',
#  '1826': 'CHD2',
#  '1869': 'E2F1',
#  '1874': 'E2F4',
#  '1876': 'E2F6',
#  '1879': 'EBF1',
#  '1958': 'EGR1',
#  '199699': 'SP1',
#  '1997': 'ELF1',
#  '2005': 'ELK4',
#  '2033': 'EP300',
#  '2099': 'ESR1',
#  '2113': 'ETS1',
#  '23462': 'HEY1',
#  '23512': 'SUZ12',
#  '2353': 'FOS',
#  '2355': 'FOSL2',
#  '23764': 'MAFF',
#  '2551': 'GABPA',
#  '25942': 'SIN3A',
#  '2623': 'GATA1',
#  '2624': 'GATA2',
#  '26469': 'BDP1',
#  '2908': 'NR3C1',
#  '2959': 'GTF2B',
#  '3066': 'HDAC2',
#  '3169': 'FOXA1',
#  '3170': 'FOXA2',
#  '3172': 'HNF4A',
#  '3174': 'HNF4G',
#  '3297': 'HSF1',
#  '3659': 'IRF1',
#  '3661': 'IRF3',
#  '3662': 'IRF4',
#  '3725': 'JUN',
#  '3726': 'JUNB',
#  '3727': 'JUND',
#  '406884': 'hsa-let-7b',
#  '406902': 'hsa-miR-10a',
#  '406903': 'hsa-miR-10b',
#  '406919': 'hsa-miR-130a',
#  '406920': 'hsa-miR-130b',
#  '406921': 'hsa-miR-132',
#  '406936': 'hsa-miR-144',
#  '406942': 'hsa-miR-150',
#  '406947': 'hsa-miR-155',
#  '406953': 'hsa-miR-18a',
#  '406982': 'hsa-miR-20a',
#  '406985': 'hsa-miR-200c',
#  '406994': 'hsa-miR-212',
#  '406998': 'hsa-miR-216a',
#  '406999': 'hsa-miR-217',
#  '407011': 'hsa-miR-23b',
#  '407028': 'hsa-miR-302a',
#  '407029': 'hsa-miR-30a',
#  '4149': 'MAX',
#  '4205': 'MEF2A',
#  '4208': 'MEF2C',
#  '442891': 'hsa-miR-135b',
#  '442895': 'hsa-miR-302c',
#  '442900': 'hsa-miR-326',
#  '442904': 'hsa-miR-335',
#  '4601': 'MXI1',
#  '4609': 'MYC',
#  '467': 'ATF3',
#  '4778': 'NFE2',
#  '4779': 'NRF1',
#  '4790': 'NFKB1',
#  '4800': 'NFYA',
#  '4801': 'NFYB',
#  '4899': 'NRF1',
#  '494324': 'hsa-miR-375',
#  '5079': 'PAX5',
#  '5090': 'PBX3',
#  '51341': 'ZBTB7A',
#  '51548': 'SIRT6',
#  '53335': 'BCL11A',
#  '5452': 'POU2F2',
#  '5460': 'POU5F1',
#  '55290': 'BRF2',
#  '55814': 'BDP1',
#  '5669': 'SP1',
#  '56897': 'WRNIP1',
#  '574455': 'hsa-miR-193b',
#  '574456': 'hsa-miR-497',
#  '5820': 'MYC',
#  '5885': 'RAD21',
#  '5993': 'RFX5',
#  '602': 'BCL3',
#  '619553': 'hsa-miR-484',
#  '6256': 'RXRA',
#  '639': 'PRDM1',
#  '6597': 'SMARCA4',
#  '6598': 'SMARCB1',
#  '6599': 'SMARCC1',
#  '6601': 'SMARCC2',
#  '6667': 'SP1',
#  '6668': 'SP2',
#  '6688': 'SPI1',
#  '672': 'BRCA1',
#  '6720': 'SREBF1',
#  '6721': 'SREBF2',
#  '6722': 'SRF',
#  '6772': 'STAT1',
#  '6773': 'STAT2',
#  '6774': 'STAT3',
#  '678': 'BRF2',
#  '6879': 'TAF7',
#  '6886': 'TAL1',
#  '6908': 'TBP',
#  '6925': 'TCF4',
#  '693158': 'hsa-miR-573',
#  '693174': 'hsa-miR-589',
#  '6934': 'TCF4',
#  '6935': 'ZEB1',
#  '6938': 'TCF12',
#  '7020': 'TFAP2A',
#  '7022': 'TFAP2C',
#  '7182': 'NR2C2',
#  '7391': 'USF1',
#  '7392': 'USF2',
#  '7528': 'YY1',
#  '768218': 'hsa-miR-766',
#  '7702': 'ZNF143',
#  '7936': 'RDBP',
#  '7975': 'MAFK',
#  '8061': 'FOSL1',
#  '84337': 'ELF1',
#  '8553': 'BHLHE40',
#  '905': 'CCNT2',
#  '9126': 'SMC3',
#  '9774': 'BCLAF1',
#  'ABCA3': 'ABCA3',
#  'ACAD9': 'ACAD9',
#  'ALDH1A1': 'ALDH1A1',
#  'BRD9': 'BRD9',
#  'C20orf111': 'C20orf111',
#  'STYXL1': 'STYXL1',
#  'TMEM14C': 'TMEM14C',
#  'ZNF775': 'ZNF775',
#  'hsa-let-7a': 'hsa-let-7a',
#  'hsa-miR-1': 'hsa-miR-1',
#  'hsa-miR-101': 'hsa-miR-101',
#  'hsa-miR-1205': 'hsa-miR-1205',
#  'hsa-miR-1207-3p': 'hsa-miR-1207-3p',
#  'hsa-miR-1207-5p': 'hsa-miR-1207-5p',
#  'hsa-miR-1208': 'hsa-miR-1208',
#  'hsa-miR-124': 'hsa-miR-124',
#  'hsa-miR-1245': 'hsa-miR-1245',
#  'hsa-miR-125a-3p': 'hsa-miR-125a-3p',
#  'hsa-miR-125a-5p': 'hsa-miR-125a-5p',
#  'hsa-miR-1260': 'hsa-miR-1260',
#  'hsa-miR-1279': 'hsa-miR-1279',
#  'hsa-miR-128': 'hsa-miR-128',
#  'hsa-miR-129-3p': 'hsa-miR-129-3p',
#  'hsa-miR-129-5p': 'hsa-miR-129-5p',
#  'hsa-miR-133a': 'hsa-miR-133a',
#  'hsa-miR-135a': 'hsa-miR-135a',
#  'hsa-miR-142-3p': 'hsa-miR-142-3p',
#  'hsa-miR-142-5p': 'hsa-miR-142-5p',
#  'hsa-miR-145': 'hsa-miR-145',
#  'hsa-miR-153': 'hsa-miR-153',
#  'hsa-miR-17': 'hsa-miR-17',
#  'hsa-miR-185': 'hsa-miR-185',
#  'hsa-miR-191': 'hsa-miR-191',
#  'hsa-miR-192': 'hsa-miR-192',
#  'hsa-miR-193a-3p': 'hsa-miR-193a-3p',
#  'hsa-miR-194': 'hsa-miR-194',
#  'hsa-miR-196a': 'hsa-miR-196a',
#  'hsa-miR-199b-5p': 'hsa-miR-199b-5p',
#  'hsa-miR-19a': 'hsa-miR-19a',
#  'hsa-miR-219-5p': 'hsa-miR-219-5p',
#  'hsa-miR-22': 'hsa-miR-22',
#  'hsa-miR-24': 'hsa-miR-24',
#  'hsa-miR-25': 'hsa-miR-25',
#  'hsa-miR-27b': 'hsa-miR-27b',
#  'hsa-miR-29b': 'hsa-miR-29b',
#  'hsa-miR-300': 'hsa-miR-300',
#  'hsa-miR-330-3p': 'hsa-miR-330-3p',
#  'hsa-miR-338-3p': 'hsa-miR-338-3p',
#  'hsa-miR-338-5p': 'hsa-miR-338-5p',
#  'hsa-miR-339-5p': 'hsa-miR-339-5p',
#  'hsa-miR-365': 'hsa-miR-365',
#  'hsa-miR-367': 'hsa-miR-367',
#  'hsa-miR-376a': 'hsa-miR-376a',
#  'hsa-miR-483-3p': 'hsa-miR-483-3p',
#  'hsa-miR-548c-3p': 'hsa-miR-548c-3p',
#  'hsa-miR-549': 'hsa-miR-549',
#  'hsa-miR-564': 'hsa-miR-564',
#  'hsa-miR-567': 'hsa-miR-567',
#  'hsa-miR-595': 'hsa-miR-595',
#  'hsa-miR-612': 'hsa-miR-612',
#  'hsa-miR-615-5p': 'hsa-miR-615-5p',
#  'hsa-miR-626': 'hsa-miR-626',
#  'hsa-miR-632': 'hsa-miR-632',
#  'hsa-miR-636': 'hsa-miR-636',
#  'hsa-miR-638': 'hsa-miR-638',
#  'hsa-miR-645': 'hsa-miR-645',
#  'hsa-miR-648': 'hsa-miR-648',
#  'hsa-miR-650': 'hsa-miR-650',
#  'hsa-miR-657': 'hsa-miR-657',
#  'hsa-miR-661': 'hsa-miR-661',
#  'hsa-miR-663': 'hsa-miR-663',
#  'hsa-miR-7': 'hsa-miR-7',
#  'hsa-miR-9': 'hsa-miR-9',
#  'hsa-miR-92a': 'hsa-miR-92a',
#  'hsa-miR-93': 'hsa-miR-93'}

# %%
for key,values in GO_id_map.items():
    GO_id_map[key]=set([mapping_relabel[value] for value in values])
GO_id_map
# Out:
# {'GO:0006337': {'NFE2', 'SMARCA4', 'SMARCB1', 'SMARCC1', 'SMARCC2'},
#  'GO:0030220': {'EP300', 'GATA1', 'MEF2C', 'SRF', 'TAL1'},
#  'GO:0043923': {'EP300', 'JUN', 'SMARCA4', 'SMARCB1', 'SP1'},
#  'GO:1901984': {'BRCA1', 'HDAC2', 'SIN3A', 'SPI1', 'TAF7'}}

# %%
set.union(*GO_id_map.values())
# Out:
# {'BRCA1',
#  'E2F1',
#  'E2F6',
#  'FOS',
#  'FOSL1',
#  'JUN',
#  'JUNB',
#  'JUND',
#  'MAX',
#  'SREBF1',
#  'STAT1',
#  'SUZ12'}

# %%
readout_common=set(gene for gene_res in set.union(*GO_id_map.values()) for gene in set(G[gene_res]) if gene in set.union(*readout_direct_targets.values()) )

# %%
readout_common
# Out:
# {'SPTBN1',
#  'WDR25',
#  'AC136618.1',
#  'MYL6B',
#  'NSUN5',
#  'LRMP',
#  'CCNB1IP1',
#  'APEX1',
#  'RPS6',
#  'ODF3B',
#  'C21orf29',
#  'NXPH1',
#  'FUT10',
#  'ASAP2',
#  'WHSC1',
#  'SEPHS2',
#  'LEPROT',
#  'SNORD114-24',
#  'PPP2CA',
#  'ARHGDIA',
#  'HNRNPUL1',
#  'SYCE2',
#  'ATL3',
#  'C17orf86',
#  'HAUS2',
#  'CREB5',
#  'UBXN4',
#  'SCFD1',
#  'RANBP9',
#  'CSRNP1',
#  'ACLY',
#  'SEH1L',
#  'LMBRD2',
#  'KIAA1468',
#  'ILF2',
#  'ACAD9',
#  'NTF3',
#  'IRX1',
#  'SPATA12',
#  'PRH1',
#  'GSG2',
#  'ERCC1',
#  'PURA',
#  'TUFT1',
#  'RHOXF2B',
#  'COL2A1',
#  'OSR1',
#  'HIST1H2BF',
#  'MT1M',
#  'RASSF7',
#  'LOC100289341',
#  'CHL1',
#  'ZBTB11',
#  'CLDN5',
#  'ANKRD16',
#  'SEC22B',
#  'P2RY11',
#  'CT62',
#  'WASF2',
#  'TOX4',
#  'AMOTL2',
#  'C19orf40',
#  'KIF5C',
#  'LTB4R2',
#  'DBP',
#  'RRAS2',
#  'PRKAG2',
#  'NRBF2',
#  'ELOVL3',
#  'TRAPPC6B',
#  'PLD1',
#  'RIBC2',
#  'OLA1',
#  'RAN',
#  'CACNA1E',
#  'GSDMD',
#  'JMJD8',
#  'CCR7',
#  'hsa-miR-130b*',
#  'hsa-miR-155*',
#  'PRKDC',
#  'GSR',
#  'FOXG1',
#  'CD70',
#  'AGGF1',
#  'TLR1',
#  'MEX3D',
#  'DNM2',
#  'hsa-miR-302d',
#  'POU3F3',
#  'EPB49',
#  'ERBB3',
#  'PPP2R3C',
#  'KAL1',
#  'HSPB6',
#  'PCNAAS',
#  'C1orf43',
#  'KPNB1',
#  'MX1',
#  'KIAA1683',
#  'GOLGA5',
#  'LTBP2',
#  'COMMD8',
#  'TEX15',
#  'SNHG3',
#  'NCRNA00263',
#  'TTC1',
#  'TNFRSF8',
#  'NBPF1',
#  'ZNF286A',
#  'HLA-E',
#  'SNORD35A',
#  'RNASEK',
#  'NFKBIA',
#  'FGL1',
#  'TMEM188',
#  'FANCD2',
#  'CECR5',
#  'HELB',
#  'CECR4',
#  'C9orf156',
#  'DDX31',
#  'UCKL1',
#  'MYB',
#  'CXADR',
#  'hsa-miR-611',
#  'SERPINB13',
#  'EIF4A1',
#  'LAMA3',
#  'MYO3B',
#  'CHCHD3',
#  'GPR109A',
#  'CDK12',
#  'UFD1L',
#  'PRMT8',
#  'CD83',
#  'hsa-miR-219-2-3p',
#  'GPCPD1',
#  'IFIT3',
#  'DPYSL3',
#  'TYMS',
#  'WDR62',
#  'MOGAT2',
#  'PDE3B',
#  'USP1',
#  'CD79A',
#  'UBC',
#  'TEAD1',
#  'AP4M1',
#  'GGA1',
#  'CDKN1B',
#  'HOXC5',
#  'hsa-miR-26b*',
#  'HIST1H1A',
#  'PUS7',
#  'HOXA1',
#  'LHX1',
#  'DMRT3',
#  'MAPRE2',
#  'HYOU1',
#  'RPL31',
#  'CD19',
#  'FBXO33',
#  'GCC1',
#  'UBR4',
#  'SERPINB3',
#  'ITGB5',
#  'KLK6',
#  'ACOT8',
#  'PAX1',
#  'ENSA',
#  'CBX3',
#  'EPB41L5',
#  'ISG15',
#  'FLJ42709',
#  'LOC152225',
#  'WDR34',
#  'IMMP2L',
#  'OPA1',
#  'DUSP1',
#  'GMPR2',
#  'CORO1C',
#  'AGT',
#  'LRRC8A',
#  'PARP16',
#  'RHOB',
#  'UPK2',
#  'RP4-788L13.1',
#  'NAT9',
#  'SLC39A7',
#  'POLE',
#  'RPS19',
#  'APOH',
#  'SLC46A3',
#  'GRAMD1A',
#  'MOSC1',
#  'FOXD4L1',
#  'SLC17A9',
#  'NKX2-5',
#  'SNX20',
#  'NGDN',
#  'OAS1',
#  'hsa-miR-124*',
#  'RGS13',
#  'C3orf58',
#  'SNORD33',
#  'RAB42P1',
#  'PTEN',
#  'STAM',
#  'DPAGT1',
#  'TMC8',
#  'MARCH7',
#  'ESF1',
#  'FOXB2',
#  'SAE1',
#  'TMPO',
#  'DOCK5',
#  'PWWP2A',
#  'TDG',
#  'NFATC2IP',
#  'EPO',
#  'RAB4B',
#  'SERPINF2',
#  'CCL3',
#  'ALDH1A1',
#  'PARP2',
#  'SLBP',
#  'SIX6',
#  'RPL35A',
#  'DENR',
#  'TMEM37',
#  'FXYD1',
#  'IQCE',
#  'LOC440925',
#  'FKBP1A',
#  'EOMES',
#  'C11orf86',
#  'SLC2A5',
#  'EIF4E',
#  'LEMD3',
#  'MT1DP',
#  'ANKFY1',
#  'FUBP1',
#  'HOXA11',
#  'GAGE2C',
#  'HIST2H2AC',
#  'CTDSPL2',
#  'RPS2',
#  'COX7B',
#  'UNG',
#  'TTC18',
#  'NNMT',
#  'LOC100188947',
#  'C1orf212',
#  'ACOT1',
#  'RHOBTB3',
#  'MTMR4',
#  'SPN',
#  'CCL14',
#  'PICALM',
#  'AKR1C1',
#  'FEZF1',
#  'HOXC13',
#  'TRIM55',
#  'POGK',
#  'WBP1',
#  'SLCO4C1',
#  'TNFRSF6B',
#  'GTF2A1',
#  'SERF2',
#  'HIST1H1C',
#  'MT1A',
#  'C13orf27',
#  'SVEP1',
#  'CASP2',
#  'KIAA0101',
#  'WDR4',
#  'CCND1',
#  'EGR3',
#  'NCOA4',
#  'RRP1B',
#  'DHCR24',
#  'HSH2D',
#  'MAN1C1',
#  'LRRC26',
#  'GPR18',
#  'FANCL',
#  'DCAF6',
#  'DOT1L',
#  'ZNF718',
#  'FRYL',
#  'ATAD2',
#  'DCAF15',
#  'RPL28',
#  'FLJ10038',
#  'PIK3CG',
#  'SLC25A1',
#  'ARNTL',
#  'TRIM44',
#  'LAD1',
#  'ISLR',
#  'CAD',
#  'SIM1',
#  'FAM40A',
#  'ANKRD13C',
#  'SAMD11',
#  'SNX12',
#  'TUBA1C',
#  'RPUSD4',
#  'ZNF280B',
#  'FDFT1',
#  'IGSF1',
#  'HOXC11',
#  'ORMDL2',
#  'C5orf51',
#  'MYH14',
#  'DDX23',
#  'KRT5',
#  'RFPL4B',
#  'HOXA9',
#  'LHX4',
#  'PPP3CC',
#  'ASXL1',
#  'LOC400891',
#  'ZNF22',
#  'ZNF75A',
#  'CRYBA2',
#  'LPAR1',
#  'ITPRIPL2',
#  'HDGF',
#  'EBF2',
#  'CCL4L1',
#  'MSH2',
#  'NOL7',
#  'MAGOHB',
#  'LSR',
#  'ARF6',
#  'DYNLL2',
#  'GPRC5C',
#  'MST1',
#  'hsa-miR-196b',
#  'CCHCR1',
#  'ZMYM2',
#  'FZD2',
#  'PDE6D',
#  'HSP90AA1',
#  'GAGE2B',
#  'HNF1B',
#  'ENO1',
#  'S100A6',
#  'CABLES2',
#  'PXMP2',
#  'PAX8',
#  'STC2',
#  'MBOAT1',
#  'PNN',
#  'PASD1',
#  'CROCCL1',
#  'KILLIN',
#  'RAB3IL1',
#  'LIPC',
#  'DAD1',
#  'INSIG2',
#  'CKS1B',
#  'SRRM1',
#  'NOP10',
#  'N4BP3',
#  'SSBP2',
#  'RFC4',
#  'MRPS18C',
#  'TIFA',
#  'IRF2BP2',
#  'FGF21',
#  'GNB1L',
#  'PPA1',
#  'DLX2',
#  'POLR2J3',
#  'HPS5',
#  'HMX1',
#  'LBR',
#  'SNX16',
#  'LOC100130691',
#  'CYB561',
#  'FKBP9',
#  'SUPT16H',
#  'ASF1B',
#  'HCST',
#  'KIAA1826',
#  'SET',
#  'PTGES',
#  'ZNF346',
#  'GPR153',
#  'DGKZ',
#  'B3GALT6',
#  'ITGB4',
#  'ACTC1',
#  'LOC344967',
#  'CD34',
#  'C4orf21',
#  'HIST1H2BN',
#  'AC010760.1',
#  'MAGEA3',
#  'SNHG10',
#  'N6AMT1',
#  'AC068580.3',
#  'PERP',
#  'GAGE1',
#  'C1orf66',
#  'VAX2',
#  'CENPA',
#  'KLF1',
#  'PPAT',
#  'PDIK1L',
#  'NAA50',
#  'OLIG3',
#  'SGK1',
#  'C5orf41',
#  'WNT9A',
#  'TMEM185B',
#  'CEACAM21',
#  'AARS',
#  'ART4',
#  'BFSP1',
#  'GPR65',
#  'C10orf81',
#  'PMAIP1',
#  'ERP29',
#  'CYB5D1',
#  'BIN1',
#  'HIST1H2AJ',
#  'STAG1',
#  'DUOXA2',
#  'LUC7L2',
#  'CRCT1',
#  'TBX21',
#  'XPO5',
#  'RND1',
#  'PRODH2',
#  'SP9',
#  'SLC35A5',
#  'ALPK1',
#  'PNPT1',
#  'C9orf102',
#  'SGPL1',
#  'C8orf75',
#  'FRG2C',
#  'LOC648691',
#  'C9orf96',
#  'LOC254559',
#  'HOXA4',
#  'SOCS5',
#  'ENTPD5',
#  'PFDN1',
#  'SMYD2',
#  'APOF',
#  'MUC1',
#  'MCM3APAS',
#  'BHLHE41',
#  'LPHN1',
#  'FEN1',
#  'MSH5',
#  'IL24',
#  'NR2F1',
#  'IL4I1',
#  'HOXB9',
#  'CDK4',
#  'RNF157',
#  'PLSCR1',
#  'STXBP4',
#  'KRT13',
#  'COPS6',
#  'RPS12',
#  'AKR1A1',
#  'ARHGEF10L',
#  'GPR132',
#  'GNPDA2',
#  'LHX2',
#  'NCDN',
#  'SLC25A25',
#  'TOMM40',
#  'C19orf70',
#  'LOC283922',
#  'MZT1',
#  'SULF2',
#  'RNF213',
#  'ZNF302',
#  'RAB3A',
#  'ITGB1',
#  'HIST1H2BK',
#  'MAD1L1',
#  'TRAF2',
#  'HNRNPA0',
#  'FOXE1',
#  'FDPS',
#  'FAM35A',
#  'TATDN2',
#  'CD53',
#  'ACTL6A',
#  'RQCD1',
#  'HMOX2',
#  'hsa-miR-92a-1*',
#  'ATP6V0D1',
#  'EPS15',
#  'PRC1',
#  'TMEM42',
#  'TRIP13',
#  'ARFGAP3',
#  'PNPO',
#  'PVT1',
#  'TRAPPC2P1',
#  'SNX5',
#  'PDAP1',
#  'ITPKC',
#  'FAM183A',
#  'DLX4',
#  'C20orf177',
#  'NKX2-8',
#  'GPR162',
#  'RRM2',
#  'DCAF16',
#  'HIST1H1T',
#  'HOXD3',
#  'ZNF131',
#  'NDRG1',
#  'ACIN1',
#  'ATP2A2',
#  'RAB36',
#  'SELPLG',
#  'DDAH1',
#  'RAC1',
#  'TBCB',
#  'ZSWIM3',
#  'SNORA67',
#  'KLK11',
#  'KRT31',
#  'LONP1',
#  'psiTPTE22',
#  'SNORD83B',
#  'PRR11',
#  'CDK5RAP3',
#  'RB1',
#  'OAS2',
#  'PCK1',
#  'LIN54',
#  'ZNF503',
#  'SSR1',
#  'PPIA',
#  'SPIB',
#  'TBC1D5',
#  'IGFL1',
#  'VAMP5',
#  'FMNL3',
#  'KIAA0090',
#  'POU4F1',
#  'NAIF1',
#  'PCNT',
#  'HIST1H1E',
#  'H2AFY',
#  'HRC',
#  'NUP107',
#  'DNAJC9',
#  'HHLA3',
#  'C1orf110',
#  'RNF44',
#  'C8orf51',
#  'TNFAIP1',
#  'ATP13A4',
#  'HERC5',
#  'MAPK14',
#  'NUDT3',
#  'GPN3',
#  'SKP2',
#  'SH3TC2',
#  'ARL14',
#  'HSPA4',
#  'CCDC122',
#  'VIM',
#  'TRIM50',
#  'BCAS3',
#  'GAD2',
#  'RTN3',
#  'RPS9',
#  'ZNF77',
#  'MAN1B1',
#  'TGM1',
#  'KDM3A',
#  'GTPBP2',
#  'DEGS1',
#  'SNORA68',
#  'C1orf55',
#  'RNFT1',
#  'IL2RG',
#  'TOP2A',
#  'hsa-miR-26b',
#  'LOC100130148',
#  'EIF3B',
#  'TINAGL1',
#  'FJX1',
#  'NEDD4',
#  'FOXB1',
#  'RAB5B',
#  'PLEC',
#  'B3GAT3',
#  'SLC26A10',
#  'MYLPF',
#  'KIAA0391',
#  'SGPP2',
#  'LAPTM5',
#  'GABPB2',
#  'WFDC1',
#  'NPIP',
#  'C6orf211',
#  'PIGX',
#  'LOC100130581',
#  'IRX5',
#  'EMX2',
#  'HNRPDL',
#  'ENOPH1',
#  'ING1',
#  'SNORD32A',
#  'HPD',
#  'TXNRD2',
#  'UBE2B',
#  'IP6K1',
#  'MOGAT3',
#  'LAGE3',
#  'C2orf27B',
#  'TOR1A',
#  'C14orf126',
#  'GOLPH3',
#  'NEU1',
#  'ITPR3',
#  'HM13',
#  'CCDC114',
#  'TKTL1',
#  'SCAND3',
#  'BPGM',
#  'IPCEF1',
#  'ZIM2',
#  'TTC9C',
#  'SQLE',
#  'PKD1L1',
#  'ATF2',
#  'SNORD114-25',
#  'RSAD1',
#  'GP1BA',
#  'CD7',
#  'RPL32',
#  'PDCD6IP',
#  'DLK1',
#  'GATA6',
#  'VWDE',
#  'HNRNPC',
#  'GAPDH',
#  'SEC31A',
#  'MCM3',
#  'TMEM189-UBE2V1',
#  'EGLN3',
#  'ALKBH2',
#  'ITGB1BP1',
#  'FAM111A',
#  'TCF19',
#  'TMEM116',
#  'ETV4',
#  'PRSS21',
#  'SIK1',
#  'DARS',
#  'GPR55',
#  'TM7SF3',
#  'PML',
#  'KAT5',
#  'NUSAP1',
#  'RPS11',
#  'HIST1H4B',
#  'CGGBP1',
#  'OLR1',
#  'RECQL',
#  'OLIG1',
#  'MAGEC2',
#  'TBC1D15',
#  'FBXL8',
#  'PES1',
#  'SLC32A1',
#  'HPCAL4',
#  'MMRN2',
#  'IFIT1',
#  'PXT1',
#  'C2orf34',
#  'AMPD3',
#  'HIST1H2AD',
#  'TBC1D16',
#  'MED15',
#  'GRIA1',
#  'RNF220',
#  'FCER2',
#  'RAD51C',
#  'EML4',
#  'STX10',
#  'C14orf4',
#  'QKI',
#  'TYMP',
#  'CDK15',
#  'SEC62',
#  'MYEOV',
#  'KDM5B',
#  'C10orf88',
#  'SEC61B',
#  'RPS13',
#  'G6PC3',
#  'C11orf91',
#  'DHX40',
#  'XPC',
#  'NUP62',
#  'DNAJB5',
#  'TPM1',
#  'RBM27',
#  'ZNF280A',
#  'NAT10',
#  'LOC285627',
#  'CCNE2',
#  'SORBS2',
#  'PALB2',
#  'TADA2A',
#  'ORMDL3',
#  'AIF1L',
#  'UBR1',
#  'DNAH14',
#  'PSMA6',
#  'TXNDC2',
#  'C6orf27',
#  'SHD',
#  'HOXA10',
#  'SMYD4',
#  'C9orf43',
#  'RGS1',
#  'hsa-miR-92b',
#  'ITGAL',
#  'ZIK1',
#  'THOC6',
#  'SLC4A8',
#  'RHCG',
#  'STAG2',
#  'TM4SF1',
#  'CCNT1',
#  'TUBGCP5',
#  'GET4',
#  'TESC',
#  'ANKRD36',
#  'HOXA6',
#  'RHBG',
#  'YTHDC2',
#  'COPZ1',
#  'TMEM49',
#  'RPL3',
#  'IER3',
#  'SNORD104',
#  'TTBK2',
#  'LOC148413',
#  'DDX10',
#  'TRIM73',
#  'SIX1',
#  'PRPF40A',
#  'TLCD1',
#  'THPO',
#  'ISLR2',
#  'hsa-miR-302b*',
#  'HSPA9',
#  'FOXRED2',
#  'TMEM161A',
#  'MTRNR2L2',
#  'ZFYVE21',
#  'GNAZ',
#  'AC044799.1',
#  'OSGEP',
#  'AMZ1',
#  'SH3BGRL3',
#  'MAP3K5',
#  'E2F7',
#  'BCR',
#  'NOL3',
#  'LMNA',
#  'SSH1',
#  'VPS29',
#  'FAM173B',
#  'NFIC',
#  'CDCA3',
#  'CLN6',
#  'MXD1',
#  'POR',
#  'LOC440461',
#  'hsa-miR-541*',
#  'SMC1B',
#  'GMPS',
#  'IL7R',
#  'TPM4',
#  'EIF4H',
#  'AKR7A2',
#  'DTX3L',
#  'SKAP1',
#  'NUBPL',
#  'CD58',
#  'ZSWIM6',
#  'ICAM1',
#  'HNRNPA1',
#  'GRHL3',
#  'PKP1',
#  'ESYT1',
#  'ANP32B',
#  'SGCD',
#  'HOXD10',
#  'C10orf119',
#  'GALNT5',
#  'ONECUT3',
#  'ITPKA',
#  'TUBD1',
#  'ADM',
#  'CCDC140',
#  'TTLL5',
#  'PRR4',
#  'EPS8',
#  'NENF',
#  'MYOG',
#  'RPP14',
#  'SLC25A24',
#  'LOC84931',
#  'CDR2',
#  'SLC39A1',
#  'NAPSA',
#  'C16orf5',
#  'TRAPPC2L',
#  'C4orf19',
#  'KLF11',
#  'CAPG',
#  'C13orf29',
#  'PHOX2B',
#  'GLYCTK',
#  'CDC20',
#  'ICMT',
#  'SHKBP1',
#  'CSTF2T',
#  'IL8',
#  'NEK6',
#  'ITGA5',
#  'KHNYN',
#  'ATP6V1G1',
#  'APBB3',
#  'TFEB',
#  'SGK2',
#  'C14orf1',
#  'SAC3D1',
#  'BAK1',
#  'RBM15',
#  'GBX2',
#  'UNC13A',
#  'TAF1D',
#  'RASA2',
#  'USP14',
#  'FAM21A',
#  'IFI6',
#  'TMEM135',
#  'MED22',
#  'KCTD9',
#  'ARHGAP24',
#  'MGA',
#  'BAGE',
#  'PGP',
#  'PSMA1',
#  'ATXN1',
#  'ZFR',
#  'MPV17',
#  'SAT1',
#  'ALS2CL',
#  'SLC3A2',
#  'EIF2AK2',
#  'MT1E',
#  'YPEL1',
#  'CD79B',
#  'LIMA1',
#  'TBC1D2B',
#  'NT5C1A',
#  'HSPB3',
#  'TRAF3',
#  'NKX2-3',
#  'LIPH',
#  'LOC729082',
#  'MMP10',
#  'DNAJC27',
#  'PPM1F',
#  'LPP',
#  'PGS1',
#  'TUBA1B',
#  'TFDP1',
#  'CCDC47',
#  'GGTLC2',
#  'HIST1H2BC',
#  'KIAA0748',
#  'ECHS1',
#  'LOC645323',
#  'ZFYVE27',
#  'IMMP1L',
#  'SPTLC2',
#  'SNORD83A',
#  'CUTA',
#  'NUBP2',
#  'EBF3',
#  'ITFG2',
#  'ABCB10',
#  'PKM2',
#  'TMED1',
#  'UBE2D3',
#  'MPND',
#  'SNORD114-27',
#  'C14orf21',
#  'ZNF217',
#  'CDCA7',
#  'ZFHX3',
#  'ZFP36L2',
#  'YTHDF1',
#  'GGA2',
#  'ALS2',
#  'EPS8L2',
#  'MRPL30',
#  'CDCA4',
#  'PTPRB',
#  'NEUROG2',
#  'SHOX',
#  'H2AFJ',
#  'RBM42',
#  'C12orf57',
#  'VAV2',
#  'GSX2',
#  'CCDC103',
#  'GNASAS',
#  'TLX1NB',
#  'MTHFS',
#  'MBTPS1',
#  'DCLRE1B',
#  'AFAP1L2',
#  'YPEL4',
#  'CSF2',
#  'HOXA3',
#  'COQ9',
#  'FOXL1',
#  'TBX3',
#  'GRK4',
#  'PCOLCE',
#  'TNFRSF1A',
#  'TMEM14C',
#  'ANAPC11',
#  'SEMA4B',
#  'FAM105B',
#  'CD68',
#  'WASH2P',
#  'H2AFV',
#  'EIF4A3',
#  'MEPCE',
#  'SCLY',
#  'SNORA48',
#  'ADAM9',
#  'NAP1L4',
#  'ATP5B',
#  'RC3H2',
#  'PLD6',
#  'SNORD27',
#  'PDE12',
#  'ERG',
#  'PPP1R15A',
#  'RBM4',
#  'hsa-miR-1293',
#  'TRIM33',
#  'CRTAP',
#  'GCLC',
#  'AC004381.6',
#  'SETD6',
#  'NADK',
#  'HCFC1R1',
#  'RAD9A',
#  'NOP16',
#  'CNDP2',
#  'FRG1',
#  'HIST1H1D',
#  'SERPINB7',
#  'ZNF219',
#  'DVL2',
#  'LIMS1',
#  'C3orf63',
#  'MSC',
#  'VSNL1',
#  'hsa-miR-21',
#  'CSPG4',
#  'ITPR1',
#  'ATF4',
#  'LRPPRC',
#  'AP4S1',
#  'DCTN2',
#  'MDH2',
#  'C12orf11',
#  'CHP',
#  'DUOX2',
#  'C12orf24',
#  ...}

# %%
def get_len(item):
    return len(net.in_edges(item))

# %%
lista=[(gene,len(G.in_edges(gene))) for gene in readout_common]

# %%
len_innodes_gene=defaultdict(set)
for el in lista:
    len_innodes_gene[el[1]].add(el[0])
len_innodes_gene[5]
# Out:
# {'AARS',
#  'AATF',
#  'ABCA17P',
#  'ABCB8',
#  'ACTL6A',
#  'AIFM2',
#  'AIMP2',
#  'APTX',
#  'ARRDC2',
#  'ATP5G1',
#  'AVPI1',
#  'C10orf88',
#  'C11orf59',
#  'C13orf29',
#  'C14orf119',
#  'C16orf74',
#  'C19orf40',
#  'C19orf51',
#  'C1QTNF6',
#  'C1orf107',
#  'C1orf228',
#  'C20orf24',
#  'C21orf58',
#  'C5orf39',
#  'C5orf51',
#  'C6orf89',
#  'C7orf40',
#  'C8orf55',
#  'C9orf3',
#  'CABC1',
#  'CCBL1',
#  'CCDC123',
#  'CCNT1',
#  'CDC5L',
#  'CDR2',
#  'CENPL',
#  'CISD2',
#  'CNTLN',
#  'COX5A',
#  'CPB2',
#  'CREB3L4',
#  'CSPG4',
#  'CYP51A1',
#  'DAGLB',
#  'DARS2',
#  'DDIT3',
#  'DDX47',
#  'DENND4A',
#  'DEPDC4',
#  'DLX4',
#  'DNA2',
#  'DNAJC9',
#  'DOCK10',
#  'DRAP1',
#  'DSCC1',
#  'ENOPH1',
#  'ERGIC2',
#  'EXD1',
#  'FLJ31306',
#  'FLJ45983',
#  'FOXE1',
#  'GADD45A',
#  'GIMAP4',
#  'GLDC',
#  'GPATCH3',
#  'GPBP1',
#  'HELQ',
#  'HES4',
#  'HGSNAT',
#  'HIGD2A',
#  'HMX2',
#  'HOXA2',
#  'HOXD8',
#  'HRC',
#  'HSF2BP',
#  'HSPBAP1',
#  'ICAM1',
#  'IFI6',
#  'IQCD',
#  'ISLR2',
#  'ITPR3',
#  'KDM3A',
#  'KEAP1',
#  'KIAA0406',
#  'KNCN',
#  'LBX1',
#  'LBX2',
#  'LENG1',
#  'LHX5',
#  'LIMS1',
#  'LIN37',
#  'LMNB1',
#  'LOC729082',
#  'LONP1',
#  'LOXL1',
#  'LOXL2',
#  'LSMD1',
#  'MAP1D',
#  'MBIP',
#  'MBOAT1',
#  'MCOLN1',
#  'MED22',
#  'MLF1IP',
#  'MPV17L2',
#  'MYO1G',
#  'NKX2-5',
#  'NLRC5',
#  'NOC3L',
#  'NOL11',
#  'NPHP4',
#  'NUDT2',
#  'NUP107',
#  'ODF3B',
#  'OSR2',
#  'PARP9',
#  'PASD1',
#  'PAWR',
#  'PCNT',
#  'PCSK9',
#  'PLA2G6',
#  'PLD6',
#  'PNO1',
#  'PNPT1',
#  'POLA1',
#  'POLE4',
#  'POLR2E',
#  'PPARG',
#  'PQLC2',
#  'PRDX2',
#  'RBBP8',
#  'RBCK1',
#  'RBM18',
#  'RECQL',
#  'RFPL4B',
#  'RGS12',
#  'RNF7',
#  'RNFT1',
#  'RPL24',
#  'RPS8',
#  'RPS9',
#  'RSAD1',
#  'RSAD2',
#  'S100A6',
#  'SAE1',
#  'SARNP',
#  'SCAMP3',
#  'SDF4',
#  'SDPR',
#  'SEC31A',
#  'SGOL1',
#  'SH2D4A',
#  'SIM1',
#  'SIX1',
#  'SKIL',
#  'SLC15A4',
#  'SLC25A11',
#  'SLC25A24',
#  'SNORA76',
#  'SNORD35B',
#  'SP9',
#  'STARD4',
#  'STRADA',
#  'SUPT4H1',
#  'TARS',
#  'TASP1',
#  'TCP11L1',
#  'TCTEX1D4',
#  'THADA',
#  'THAP8',
#  'TM2D2',
#  'TM7SF3',
#  'TMEM140',
#  'TMEM159',
#  'TMEM161A',
#  'TMEM201',
#  'TMEM45A',
#  'TRIP13',
#  'TRPM7',
#  'TSPAN31',
#  'TUBGCP3',
#  'TYK2',
#  'UBE2C',
#  'UBE2L6',
#  'UBE2S',
#  'UNG',
#  'USP18',
#  'VRTN',
#  'WBP1',
#  'WDR36',
#  'WDR4',
#  'WDR89',
#  'WT1',
#  'XPC',
#  'YTHDC2',
#  'ZFYVE27',
#  'ZNF564',
#  'ZNF593',
#  'ZNF691',
#  'ZNF785',
#  'ZXDB',
#  'hsa-miR-302d',
#  'hsa-miR-302d*',
#  'hsa-miR-367*',
#  'hsa-miR-483-5p',
#  'hsa-miR-9*'}

# %%
set_common=[]
for GO_term in GO_id_map.keys():
    print()
    print(GO_term)
    for gene_view in GO_id_map[GO_term]:
        print(gene_view,"",set(G[gene_view]) & len_innodes_gene[5])
        set_common.append(set(G[gene_view]) & len_innodes_gene[5])
# Out:
# GO:0070317
# BRCA1  {'SLC25A11', 'NUDT2', 'GPBP1', 'CDC5L', 'SLC15A4', 'LSMD1', 'C6orf89', 'XPC', 'NOL11', 'CCNT1', 'STYXL1', 'GPATCH3', 'THADA', 'SNORD35B', 'MED22', 'ERGIC2', 'POLR2E'}
# E2F6  {'HES4', 'ABCA17P', 'KIAA0406', 'HSF2BP', 'RBM18', 'ZNF785', 'C10orf88', 'EXD1', 'CNTLN', 'CISD2', 'PQLC2', 'SDF4', 'KEAP1', 'ACAD9', 'SP9', 'AATF', 'WDR36', 'AIMP2', 'POLE4', 'DNA2', 'C8orf55', 'CABC1', 'HSPBAP1', 'ENOPH1', 'ABCA3', 'HRC'}
# MAX  {'SNORA76', 'WDR4', 'ZFYVE27', 'HES4', 'ABCA17P', 'ALDH1A1', 'MAP1D', 'TASP1', 'HSF2BP', 'PLD6', 'ZNF785', 'WDR89', 'C10orf88', 'EXD1', 'KDM3A', 'GLDC', 'C7orf40', 'SCAMP3', 'ACAD9', 'HELQ', 'SGOL1', 'MCOLN1', 'C1orf107', 'LONP1', 'THAP8', 'THADA', 'AATF', 'HIGD2A', 'WDR36', 'DOCK10', 'AIMP2', 'RPS8', 'C11orf59', 'POLE4', 'LOXL1', 'CCNT1', 'UBE2S', 'CABC1', 'HSPBAP1', 'ENOPH1', 'NOC3L', 'SAE1', 'ABCA3', 'HRC', 'POLR2E', 'PNO1'}
# E2F1  {'STRADA', 'SUPT4H1', 'DSCC1', 'HES4', 'MBOAT1', 'ITPR3', 'TMEM159', 'CENPL', 'TRPM7', 'HSF2BP', 'CREB3L4', 'PAWR', 'ARRDC2', 'SKIL', 'COX5A', 'DARS2', 'HGSNAT', 'RSAD1', 'TMEM201', 'LMNB1', 'POLA1', 'AIFM2', 'RNFT1', 'TCP11L1', 'PQLC2', 'BRD9', 'SH2D4A', 'CCBL1', 'SLC25A24', 'OSR2', 'TUBGCP3', 'RBBP8', 'TM7SF3', 'C16orf74', 'AVPI1', 'TRIP13', 'C8orf55', 'DNAJC9'}
# SUZ12  {'SIM1', 'HOXA2', 'NKX2-5', 'FOXE1', 'SP9', 'FLJ45983', 'OSR2', 'HOXD8', 'LHX5', 'hsa-miR-9*', 'AATF', 'SIX1', 'LBX1', 'LBX2', 'DLX4', 'WT1', 'HMX2', 'ISLR2'}
#
# GO:0051591
# FOS  {'S100A6', 'UBE2C', 'TM2D2', 'ZNF564', 'GADD45A', 'LOXL2', 'AARS', 'FLJ31306', 'TMEM161A', 'C19orf51', 'C1orf228', 'GIMAP4', 'ATP5G1', 'C21orf58', 'ABCB8', 'MPV17L2', 'UNG', 'TCTEX1D4', 'SARNP', 'CCDC123', 'ACTL6A', 'LIMS1', 'LOC729082', 'CDR2', 'CSPG4', 'WBP1', 'LIN37', 'RECQL', 'TMEM45A', 'LENG1', 'PCNT', 'CABC1', 'IQCD', 'ZNF775', 'ZNF691', 'C13orf29', 'C19orf40', 'TYK2', 'NPHP4'}
# SREBF1  {'C5orf51', 'CYP51A1', 'PCSK9', 'PLA2G6', 'C14orf119', 'ZNF775', 'STARD4', 'TMEM14C', 'RBCK1'}
# JUNB  set()
# JUN  {'CSPG4', 'MBIP', 'ZNF593', 'TCTEX1D4', 'ALDH1A1', 'DDX47', 'PASD1', 'C20orf24', 'RPL24', 'ATP5G1', 'DDIT3', 'SDPR', 'TM2D2', 'SEC31A', 'LIMS1', 'C13orf29', 'GIMAP4', 'RBCK1'}
# JUND  {'RGS12', 'ZFYVE27', 'HES4', 'PASD1', 'C20orf24', 'PPARG', 'C9orf3', 'PRDX2', 'hsa-miR-302d', 'CDC5L', 'C20orf111', 'hsa-miR-367*', 'ATP5G1', 'ACAD9', 'CCBL1', 'MYO1G', 'RFPL4B', 'hsa-miR-483-5p', 'THADA', 'RPL24', 'hsa-miR-302d*', 'RBCK1', 'DAGLB', 'MBIP', 'MLF1IP', 'ZNF593', 'RNF7', 'TSPAN31', 'VRTN', 'DEPDC4', 'ZXDB', 'CPB2', 'APTX', 'C13orf29', 'YTHDC2'}
# STAT1  {'RPS9', 'C1QTNF6', 'USP18', 'C5orf39', 'IFI6', 'TMEM140', 'KNCN', 'UBE2L6', 'NLRC5', 'PNPT1', 'RSAD2', 'ODF3B', 'NUP107', 'PARP9', 'DENND4A', 'TARS', 'ICAM1'}
# FOSL1  {'DRAP1'}

# %%
i=range(0,len(set_common))
for index,el in enumerate(set_common):
    print(index)
    for number in i:
        if number != index:
            print(el & set_common[number])
# Out:
# 0
# set()
# {'CCNT1', 'POLR2E', 'THADA'}
# set()
# set()
# set()
# set()
# set()
# set()
# {'CDC5L', 'THADA'}
# set()
# set()
# 1
# set()
# {'C10orf88', 'EXD1', 'AIMP2', 'HES4', 'ABCA17P', 'POLE4', 'CABC1', 'AATF', 'HSPBAP1', 'ENOPH1', 'WDR36', 'ABCA3', 'HSF2BP', 'HRC', 'ZNF785', 'ACAD9'}
# {'HES4', 'HSF2BP', 'PQLC2', 'C8orf55'}
# {'AATF', 'SP9'}
# {'CABC1'}
# set()
# set()
# set()
# {'HES4', 'ACAD9'}
# set()
# set()
# 2
# {'CCNT1', 'POLR2E', 'THADA'}
# {'C10orf88', 'EXD1', 'AIMP2', 'HES4', 'ABCA17P', 'POLE4', 'CABC1', 'AATF', 'HSPBAP1', 'ENOPH1', 'WDR36', 'ABCA3', 'HSF2BP', 'HRC', 'ZNF785', 'ACAD9'}
# {'HES4', 'HSF2BP'}
# {'AATF'}
# {'CABC1'}
# set()
# set()
# {'ALDH1A1'}
# {'HES4', 'ZFYVE27', 'ACAD9', 'THADA'}
# set()
# set()
# 3
# set()
# {'HES4', 'HSF2BP', 'PQLC2', 'C8orf55'}
# {'HES4', 'HSF2BP'}
# {'OSR2'}
# set()
# set()
# set()
# set()
# {'HES4', 'CCBL1'}
# set()
# set()
# 4
# set()
# {'AATF', 'SP9'}
# {'AATF'}
# {'OSR2'}
# set()
# set()
# set()
# set()
# set()
# {'CCNT1', 'POLR2E', 'THADA'}
# set()
# set()
# 5
# set()
# {'CABC1'}
# {'CABC1'}
# set()
# {'CDC5L', 'THADA'}
# set()
# {'ZNF775'}
# set()
# {'CSPG4', 'TCTEX1D4', 'TM2D2', 'GIMAP4', 'LIMS1', 'C13orf29', 'ATP5G1'}
# {'C13orf29', 'ATP5G1'}
# set()
# set()
# 6
# set()
# 1
# set()
# {'ZNF785', 'ENOPH1', 'ABCA17P', 'CABC1', 'ACAD9', 'HRC', 'ABCA3', 'HSF2BP', 'AATF', 'AIMP2', 'C10orf88', 'EXD1', 'HSPBAP1', 'POLE4', 'HES4', 'WDR36'}
# {'SP9', 'AATF'}
# {'C8orf55', 'PQLC2', 'HES4', 'HSF2BP'}
# set()
# set()
# set()
# {'ZNF775'}
# set()
# {'RBCK1'}
# {'RBCK1'}
# set()
# set()
# 7
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# 8
# set()
# set()
# {'ALDH1A1'}
# set()
# set()
# {'CSPG4', 'TCTEX1D4', 'TM2D2', 'GIMAP4', 'LIMS1', 'C13orf29', 'ATP5G1'}
# {'RBCK1'}
# set()
# {'MBIP', 'ZNF593', 'PASD1', 'C20orf24', 'RPL24', 'C13orf29', 'ATP5G1', 'RBCK1'}
# set()
# set()
# 9
# {'CDC5L', 'THADA'}
# {'HES4', 'ACAD9'}
# {'HES4', 'ZFYVE27', 'ACAD9', 'THADA'}
# {'HES4', 'CCBL1'}
# set()
# {'C13orf29', 'ATP5G1'}
# {'RBCK1'}
# set()
# {'MBIP', 'ZNF593', 'PASD1', 'C20orf24', 'RPL24', 'C13orf29', 'ATP5G1', 'RBCK1'}
# set()
# set()
# 10
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# 11
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()

# %%
for gene in len_innodes_gene[10]:
    
    genes_res_no_go=set(edge[0] for edge in G.in_edges(gene) if edge[0] not in set.union(*GO_id_map.values()))
    
    if genes_res_no_go.intersection(set(net.nodes())) != genes_res_no_go:
        continue
    print(gene)
    for key in GO_id_map.keys():
        print(key)
        print(set(gene_res for edge in G.in_edges(gene) for gene_res in GO_id_map[key] if gene_res in edge[0] ))
   
    print(genes_res_no_go)
   
    print()
# Out:
# HES4
# GO:0070317
# {'E2F1', 'MAX', 'E2F6'}
# GO:0051591
# {'JUN', 'JUND'}
# {'ZBTB7A'}
#
# ALDH1A1
# GO:0070317
# {'MAX'}
# GO:0051591
# {'JUN'}
# {'USF1', 'CTCF', 'RAD21'}
#
# UBE2C
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'SP1', 'EP300', 'IRF3', 'E2F4'}
#
# MAP1D
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'MYC', 'USF1', 'SIN3A', 'YY1'}
#
# ODF3B
# GO:0070317
# set()
# GO:0051591
# {'STAT1'}
# {'STAT3', 'POU2F2', 'STAT2', 'NFKB1'}
#
# CREB3L4
# GO:0070317
# {'E2F1'}
# GO:0051591
# set()
# {'NFYB', 'PBX3', 'FOXA1', 'NFYA'}
#
# C10orf88
# GO:0070317
# {'MAX', 'E2F6'}
# GO:0051591
# set()
# {'NRF1', 'TCF4', 'E2F4'}
#
# FLJ31306
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'SP1', 'NFYB', 'IRF3', 'NFYA'}
#
# hsa-miR-367*
# GO:0070317
# set()
# GO:0051591
# {'JUN', 'JUND'}
# {'TAF7', 'BCL3', 'POU5F1', 'BCL11A'}
#
# ACAD9
# GO:0070317
# {'MAX', 'E2F6'}
# GO:0051591
# {'JUN', 'JUND'}
# {'ATF3', 'NRF1'}
#
# ABCB8
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'SP1', 'NFYB', 'NFYA', 'SP2'}
#
# NUDT2
# GO:0070317
# {'BRCA1'}
# GO:0051591
# set()
# {'ELK4', 'NFYB', 'NFYA', 'E2F4'}
#
# NOL11
# GO:0070317
# {'BRCA1'}
# GO:0051591
# set()
# {'ZBTB33', 'CTCFL', 'CTCF', 'CEBPB'}
#
# RBCK1
# GO:0070317
# set()
# GO:0051591
# {'SREBF1', 'JUN', 'JUND'}
# {'SREBF2', 'EP300'}
#
# AVPI1
# GO:0070317
# {'E2F1'}
# GO:0051591
# set()
# {'NR3C1', 'EGR1', 'TFAP2A', 'TFAP2C'}
#
# TMEM45A
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'NFYB', 'PBX3', 'hsa-miR-19a', 'NFYA'}
#
# C11orf59
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'USF1', 'ATF3', 'USF2', 'NFE2'}
#
# CCNT1
# GO:0070317
# {'BRCA1', 'MAX'}
# GO:0051591
# set()
# {'USF1', 'EGR1', 'USF2'}
#
# TRIP13
# GO:0070317
# {'E2F1'}
# GO:0051591
# set()
# {'MYC', 'SIN3A', 'GABPA', 'E2F4'}
#
# ZNF691
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'SP1', 'NFYB', 'NFYA', 'hsa-miR-125a-5p'}
#
# C19orf40
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'SP1', 'NFYB', 'NFYA', 'E2F4'}
#
# TMEM14C
# GO:0070317
# set()
# GO:0051591
# {'SREBF1'}
# {'SP1', 'NR3C1', 'MAFK', 'MAFF'}
#
# DENND4A
# GO:0070317
# set()
# GO:0051591
# {'STAT1'}
# {'MEF2A', 'ZNF263', 'EGR1', 'NFKB1'}
#
# POLR2E
# GO:0070317
# {'BRCA1', 'MAX'}
# GO:0051591
# set()
# {'ZBTB33', 'BATF', 'MYC'}
#
# SIX1
# GO:0070317
# {'SUZ12'}
# GO:0051591
# set()
# {'CTBP2', 'ZNF263', 'TCF12', 'EP300'}
#
# PRDX2
# GO:0070317
# set()
# GO:0051591
# {'JUN', 'JUND'}
# {'SMARCA4', 'SMARCB1', 'SRF', 'EP300'}
#
# PLD6
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'PAX5', 'EGR1', 'MYC', 'USF1'}
#
# hsa-miR-302d
# GO:0070317
# set()
# GO:0051591
# {'JUN', 'JUND'}
# {'TAF7', 'BCL3', 'POU5F1', 'BCL11A'}
#
# CDC5L
# GO:0070317
# {'BRCA1'}
# GO:0051591
# {'JUN', 'JUND'}
# {'ZBTB33', 'NRF1', 'ETS1'}
#
# DDX47
# GO:0070317
# set()
# GO:0051591
# {'JUN'}
# {'CTCF', 'YY1', 'RAD21', 'GATA2'}
#
# TMEM161A
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'NFYB', 'PBX3', 'TCF4', 'NFYA'}
#
# C19orf51
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'NFYB', 'EP300', 'NFYA', 'CTCF'}
#
# HELQ
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'USF2', 'USF1', 'NRF1', 'GABPA'}
#
# BRD9
# GO:0070317
# {'E2F1'}
# GO:0051591
# set()
# {'MYC', 'SIN3A', 'GABPA', 'E2F4'}
#
# C5orf51
# GO:0070317
# set()
# GO:0051591
# {'SREBF1'}
# {'ELK4', 'USF1', 'SRF', 'USF2'}
#
# RFPL4B
# GO:0070317
# set()
# GO:0051591
# {'JUN', 'JUND'}
# {'STAT3', 'EP300', 'CEBPB', 'RFX5'}
#
# LONP1
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'MYC', 'USF1', 'ATF3', 'USF2'}
#
# hsa-miR-483-5p
# GO:0070317
# set()
# GO:0051591
# {'FOS', 'JUN', 'JUND'}
# {'HEY1', 'FOXA1', 'MYC', 'FOSL2'}
#
# THADA
# GO:0070317
# {'BRCA1', 'MAX'}
# GO:0051591
# {'JUN', 'JUND'}
# {'ZBTB33', 'SIN3A'}
#
# SLC25A11
# GO:0070317
# {'BRCA1'}
# GO:0051591
# set()
# {'POU2F2', 'ZBTB33', 'BCL3', 'ETS1'}
#
# LIN37
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'SP1', 'PBX3', 'SIX5', 'CEBPB'}
#
# ZNF593
# GO:0070317
# set()
# GO:0051591
# {'JUN', 'JUND'}
# {'ZNF263', 'MYC', 'CTCF'}
#
# FLJ45983
# GO:0070317
# {'SUZ12'}
# GO:0051591
# set()
# {'CTBP2', 'TCF12', 'CTCF', 'RAD21'}
#
# PCNT
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'NFYB', 'TAL1', 'GATA2', 'E2F4'}
#
# CPB2
# GO:0070317
# set()
# GO:0051591
# {'JUN', 'JUND'}
# {'TAL1', 'TCF4', 'EP300', 'MAFK'}
#
# NUP107
# GO:0070317
# set()
# GO:0051591
# {'STAT1'}
# {'STAT3', 'NR2C2', 'NRF1', 'GABPA'}
#
# NPHP4
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'SP1', 'NFYB', 'PBX3', 'NFYA'}
#
# S100A6
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'SMARCA4', 'SMARCB1', 'TFAP2A', 'TFAP2C'}
#
# ABCA17P
# GO:0070317
# {'MAX', 'E2F6'}
# GO:0051591
# set()
# {'NRF1', 'CTCFL', 'CTCF'}
#
# C20orf24
# GO:0070317
# set()
# GO:0051591
# {'JUN', 'JUND'}
# {'CTCF', 'RAD21', 'SPI1'}
#
# ZNF564
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'SP1', 'NFYB', 'PBX3', 'NFYA'}
#
# HSF2BP
# GO:0070317
# {'E2F1', 'MAX', 'E2F6'}
# GO:0051591
# set()
# {'TCF4', 'MYC'}
#
# HOXA2
# GO:0070317
# {'SUZ12'}
# GO:0051591
# set()
# {'CTBP2', 'TCF12', 'hsa-miR-760', 'GATA2'}
#
# SLC15A4
# GO:0070317
# {'BRCA1'}
# GO:0051591
# set()
# {'TCF12', 'ZBTB33', 'EBF1', 'hsa-miR-124'}
#
# STYXL1
# GO:0070317
# {'BRCA1'}
# GO:0051591
# set()
# {'ZBTB33', 'GABPA', 'ELF1', 'ETS1'}
#
# C1orf228
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'SP1', 'NFYA', 'PBX3', 'SP2'}
#
# SCAMP3
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'USF1', 'hsa-miR-145', 'USF2', 'hsa-miR-128'}
#
# ATP5G1
# GO:0070317
# set()
# GO:0051591
# {'FOS', 'JUN', 'JUND'}
# {'SP1', 'NFYA'}
#
# C21orf58
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'NFYB', 'TAL1', 'GATA2', 'E2F4'}
#
# SGOL1
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'NFE2', 'USF1', 'USF2', 'E2F4'}
#
# LSMD1
# GO:0070317
# {'BRCA1'}
# GO:0051591
# set()
# {'GATA1', 'ZBTB33', 'ETS1', 'GATA2'}
#
# LHX5
# GO:0070317
# {'SUZ12'}
# GO:0051591
# set()
# {'hsa-miR-9', 'CTBP2', 'TCF12', 'hsa-miR-133a'}
#
# CCDC123
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'SP1', 'NFYB', 'NFYA', 'E2F4'}
#
# AATF
# GO:0070317
# {'SUZ12', 'MAX', 'E2F6'}
# GO:0051591
# set()
# {'USF1', 'ELF1'}
#
# hsa-miR-302d*
# GO:0070317
# set()
# GO:0051591
# {'JUN', 'JUND'}
# {'TAF7', 'BCL3', 'POU5F1', 'BCL11A'}
#
# C16orf74
# GO:0070317
# {'E2F1'}
# GO:0051591
# set()
# {'ESR1', 'CTCF', 'SPI1', 'EP300'}
#
# DAGLB
# GO:0070317
# set()
# GO:0051591
# {'FOS', 'JUN', 'JUND'}
# {'TAL1', 'NRF1', 'GTF2B', 'FOSL2'}
#
# C6orf89
# GO:0070317
# {'BRCA1'}
# GO:0051591
# set()
# {'ZBTB33', 'GABPA', 'CTCF', 'ELF1'}
#
# C8orf55
# GO:0070317
# {'E2F1', 'E2F6'}
# GO:0051591
# set()
# {'CTCF', 'TFAP2A', 'TFAP2C'}
#
# ZNF775
# GO:0070317
# set()
# GO:0051591
# {'SREBF1', 'FOS'}
# {'NFYB', 'TCF4', 'NFYA'}
#
# C13orf29
# GO:0070317
# set()
# GO:0051591
# {'FOS', 'JUN', 'JUND'}
# {'TFAP2A', 'TFAP2C'}
#
# TYK2
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'SP1', 'NFYB', 'NFYA', 'NFKB1'}
#
# SNORA76
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'MYC', 'USF1', 'TBP', 'USF2'}
#
# STARD4
# GO:0070317
# set()
# GO:0051591
# {'SREBF1'}
# {'hsa-miR-129-3p', 'SREBF2', 'TFAP2A', 'TFAP2C'}
#
# IFI6
# GO:0070317
# set()
# GO:0051591
# {'STAT1'}
# {'STAT2', 'IRF1', 'CTCF', 'ZEB1'}
#
# C20orf111
# GO:0070317
# set()
# GO:0051591
# {'JUN', 'JUND'}
# {'NRF1', 'SIN3A', 'CTCF', 'RAD21'}
#
# MPV17L2
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'SP1', 'NFYB', 'NFYA', 'SP2'}
#
# CCBL1
# GO:0070317
# {'E2F1'}
# GO:0051591
# {'JUN', 'JUND'}
# {'ELF1', 'YY1', 'GATA2'}
#
# MCOLN1
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'USF1', 'ATF3', 'USF2', 'NFE2'}
#
# MYO1G
# GO:0070317
# set()
# GO:0051591
# {'JUN', 'JUND'}
# {'EBF1', 'EP300', 'CEBPB', 'TFAP2C'}
#
# C1orf107
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'ELK4', 'ATF3', 'MYC', 'GATA2'}
#
# THAP8
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'NFYB', 'USF2', 'CTCF', 'USF1'}
#
# SP9
# GO:0070317
# {'SUZ12', 'E2F6'}
# GO:0051591
# set()
# {'CTBP2', 'TCF12', 'TCF4'}
#
# SNORD35B
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'ZBTB33', 'BCL3', 'SMARCA4', 'ETS1'}
#
# SARNP
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'SP1', 'NFYB', 'IRF3', 'NFYA'}
#
# LOC729082
# GO:0070317
# {'E2F1'}
# GO:0051591
# {'FOS'}
# {'NFYB', 'PBX3', 'IRF3', 'NFYA'}
#
# LOC147727
# GO:0070317
# {'MAX', 'E2F6'}
# GO:0051591
# set()
# {'MYC', 'hsa-miR-19a', 'EP300', 'CEBPB'}
#
# MLF1IP
# GO:0070317
# set()
# GO:0051591
# {'JUN', 'JUND'}
# {'SP1', 'NR3C1', 'NRF1', 'E2F4'}
#
# AIMP2
# GO:0070317
# {'MAX', 'E2F6'}
# GO:0051591
# set()
# {'NFYB', 'MYC', 'NFYA'}
#
# CABC1
# GO:0070317
# {'MAX', 'E2F6'}
# GO:0051591
# {'FOS'}
# {'NFYB', 'NFYA'}
#
# HSPBAP1
# GO:0070317
# {'MAX', 'E2F6'}
# GO:0051591
# set()
# {'USF1', 'USF2', 'NFE2'}
#
# SAE1
# GO:0070317
# {'MAX'}
# GO:0051591
# set()
# {'MYC', 'USF1', 'USF2', 'CTCFL'}
#
# IQCD
# GO:0070317
# set()
# GO:0051591
# {'FOS'}
# {'SP1', 'NFYB', 'PBX3', 'NFYA'}
#
# ABCA3
# GO:0070317
# {'MAX', 'E2F6'}
# GO:0051591
# set()
# {'NRF1', 'CTCFL', 'CTCF'}

# %%
max(len_innodes_gene, key=len_innodes_gene.get)
# Out:
# 55

# %%
GO_007={readout_gene : { edge[0] for edge in G.in_edges(readout_gene) if edge[0] in net.nodes()}for readout_gene in ["STYXL1","BRD9","ABCA3"]}
np.save('GO_007.npy',GO_007)

# %%
GO_007_005= {readout_gene :{ edge[0] for edge in G.in_edges(readout_gene) if edge[0] in net.nodes()}for readout_gene in ["ACAD9","ALDH1A1"]}
np.save('GO_007and005.npy',GO_007_005)

# %%
GO_005={readout_gene : { edge[0] for edge in G.in_edges(readout_gene)} for readout_gene in ["UBE2C","hsa-miR-483-5p","C20orf111"]}
np.save('GO_005.npy',GO_005)

# %%
[key for dici in [GO_005,GO_007,GO_007_005] for key in dici]
# Out:
# ['APOM', 'TUBB1', 'SPHK1']

# %%
## Win test
res_size=207
in_size=1
i_scaling=1

# %%
matrix,dict_pos=build_adj_weighted_matrix(file,mapping_relabel)

# %%
Win=np.zeros((res_size,1+in_size))*i_scaling
Win[1,]

# %%
#print(GO_id_map["GO:0030220"])
for gene in GO_id_map["GO:0030220"]:
    print(dict_pos[gene])
    Win[dict_pos[gene],]=2
print(np.where(Win==2))

# %%
def input_matrix_just_genes_GOterm(Win,GOterm,GO_id_map):
    for gene in GO_id_map[GOterm]:
        Win[dict_pos[gene],]=np.random.uniform(0,1)
    return Win

# %%
Win=np.zeros((res_size,1+in_size))*i_scaling
input_matrix_just_genes_GOterm(Win,"GO:0030220",GO_id_map)
